# %% [markdown]
# ## Activity 3, Wednesday 18th of January

# %% [markdown]
# ### - Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# First, I import the database in csv format
mca = pd.read_csv('Data_Marketing_Customer_Analysis_Round3.csv')

# %%
mca
# Out:
#             region  customer_lifetime_value response  coverage education  \
# 0          central                     4809       no     basic   college
# 1      west region                     2228       no     basic   college
# 2             east                    14947       no     basic  bachelor
# 3       north west                    22332      yes  extended   college
# 4       north west                     9025       no   premium  bachelor
# ...            ...                      ...      ...       ...       ...
# 10684      central                    15563       no   premium  bachelor
# 10685   north west                     5259       no     basic   college
# 10686      central                    23893       no  extended  bachelor
# 10687  west region                    11971       no   premium   college
# 10688      central                     6857       no     basic  bachelor
#
#       effective_to_date month employment_status gender  income  ...  \
# ...

# %%
# the database is clean and can be divided in two groups of variables: numerical variables (with integers) and categorical (objects)
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
# ...

# %%
#I create two new dataframes, one for each group of variables
numerical = mca.select_dtypes(include=np.number)
categorical = mca.select_dtypes(include=object)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12304\492430583.py in <module>
#       1 #I create two new dataframes, one for each group of variables
# ----> 2 numerical = mca.select_dtypes(include=np.number)
#       3 categorical = mca.select_dtypes(include=object)
#
# NameError: name 'mca' is not defined

# %%
numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_lifetime_value        10689 non-null  int64
#  1   income                         10689 non-null  int64
#  2   monthly_premium_auto           10689 non-null  int64
#  3   months_since_last_claim        10689 non-null  int64
#  4   months_since_policy_inception  10689 non-null  int64
#  5   number_of_open_complaints      10689 non-null  int64
#  6   number_of_policies             10689 non-null  int64
#  7   total_claim_amount             10689 non-null  int64
# dtypes: int64(8)
# memory usage: 668.2 KB

# %%
categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   region             10689 non-null  object
#  1   response           10689 non-null  object
#  2   coverage           10689 non-null  object
#  3   education          10689 non-null  object
#  4   effective_to_date  10689 non-null  object
#  5   month              10689 non-null  object
#  6   employment_status  10689 non-null  object
#  7   gender             10689 non-null  object
#  8   location_code      10689 non-null  object
#  9   marital_status     10689 non-null  object
#  10  policy_type        10689 non-null  object
#  11  policy             10689 non-null  object
#  12  renew_offer_type   10689 non-null  object
#  13  sales_channel      10689 non-null  object
#  14  vehicle_class      10689 non-null  object
#  15  vehicle_size       10689 non-null  object
# ...

# %%
#Before I start with the plots, I remove one column of the categorical dataframe
def drop_columns(categorical):
    categorical.drop(columns=["effective_to_date"], inplace=True)
    return categorical

# %%
drop_columns(categorical)
categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   region             10689 non-null  object
#  1   response           10689 non-null  object
#  2   coverage           10689 non-null  object
#  3   education          10689 non-null  object
#  4   month              10689 non-null  object
#  5   employment_status  10689 non-null  object
#  6   gender             10689 non-null  object
#  7   location_code      10689 non-null  object
#  8   marital_status     10689 non-null  object
#  9   policy_type        10689 non-null  object
#  10  policy             10689 non-null  object
#  11  renew_offer_type   10689 non-null  object
#  12  sales_channel      10689 non-null  object
#  13  vehicle_class      10689 non-null  object
#  14  vehicle_size       10689 non-null  object
# dtypes: object(15)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Now we will try to check the normality of the numerical variables visually:

# %% [markdown]
#  #### - Use seaborn library to construct distribution plots for the numerical variables

# %%
# Now, I use seaborn library to create histograms for the numerical variables using kde=True, that shapes the form of the distribution.
sns.displot(numerical['income'], kde=True)
sns.displot(numerical['customer_lifetime_value'], kde=True)
sns.displot(numerical['monthly_premium_auto'], kde=True)
sns.displot(numerical['monthly_premium_auto'], kde=True)
sns.displot(numerical['months_since_last_claim'], kde=True)
sns.displot(numerical['months_since_policy_inception'], kde=True)
sns.displot(numerical['number_of_open_complaints'], kde=True)
sns.displot(numerical['number_of_policies'], kde=True)
sns.displot(numerical['total_claim_amount'], kde=True)

# %% [markdown]
# ####  - Use Matplotlib to construct histograms.

# %%
#I do the same with the Matplot library. 
numerical.hist(figsize=(10,15))
# Out:
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #### - Do the distributions for different numerical variables look like a normal distribution?

# %%
# None of them look like a normal distribution, "months_since_policy_inception" is the graph that looks more as a normal distribution.

# %% [markdown]
# ### - For the numerical variables, check for correlation between the input features. Note: this does not include the target feature.

# %%
# With this function I can see the correlation between all variables, the most correlated variables are "customer_lifetime_value" and "monthly_premium_auto" with 0.4. 
numerical.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.003732
# income                                        0.003732  1.000000
# monthly_premium_auto                          0.404235 -0.002431
# months_since_last_claim                       0.011912 -0.026564
# months_since_policy_inception                 0.017055  0.003846
# number_of_open_complaints                    -0.032371  0.018903
# number_of_policies                            0.016789 -0.004461
# total_claim_amount                            0.232849 -0.111221
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.404235                 0.011912
# income                                    -0.002431                -0.026564
# monthly_premium_auto                       1.000000                 0.010036
# ...

# %% [markdown]
# #### - Plot the Correlation Heatmap.

# %%
sns.heatmap(numerical.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Activity 4, Thursday 19th of January

# %% [markdown]
# #### - Show a plot of the total number of responses.

# %%
responses = categorical['response'].value_counts()

# %%
#With this barplot I can see the count on the variable "responses" (yes or no) 
plt.bar(responses.index, responses, color=('red', 'green'))
plt.title('number of responses')
plt.xticks(ticks=[0,1], labels=["yes", "no"])
# Out:
# ([<matplotlib.axis.XTick at 0x19b8a7c5d00>,
# ...
#  [Text(0, 0, 'yes'), Text(1, 0, 'no')])

# %% [markdown]
# #### - Show a plot of the response by the sales channel.

# %%
categorical['sales_channel'].value_counts()
# Out:
# agent          4019
# branch         2975
# call center    2099
# web            1596
# Name: sales_channel, dtype: int64

# %%
#In order to count the number of responses for each sales channel I create a new dummy variable "sales_response" based on "response".
#Since it is going to create a new dataframe with two columns (one for yes and one for no) I drop one of it.
sales_response=pd.get_dummies(categorical['response'])
sales_response = sales_response.drop(columns=['no'])

# %%
sales_response
# Out:
#        yes
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
# ...    ...
# 10684    0
# 10685    0
# 10686    0
# 10687    0
# 10688    0
#
# [10689 rows x 1 columns]

# %%
categorical['sales_response'] = sales_response

# %%
response_sales_channels = categorical.groupby(['sales_channel', 'response'])['sales_response'].count().reset_index()## with reset_index we get it in form of a Dataframe
response_sales_channels
# Out:
#   sales_channel response  sales_response
# 0         agent       no            3340
# 1         agent      yes             679
# 2        branch       no            2665
# 3        branch      yes             310
# 4   call center       no            1890
# 5   call center      yes             209
# 6           web       no            1421
# 7           web      yes             175

# %%
#For this I use a barplot as well, now with more results, in the x I have 4 results and in the y the count of "response": "sales_response"
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
plt.title('Response by sales channel', size='25', fontweight='bold')

sns.set_palette('RdYlGn')
palette_sales = {"yes": "C5", "no": "C0"}


sns.barplot(x = response_sales_channels['sales_channel'],y = response_sales_channels['sales_response'], hue = response_sales_channels['response'], palette=palette_sales)
# Out:
# <AxesSubplot:title={'center':'Response by sales channel'}, xlabel='sales_channel', ylabel='sales_response'>

# %% [markdown]
# #### - Show a plot of the response by the total claim amount.

# %%
numerical['total_claim_amount'].value_counts()
# Out:
# 316     147
# 292     143
# 350     137
# 312     128
# 331     123
#        ...
# 816       1
# 1980      1
# 1543      1
# 1562      1
# 1621      1
# Name: total_claim_amount, Length: 1172, dtype: int64

# %%
#Since now one variable is categorical and the other numerical, I need to use another graph. So I take the histogram again,
#that shows me the frequency of "no" and "yes" for "total_claim_amount"
responses_total_claim_amount = sns.displot(x='total_claim_amount', hue = 'response', data=mca, kde=True)

# %% [markdown]
# #### - Show a plot of the response by income.

# %%
responses_income = sns.displot(x='income', hue = 'response', data=mca, kde=True)
