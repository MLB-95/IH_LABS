# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

RAND_STATE = 32 # for reproducible shuffling
TT_RATIO = 0.25 # test/train

from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
data_vienna = pd.read_csv('data_vienna.csv')

# %%
data_vienna.corr()
# Out:
#                             Unnamed: 0   realSum  person_capacity     multi  \
# Unnamed: 0                    1.000000  0.004748         0.030133 -0.030291
# realSum                       0.004748  1.000000         0.103715 -0.035699
# person_capacity               0.030133  0.103715         1.000000 -0.028392
# multi                        -0.030291 -0.035699        -0.028392  1.000000
# biz                           0.041480  0.048524         0.167593 -0.446372
# cleanliness_rating           -0.008596 -0.003742        -0.023295  0.069795
# guest_satisfaction_overall   -0.010920 -0.004864        -0.096461  0.065076
# bedrooms                      0.048634  0.080097         0.509397  0.004166
# dist                          0.034396 -0.082808        -0.008608 -0.007044
# metro_dist                   -0.080204 -0.041808        -0.017072  0.021472
# attr_index_norm               0.123269  0.070861        -0.009512  0.036090
# rest_index_norm               0.075822  0.070250        -0.005979  0.049105
# room_shared_True              0.051391 -0.016328        -0.011847  0.033207
# room_private_True             0.041660 -0.068082        -0.403857  0.067104
# host_is_superhost_True       -0.087588 -0.008543         0.022959  0.077645
# weekend_yes                   0.029840  0.002960         0.016241 -0.007579
#
#                                  biz  cleanliness_rating  \
# Unnamed: 0                  0.041480           -0.008596
# realSum                     0.048524           -0.003742
# person_capacity             0.167593           -0.023295
# multi                      -0.446372            0.069795
# biz                         1.000000           -0.109473
# cleanliness_rating         -0.109473            1.000000
# guest_satisfaction_overall -0.229411            0.626382
# bedrooms                   -0.046566           -0.000560
# dist                       -0.041000           -0.022186
# metro_dist                 -0.070167            0.010287
# attr_index_norm             0.007565            0.060638
# rest_index_norm             0.009899            0.052512
# room_shared_True           -0.003890           -0.091418
# room_private_True          -0.157412           -0.042104
# host_is_superhost_True     -0.054972            0.264734
# weekend_yes                 0.009116           -0.000601
#
#                             guest_satisfaction_overall  bedrooms      dist  \
# Unnamed: 0                                   -0.010920  0.048634  0.034396
# realSum                                      -0.004864  0.080097 -0.082808
# person_capacity                              -0.096461  0.509397 -0.008608
# multi                                         0.065076  0.004166 -0.007044
# biz                                          -0.229411 -0.046566 -0.041000
# cleanliness_rating                            0.626382 -0.000560 -0.022186
# guest_satisfaction_overall                    1.000000  0.023281  0.016205
# bedrooms                                      0.023281  1.000000  0.074492
# dist                                          0.016205  0.074492  1.000000
# metro_dist                                    0.033979  0.077689  0.576110
# attr_index_norm                               0.034095 -0.041841 -0.590241
# rest_index_norm                               0.024415 -0.018505 -0.567638
# room_shared_True                             -0.052344 -0.011447 -0.013974
# room_private_True                             0.035528 -0.083066  0.111983
# host_is_superhost_True                        0.273962 -0.004013 -0.044134
# weekend_yes                                  -0.009032  0.009269 -0.001167
#
#                             metro_dist  attr_index_norm  rest_index_norm  \
# Unnamed: 0                   -0.080204         0.123269         0.075822
# realSum                      -0.041808         0.070861         0.070250
# person_capacity              -0.017072        -0.009512        -0.005979
# multi                         0.021472         0.036090         0.049105
# biz                          -0.070167         0.007565         0.009899
# cleanliness_rating            0.010287         0.060638         0.052512
# guest_satisfaction_overall    0.033979         0.034095         0.024415
# bedrooms                      0.077689        -0.041841        -0.018505
# dist                          0.576110        -0.590241        -0.567638
# metro_dist                    1.000000        -0.299581        -0.268445
# attr_index_norm              -0.299581         1.000000         0.877996
# rest_index_norm              -0.268445         0.877996         1.000000
# room_shared_True             -0.040542         0.017570         0.007668
# room_private_True             0.022190        -0.067159        -0.067829
# host_is_superhost_True       -0.013703         0.054998         0.048343
# weekend_yes                  -0.018835        -0.008162        -0.000290
#
#                             room_shared_True  room_private_True  \
# Unnamed: 0                          0.051391           0.041660
# realSum                            -0.016328          -0.068082
# person_capacity                    -0.011847          -0.403857
# multi                               0.033207           0.067104
# biz                                -0.003890          -0.157412
# cleanliness_rating                 -0.091418          -0.042104
# guest_satisfaction_overall         -0.052344           0.035528
# bedrooms                           -0.011447          -0.083066
# dist                               -0.013974           0.111983
# metro_dist                         -0.040542           0.022190
# attr_index_norm                     0.017570          -0.067159
# rest_index_norm                     0.007668          -0.067829
# room_shared_True                    1.000000          -0.035679
# room_private_True                  -0.035679           1.000000
# host_is_superhost_True             -0.033128          -0.033241
# weekend_yes                         0.007265          -0.002290
#
#                             host_is_superhost_True  weekend_yes
# Unnamed: 0                               -0.087588     0.029840
# realSum                                  -0.008543     0.002960
# person_capacity                           0.022959     0.016241
# multi                                     0.077645    -0.007579
# biz                                      -0.054972     0.009116
# cleanliness_rating                        0.264734    -0.000601
# guest_satisfaction_overall                0.273962    -0.009032
# bedrooms                                 -0.004013     0.009269
# dist                                     -0.044134    -0.001167
# metro_dist                               -0.013703    -0.018835
# attr_index_norm                           0.054998    -0.008162
# rest_index_norm                           0.048343    -0.000290
# room_shared_True                         -0.033128     0.007265
# room_private_True                        -0.033241    -0.002290
# host_is_superhost_True                    1.000000    -0.020272
# weekend_yes                              -0.020272     1.000000

# %%
data_vienna = data_vienna.drop(['Unnamed: 0', 'multi', 'metro_dist', 'rest_index_norm', 'weekend_yes', 'host_is_superhost_True'], axis=1)

# %%
x = data_vienna.drop('realSum', axis=1)
y = data_vienna.realSum

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TT_RATIO, random_state=RAND_STATE)
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train.describe()
# Out:
#        person_capacity          biz  cleanliness_rating  \
# count      2652.000000  2652.000000         2652.000000
# mean          3.331825     0.340498            9.474359
# std           1.281266     0.473966            0.866245
# min           2.000000     0.000000            2.000000
# 25%           2.000000     0.000000            9.000000
# 50%           3.000000     0.000000           10.000000
# 75%           4.000000     1.000000           10.000000
# max           6.000000     1.000000           10.000000
#
#        guest_satisfaction_overall     bedrooms         dist  attr_index_norm  \
# count                 2652.000000  2652.000000  2652.000000      2652.000000
# mean                    93.734163     1.096531     3.150468         8.710955
# std                      7.212661     0.606543     1.942084         6.328160
# min                     20.000000     0.000000     0.040000         1.387764
# 25%                     91.000000     1.000000     1.900000         5.748129
# 50%                     96.000000     1.000000     2.760000         7.432795
# 75%                     99.000000     1.000000     3.960000         9.791896
# max                    100.000000     4.000000    13.340000       100.000000
#
#        room_shared_True  room_private_True
# count       2652.000000        2652.000000
# mean           0.004148           0.222851
# std            0.064282           0.416237
# min            0.000000           0.000000
# 25%            0.000000           0.000000
# 50%            0.000000           0.000000
# 75%            0.000000           0.000000
# max            1.000000           1.000000

# %%
x_train_const = sm.add_constant(x_train) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     22.30
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):           7.05e-37
# Time:                        17:07:09   Log-Likelihood:                -18493.
# No. Observations:                2652   AIC:                         3.701e+04
# Df Residuals:                    2642   BIC:                         3.706e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          6.8964     74.603      0.092      0.926    -139.389     153.182
# person_capacity               23.7589      5.202      4.567      0.000      13.559      33.959
# biz                           48.1880     11.208      4.299      0.000      26.210      70.166
# cleanliness_rating           -17.1622      7.569     -2.267      0.023     -32.004      -2.321
# guest_satisfaction_overall     3.0232      0.928      3.258      0.001       1.204       4.843
# bedrooms                      31.1495      9.961      3.127      0.002      11.618      50.681
# dist                         -10.2553      3.204     -3.201      0.001     -16.537      -3.973
# attr_index_norm                2.5711      0.977      2.630      0.009       0.654       4.488
# room_shared_True             -85.3848     78.840     -1.083      0.279    -239.979      69.209
# room_private_True            -53.8804     13.642     -3.950      0.000     -80.631     -27.130
# ==============================================================================
# Omnibus:                     8040.322   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        500348828.251
# Skew:                          43.746   Prob(JB):                         0.00
# Kurtosis:                    2129.121   Cond. No.                     1.54e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sts = StandardScaler()

x_train_standarized = sts.fit_transform(x_train)
x_test_standarized = sts.transform(x_test)

x_train_standarized = pd.DataFrame(x_train_standarized)

# %%
x_train_const = sm.add_constant(x_train_standarized.to_numpy()) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test_standarized) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     22.30
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):           7.05e-37
# Time:                        17:07:09   Log-Likelihood:                -18493.
# No. Observations:                2652   AIC:                         3.701e+04
# Df Residuals:                    2642   BIC:                         3.706e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        235.1238      5.026     46.780      0.000     225.268     244.979
# x1            30.4358      6.664      4.567      0.000      17.369      43.502
# x2            22.8352      5.311      4.299      0.000      12.420      33.250
# x3           -14.8639      6.555     -2.267      0.023     -27.718      -2.010
# x4            21.8012      6.692      3.258      0.001       8.679      34.923
# x5            18.8899      6.040      3.127      0.002       7.045      30.734
# x6           -19.9128      6.221     -3.201      0.001     -32.111      -7.715
# x7            16.2672      6.184      2.630      0.009       4.141      28.393
# x8            -5.4877      5.067     -1.083      0.279     -15.423       4.448
# x9           -22.4228      5.677     -3.950      0.000     -33.555     -11.290
# ==============================================================================
# Omnibus:                     8040.322   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        500348828.251
# Skew:                          43.746   Prob(JB):                         0.00
# Kurtosis:                    2129.121   Cond. No.                         2.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.coef_
model.intercept_
# Out:
# 6.896383958681298

# %%
model.score(x_train, y_train)
# Out:
# 0.07058911814529745

# %%
y_pred = pd.DataFrame(model.predict(x_test),columns = ['realSum'] )      # model prediction
y_pred_train =  pd.DataFrame(model.predict(x_train),columns = ['realSum'])

# %%
mse(y_test,y_pred)
# Out:
# 419912.7336630292

# %%
rmse = np.sqrt(mse(y_test,y_pred))
rmse
# Out:
# 648.0067389024817

# %%
##prediction on the train set
mse(y_train,y_pred_train)
# Out:
# 66743.00514565613

# %%
mae(y_test,y_pred)
# Out:
# 89.09313483472312

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# -0.00842670357999209

# %%
R2_test=model.score(x_test,y_test)
R2_train=model.score(x_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
Adj_R2
# Out:
# -0.01879909253110057

# %%
model_lasso=Lasso(alpha=0.05)

model_lasso.fit(x_train, y_train)
print(f"{model_lasso.__class__.__name__}: Train -> {model_lasso.score(x_train, y_train)}, Test -> {model_lasso.score(x_test, y_test)}")
# Out:
# Lasso: Train -> 0.07057971671568886, Test -> -0.008403104780906556

# %%
model_ridge=Ridge(alpha=1000)
model_ridge.fit(x_train, y_train)
print(f"{model_ridge.__class__.__name__}: Train -> {model_ridge.score(x_train, y_train)}, Test -> {model_ridge.score(x_test, y_test)}")
# Out:
# Ridge: Train -> 0.06302725964875089, Test -> -0.003063621100444003

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

print("X_train has %d rows and %d columns"  %(x_train.shape[0],x_train.shape[1]))
print("-----------------------------------")
print("The coefficient of determination for the test data is R2=%.2f"
      %(model.score(x_test, y_test)))
print("The coefficient of determination for the train data is R2=%.2f"
      %(model.score(x_train, y_train)))
# Out:
# X_train has 2652 rows and 9 columns
# -----------------------------------
# The coefficient of determination for the test data is R2=-0.46
# The coefficient of determination for the train data is R2=1.00

# %%
scores=cross_val_score(model, x_train, y_train, cv=5)
print("Cross validation scores: ", scores)
print("Score stats: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Cross validation scores:  [ 3.07220983e-01 -2.77875814e+01  2.87269796e-02 -3.59606102e+01
#   6.58806404e-01]
# Score stats: -12.55 accuracy with a standard deviation of 15.99

# %%
model1 = DecisionTreeRegressor()
model2 = LinearRegression()
model3 = KNeighborsRegressor()

model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, x_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': -12.60607248238603, 'Linear Regression': 0.2787198848497816, 'KNN': 0.08921759309335342}
