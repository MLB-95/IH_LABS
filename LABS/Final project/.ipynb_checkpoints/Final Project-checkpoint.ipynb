# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import and join all databases

# %%
amsterdam_weekend = pd.read_csv("Data/Amsterdam_Weekends.csv")

# %%
amsterdam_weekend['city'] = ('Amsterdam')

# %%
barcelona_weekend = pd.read_csv("Data/Barcelona_Weekends.csv")

# %%
barcelona_weekend['city'] = ('Barcelona')

# %%
athens_weekend = pd.read_csv("Data/Athens_Weekends.csv")

# %%
athens_weekend['city'] = ('Athens')

# %%
london_weekend = pd.read_csv("Data/London_Weekends.csv")

# %%
london_weekend['city'] = ('London')

# %%
berlin_weekend = pd.read_csv("Data/Berlin_Weekends.csv")

# %%
berlin_weekend['city'] = ('Berlin')

# %%
budapest_weekend = pd.read_csv("Data/Budapest_Weekends.csv")

# %%
budapest_weekend['city'] = ('Budapest')

# %%
lisbon_weekend = pd.read_csv("Data/Lisbon_Weekends.csv")

# %%
lisbon_weekend['city'] = ('Lisbon')

# %%
paris_weekend = pd.read_csv("Data/Paris_Weekends.csv")

# %%
paris_weekend['city'] = ('Paris')

# %%
rome_weekend = pd.read_csv("Data/Rome_Weekends.csv")

# %%
rome_weekend['city'] = ('Rome')

# %%
vienna_weekend = pd.read_csv("Data/Vienna_Weekends.csv")

# %%
vienna_weekend['city'] = ('Vienna')

# %%
weekend_data = pd.concat((amsterdam_weekend, berlin_weekend, barcelona_weekend, london_weekend, budapest_weekend, lisbon_weekend, paris_weekend, rome_weekend, vienna_weekend, athens_weekend))

# %%
weekend_data
# Out:
#       Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0              0   319.640053     Private room        False          True
# 1              1   347.995219     Private room        False          True
# 2              2   482.975183     Private room        False          True
# 3              3   485.552926     Private room        False          True
# 4              4  2771.541724  Entire home/apt        False         False
# ...          ...          ...              ...          ...           ...
# 2622        2622    74.051508  Entire home/apt        False         False
# 2623        2623   295.737351  Entire home/apt        False         False
# 2624        2624   169.193635  Entire home/apt        False         False
# 2625        2625   160.991728  Entire home/apt        False         False
# 2626        2626   192.393317  Entire home/apt        False         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0                 2.0              False      0    1                 9.0  ...
# 1                 2.0              False      0    1                 9.0  ...
# 2                 4.0              False      0    1                 9.0  ...
# 3                 2.0               True      0    0                10.0  ...
# 4                 4.0               True      0    0                10.0  ...
# ...               ...                ...    ...  ...                 ...  ...
# 2622              3.0               True      0    0                10.0  ...
# 2623              4.0               True      0    1                10.0  ...
# 2624              4.0               True      0    1                10.0  ...
# 2625              4.0               True      1    0                10.0  ...
# 2626              4.0              False      0    1                10.0  ...
#
#       bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# 0            1  4.763360    0.852117  110.906123         5.871971  136.982208
# 1            1  5.748310    3.651591   75.275937         3.985516   95.386468
# 2            2  0.384872    0.439852  493.272517        26.116521  875.114817
# 3            1  0.544723    0.318688  552.849514        29.270850  815.303994
# 4            3  1.686798    1.458399  208.809162        11.055489  272.315202
# ...        ...       ...         ...         ...              ...         ...
# 2622         1  3.311976    1.856865   49.097725         1.849891   71.119758
# 2623         1  1.800556    0.571033  146.240703         5.510019  203.884287
# 2624         2  3.845100    0.786416   42.260382         1.592276   60.948754
# 2625         1  4.827460    0.141952   35.700540         1.345116   52.659912
# 2626         1  1.776319    0.317120  107.126909         4.036300  149.191222
#
#       rest_index_norm       lng       lat       city
# 0           11.941560   4.84639  52.34137  Amsterdam
# 1            8.315410   4.97512  52.36103  Amsterdam
# 2           76.289005   4.89417  52.37663  Amsterdam
# 3           71.074937   4.90051  52.37508  Amsterdam
# 4           23.739349   4.88467  52.38749  Amsterdam
# ...               ...       ...       ...        ...
# 2622         1.062098  23.75000  38.00306     Athens
# 2623         3.044796  23.71500  37.97400     Athens
# 2624         0.910205  23.76657  37.99986     Athens
# 2625         0.786420  23.73300  38.01900     Athens
# 2626         2.228013  23.72863  37.99064     Athens
#
# [26207 rows x 21 columns]

# %%
weekend_data['weekend'] = ('yes')

# %%
weekend_data['weekend'].value_counts()
# Out:
# yes    26207
# Name: weekend, dtype: int64

# %%
weekday_rome = pd.read_csv('Data/Rome_Weekdays.csv')
weekday_rome['city'] = ('Rome')
weekday_berlin = pd.read_csv('Data/Berlin_Weekdays.csv')
weekday_berlin['city'] = ('Berlin')
weekday_london = pd.read_csv('Data/London_Weekdays.csv')
weekday_london['city'] = ('London')
weekday_lisbon = pd.read_csv("Data/Lisbon_Weekdays.csv")
weekday_lisbon['city'] = ('Lisbon')
weekday_amsterdam = pd.read_csv('Data/Amsterdam_Weekdays.csv')
weekday_amsterdam['city'] = ('Amsterdam')
weekday_barcelona = pd.read_csv('Data/Barcelona_Weekdays.csv')
weekday_barcelona['city'] = ('Barcelona')
weekday_budapest = pd.read_csv('Data/Budapest_Weekdays.csv')
weekday_budapest['city'] = ('Budapest')
weekday_athens = pd.read_csv('Data/Athens_Weekdays.csv')
weekday_athens['city'] = ('Athens')
weekday_vienna = pd.read_csv('Data/Vienna_Weekdays.csv')
weekday_vienna['city'] = ('Vienna')
weekday_paris = pd.read_csv('Data/Paris_Weekdays.csv')
weekday_paris['city'] = ('Paris')

# %%
weekdays = pd.concat([weekday_rome, weekday_berlin, weekday_london, weekday_lisbon, weekday_amsterdam, weekday_barcelona, weekday_budapest, weekday_athens, weekday_vienna, weekday_paris])

# %%
weekdays['weekend'] = ('no')

# %%
weekdays
# Out:
#       Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0              0  156.874664     Private room        False          True
# 1              1  172.772543     Private room        False          True
# 2              2  277.745307  Entire home/apt        False         False
# 3              3  444.906834  Entire home/apt        False         False
# 4              4  131.391298     Private room        False          True
# ...          ...         ...              ...          ...           ...
# 3125        3125  231.615248  Entire home/apt        False         False
# 3126        3126  223.692795  Entire home/apt        False         False
# 3127        3127  567.853481  Entire home/apt        False         False
# 3128        3128  200.391462  Entire home/apt        False         False
# 3129        3129  301.286234  Entire home/apt        False         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0                 2.0               True      1    0                10.0  ...
# 1                 2.0              False      1    0                 9.0  ...
# 2                 4.0              False      0    1                 9.0  ...
# 3                 6.0              False      1    0                 9.0  ...
# 4                 3.0              False      1    0                 9.0  ...
# ...               ...                ...    ...  ...                 ...  ...
# 3125              4.0              False      0    0                10.0  ...
# 3126              2.0              False      1    0                 9.0  ...
# 3127              6.0               True      0    0                10.0  ...
# 3128              2.0               True      0    0                 9.0  ...
# 3129              2.0              False      0    0                10.0  ...
#
#           dist  metro_dist  attr_index  attr_index_norm   rest_index  \
# 0     2.978468    1.595733  281.163932         6.230648   697.727246
# 1     0.935371    0.649269  482.707193        10.696887  1251.524333
# 2     2.203025    0.494697  691.708998        15.328408  1625.897266
# 3     2.703010    1.295153  805.592641        17.852092  2035.819533
# 4     1.295968    0.867455  317.076369         7.026475   836.622814
# ...        ...         ...         ...              ...          ...
# 3125  3.558773    0.154750  185.488125         9.029499   474.358260
# 3126  4.205210    0.253034  172.658783         8.404971   406.585538
# 3127  4.312136    0.304642  178.222781         8.675825   420.726229
# 3128  2.891206    0.240686  235.168523        11.447924   602.451547
# 3129  3.469721    0.508493  200.639467         9.767062   478.992836
#
#       rest_index_norm       lng       lat   city  weekend
# 0           15.191486  12.48654  41.92498   Rome       no
# 1           27.249208  12.49627  41.90801   Rome       no
# 2           35.400361  12.47700  41.90700   Rome       no
# 3           44.325522  12.46969  41.90019   Rome       no
# 4           18.215634  12.51544  41.89463   Rome       no
# ...               ...       ...       ...    ...      ...
# 3125        27.873072   2.40050  48.85093  Paris       no
# 3126        23.890778   2.40100  48.87700  Paris       no
# 3127        24.721678   2.39334  48.88463  Paris       no
# 3128        35.399774   2.38200  48.87400  Paris       no
# 3129        28.145397   2.39992  48.85886  Paris       no
#
# [25500 rows x 22 columns]

# %%
data = pd.concat((weekdays, weekend_data))

# %% [markdown]
# ### Drop irrelevant features and transform the boolean data types into dummy variables

# %%
data.drop_duplicates(inplace=True)

# %%
data.corr()
# Out:
#                             Unnamed: 0   realSum  room_shared  room_private  \
# Unnamed: 0                    1.000000  0.010863    -0.003336      0.039880
# realSum                       0.010863  1.000000    -0.035095     -0.171949
# room_shared                  -0.003336 -0.035095     1.000000     -0.063533
# room_private                  0.039880 -0.171949    -0.063533      1.000000
# person_capacity              -0.001816  0.203077     0.035146     -0.499993
# host_is_superhost            -0.059890 -0.045478    -0.027839     -0.049501
# multi                        -0.001999 -0.052926    -0.016061      0.137026
# biz                           0.018735  0.037144     0.044406     -0.040198
# cleanliness_rating           -0.049342 -0.006082    -0.040097     -0.030983
# guest_satisfaction_overall   -0.062290 -0.001888    -0.027876     -0.033401
# bedrooms                      0.019509  0.221653    -0.021365     -0.155889
# dist                          0.186218 -0.044725     0.014144      0.213351
# metro_dist                    0.024200 -0.061025    -0.002868      0.101981
# attr_index                    0.084314  0.178228    -0.031458     -0.022286
# attr_index_norm               0.035687  0.292396    -0.006137      0.029140
# rest_index                    0.158729  0.134722    -0.031297     -0.022343
# rest_index_norm              -0.141629  0.144094     0.005711     -0.136846
# lng                          -0.156467 -0.173833    -0.027829     -0.201709
# lat                           0.056303  0.211805     0.023304      0.140762
#
#                             person_capacity  host_is_superhost     multi  \
# Unnamed: 0                        -0.001816          -0.059890 -0.001999
# realSum                            0.203077          -0.045478 -0.052926
# room_shared                        0.035146          -0.027839 -0.016061
# room_private                      -0.499993          -0.049501  0.137026
# person_capacity                    1.000000           0.031431 -0.054326
# host_is_superhost                  0.031431           1.000000  0.097520
# multi                             -0.054326           0.097520  1.000000
# biz                                0.110668          -0.108506 -0.470725
# cleanliness_rating                 0.003256           0.272376  0.041064
# guest_satisfaction_overall         0.005181           0.280062  0.054254
# bedrooms                           0.560627           0.024250 -0.000659
# dist                              -0.128488          -0.056113  0.033426
# metro_dist                        -0.037267          -0.000722  0.043365
# attr_index                         0.028394          -0.026335  0.006319
# attr_index_norm                   -0.050487          -0.088949 -0.041412
# rest_index                         0.037330          -0.035060  0.007051
# rest_index_norm                    0.038059          -0.018348 -0.037402
# lng                                0.146848           0.185748  0.041260
# lat                               -0.168265          -0.113811 -0.034058
#
#                                  biz  cleanliness_rating  \
# Unnamed: 0                  0.018735           -0.049342
# realSum                     0.037144           -0.006082
# room_shared                 0.044406           -0.040097
# room_private               -0.040198           -0.030983
# person_capacity             0.110668            0.003256
# host_is_superhost          -0.108506            0.272376
# multi                      -0.470725            0.041064
# biz                         1.000000           -0.107310
# cleanliness_rating         -0.107310            1.000000
# guest_satisfaction_overall -0.208160            0.714045
# bedrooms                   -0.026741            0.033489
# dist                       -0.164767           -0.030202
# metro_dist                 -0.109153            0.010441
# attr_index                  0.114732           -0.025322
# attr_index_norm             0.093720           -0.075372
# rest_index                  0.137747           -0.031929
# rest_index_norm             0.083999           -0.005995
# lng                        -0.088943            0.120379
# lat                        -0.126433           -0.092502
#
#                             guest_satisfaction_overall  bedrooms      dist  \
# Unnamed: 0                                   -0.062290  0.019509  0.186218
# realSum                                      -0.001888  0.221653 -0.044725
# room_shared                                  -0.027876 -0.021365  0.014144
# room_private                                 -0.033401 -0.155889  0.213351
# person_capacity                               0.005181  0.560627 -0.128488
# host_is_superhost                             0.280062  0.024250 -0.056113
# multi                                         0.054254 -0.000659  0.033426
# biz                                          -0.208160 -0.026741 -0.164767
# cleanliness_rating                            0.714045  0.033489 -0.030202
# guest_satisfaction_overall                    1.000000  0.047573 -0.004178
# bedrooms                                      0.047573  1.000000 -0.006262
# dist                                         -0.004178 -0.006262  1.000000
# metro_dist                                    0.029788  0.044431  0.558064
# attr_index                                   -0.050624 -0.011735 -0.363088
# attr_index_norm                              -0.074146 -0.063773 -0.242862
# rest_index                                   -0.069319 -0.014047 -0.346653
# rest_index_norm                              -0.008765 -0.057726 -0.467791
# lng                                           0.156079  0.013688 -0.147424
# lat                                          -0.033957 -0.104694  0.405878
#
#                             metro_dist  attr_index  attr_index_norm  \
# Unnamed: 0                    0.024200    0.084314         0.035687
# realSum                      -0.061025    0.178228         0.292396
# room_shared                  -0.002868   -0.031458        -0.006137
# room_private                  0.101981   -0.022286         0.029140
# person_capacity              -0.037267    0.028394        -0.050487
# host_is_superhost            -0.000722   -0.026335        -0.088949
# multi                         0.043365    0.006319        -0.041412
# biz                          -0.109153    0.114732         0.093720
# cleanliness_rating            0.010441   -0.025322        -0.075372
# guest_satisfaction_overall    0.029788   -0.050624        -0.074146
# bedrooms                      0.044431   -0.011735        -0.063773
# dist                          0.558064   -0.363088        -0.242862
# metro_dist                    1.000000   -0.168010        -0.219587
# attr_index                   -0.168010    1.000000         0.714847
# attr_index_norm              -0.219587    0.714847         1.000000
# rest_index                   -0.138876    0.850229         0.527623
# rest_index_norm              -0.259654    0.544403         0.472143
# lng                          -0.069506   -0.126942        -0.221591
# lat                           0.086424   -0.052438         0.435237
#
#                             rest_index  rest_index_norm       lng       lat
# Unnamed: 0                    0.158729        -0.141629 -0.156467  0.056303
# realSum                       0.134722         0.144094 -0.173833  0.211805
# room_shared                  -0.031297         0.005711 -0.027829  0.023304
# room_private                 -0.022343        -0.136846 -0.201709  0.140762
# person_capacity               0.037330         0.038059  0.146848 -0.168265
# host_is_superhost            -0.035060        -0.018348  0.185748 -0.113811
# multi                         0.007051        -0.037402  0.041260 -0.034058
# biz                           0.137747         0.083999 -0.088943 -0.126433
# cleanliness_rating           -0.031929        -0.005995  0.120379 -0.092502
# guest_satisfaction_overall   -0.069319        -0.008765  0.156079 -0.033957
# bedrooms                     -0.014047        -0.057726  0.013688 -0.104694
# dist                         -0.346653        -0.467791 -0.147424  0.405878
# metro_dist                   -0.138876        -0.259654 -0.069506  0.086424
# attr_index                    0.850229         0.544403 -0.126942 -0.052438
# attr_index_norm               0.527623         0.472143 -0.221591  0.435237
# rest_index                    1.000000         0.617970 -0.176704 -0.113163
# rest_index_norm               0.617970         1.000000 -0.134731  0.023698
# lng                          -0.176704        -0.134731  1.000000 -0.159214
# lat                          -0.113163         0.023698 -0.159214  1.000000

# %%
data_clean = data.drop(['Unnamed: 0', 'room_type', 'attr_index', 'rest_index'], axis=1)

# %%
data_clean
# Out:
#          realSum  room_shared  room_private  person_capacity  \
# 0     156.874664        False          True              2.0
# 1     172.772543        False          True              2.0
# 2     277.745307        False         False              4.0
# 3     444.906834        False         False              6.0
# 4     131.391298        False          True              3.0
# ...          ...          ...           ...              ...
# 2622   74.051508        False         False              3.0
# 2623  295.737351        False         False              4.0
# 2624  169.193635        False         False              4.0
# 2625  160.991728        False         False              4.0
# 2626  192.393317        False         False              4.0
#
#       host_is_superhost  multi  biz  cleanliness_rating  \
# 0                  True      1    0                10.0
# 1                 False      1    0                 9.0
# 2                 False      0    1                 9.0
# 3                 False      1    0                 9.0
# 4                 False      1    0                 9.0
# ...                 ...    ...  ...                 ...
# 2622               True      0    0                10.0
# 2623               True      0    1                10.0
# 2624               True      0    1                10.0
# 2625               True      1    0                10.0
# 2626              False      0    1                10.0
#
#       guest_satisfaction_overall  bedrooms      dist  metro_dist  \
# 0                           95.0         1  2.978468    1.595733
# 1                           80.0         1  0.935371    0.649269
# 2                           90.0         1  2.203025    0.494697
# 3                           92.0         2  2.703010    1.295153
# 4                           91.0         1  1.295968    0.867455
# ...                          ...       ...       ...         ...
# 2622                        98.0         1  3.311976    1.856865
# 2623                       100.0         1  1.800556    0.571033
# 2624                        99.0         2  3.845100    0.786416
# 2625                       100.0         1  4.827460    0.141952
# 2626                        99.0         1  1.776319    0.317120
#
#       attr_index_norm  rest_index_norm       lng       lat    city weekend
# 0            6.230648        15.191486  12.48654  41.92498    Rome      no
# 1           10.696887        27.249208  12.49627  41.90801    Rome      no
# 2           15.328408        35.400361  12.47700  41.90700    Rome      no
# 3           17.852092        44.325522  12.46969  41.90019    Rome      no
# 4            7.026475        18.215634  12.51544  41.89463    Rome      no
# ...               ...              ...       ...       ...     ...     ...
# 2622         1.849891         1.062098  23.75000  38.00306  Athens     yes
# 2623         5.510019         3.044796  23.71500  37.97400  Athens     yes
# 2624         1.592276         0.910205  23.76657  37.99986  Athens     yes
# 2625         1.345116         0.786420  23.73300  38.01900  Athens     yes
# 2626         4.036300         2.228013  23.72863  37.99064  Athens     yes
#
# [51707 rows x 18 columns]

# %%
data_clean['bedrooms'].value_counts()
# Out:
# 1     36333
# 2      9290
# 0      4485
# 3      1477
# 4        96
# 9        10
# 5        10
# 8         2
# 10        2
# 6         2
# Name: bedrooms, dtype: int64

# %%
data_clean = pd.get_dummies(data_clean, columns = ['room_shared', 'room_private', 'host_is_superhost', 'weekend'], drop_first =True)
data_clean
# Out:
#          realSum  person_capacity  multi  biz  cleanliness_rating  \
# 0     156.874664              2.0      1    0                10.0
# 1     172.772543              2.0      1    0                 9.0
# 2     277.745307              4.0      0    1                 9.0
# 3     444.906834              6.0      1    0                 9.0
# 4     131.391298              3.0      1    0                 9.0
# ...          ...              ...    ...  ...                 ...
# 2622   74.051508              3.0      0    0                10.0
# 2623  295.737351              4.0      0    1                10.0
# 2624  169.193635              4.0      0    1                10.0
# 2625  160.991728              4.0      1    0                10.0
# 2626  192.393317              4.0      0    1                10.0
#
#       guest_satisfaction_overall  bedrooms      dist  metro_dist  \
# 0                           95.0         1  2.978468    1.595733
# 1                           80.0         1  0.935371    0.649269
# 2                           90.0         1  2.203025    0.494697
# 3                           92.0         2  2.703010    1.295153
# 4                           91.0         1  1.295968    0.867455
# ...                          ...       ...       ...         ...
# 2622                        98.0         1  3.311976    1.856865
# 2623                       100.0         1  1.800556    0.571033
# 2624                        99.0         2  3.845100    0.786416
# 2625                       100.0         1  4.827460    0.141952
# 2626                        99.0         1  1.776319    0.317120
#
#       attr_index_norm  rest_index_norm       lng       lat    city  \
# 0            6.230648        15.191486  12.48654  41.92498    Rome
# 1           10.696887        27.249208  12.49627  41.90801    Rome
# 2           15.328408        35.400361  12.47700  41.90700    Rome
# 3           17.852092        44.325522  12.46969  41.90019    Rome
# 4            7.026475        18.215634  12.51544  41.89463    Rome
# ...               ...              ...       ...       ...     ...
# 2622         1.849891         1.062098  23.75000  38.00306  Athens
# 2623         5.510019         3.044796  23.71500  37.97400  Athens
# 2624         1.592276         0.910205  23.76657  37.99986  Athens
# 2625         1.345116         0.786420  23.73300  38.01900  Athens
# 2626         4.036300         2.228013  23.72863  37.99064  Athens
#
#       room_shared_True  room_private_True  host_is_superhost_True  weekend_yes
# 0                    0                  1                       1            0
# 1                    0                  1                       0            0
# 2                    0                  0                       0            0
# 3                    0                  0                       0            0
# 4                    0                  1                       0            0
# ...                ...                ...                     ...          ...
# 2622                 0                  0                       1            1
# 2623                 0                  0                       1            1
# 2624                 0                  0                       1            1
# 2625                 0                  0                       1            1
# 2626                 0                  0                       0            1
#
# [51707 rows x 18 columns]

# %%
data_clean[['cleanliness_rating']] = data[['cleanliness_rating']].astype(int)

# %%
data_clean[['realSum', 'dist', 'metro_dist']]=data_clean[['realSum', 'dist', 'metro_dist']].round(2)

# %%
data_clean['realSum'].describe()
# Out:
# count    51707.000000
# mean       279.879630
# std        327.948372
# min         34.780000
# 25%        148.750000
# 50%        211.340000
# 75%        319.690000
# max      18545.450000
# Name: realSum, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %%
RAND_STATE = 32 # for reproducible shuffling
TT_RATIO = 0.25 # test/train

# %%
data_clean.isna().any()
# Out:
# realSum                       False
# person_capacity               False
# multi                         False
# biz                           False
# cleanliness_rating            False
# guest_satisfaction_overall    False
# bedrooms                      False
# dist                          False
# metro_dist                    False
# attr_index_norm               False
# rest_index_norm               False
# lng                           False
# lat                           False
# city                          False
# room_shared_True              False
# room_private_True             False
# host_is_superhost_True        False
# weekend_yes                   False
# dtype: bool

# %%
data_clean_numerical = data_clean.drop(['city'], axis=1)

# %%
data_clean_numerical
# Out:
#       realSum  person_capacity  multi  biz  cleanliness_rating  \
# 0      156.87              2.0      1    0                  10
# 1      172.77              2.0      1    0                   9
# 2      277.75              4.0      0    1                   9
# 3      444.91              6.0      1    0                   9
# 4      131.39              3.0      1    0                   9
# ...       ...              ...    ...  ...                 ...
# 2622    74.05              3.0      0    0                  10
# 2623   295.74              4.0      0    1                  10
# 2624   169.19              4.0      0    1                  10
# 2625   160.99              4.0      1    0                  10
# 2626   192.39              4.0      0    1                  10
#
#       guest_satisfaction_overall  bedrooms  dist  metro_dist  attr_index_norm  \
# 0                           95.0         1  2.98        1.60         6.230648
# 1                           80.0         1  0.94        0.65        10.696887
# 2                           90.0         1  2.20        0.49        15.328408
# 3                           92.0         2  2.70        1.30        17.852092
# 4                           91.0         1  1.30        0.87         7.026475
# ...                          ...       ...   ...         ...              ...
# 2622                        98.0         1  3.31        1.86         1.849891
# 2623                       100.0         1  1.80        0.57         5.510019
# 2624                        99.0         2  3.85        0.79         1.592276
# 2625                       100.0         1  4.83        0.14         1.345116
# 2626                        99.0         1  1.78        0.32         4.036300
#
#       rest_index_norm       lng       lat  room_shared_True  \
# 0           15.191486  12.48654  41.92498                 0
# 1           27.249208  12.49627  41.90801                 0
# 2           35.400361  12.47700  41.90700                 0
# 3           44.325522  12.46969  41.90019                 0
# 4           18.215634  12.51544  41.89463                 0
# ...               ...       ...       ...               ...
# 2622         1.062098  23.75000  38.00306                 0
# 2623         3.044796  23.71500  37.97400                 0
# 2624         0.910205  23.76657  37.99986                 0
# 2625         0.786420  23.73300  38.01900                 0
# 2626         2.228013  23.72863  37.99064                 0
#
#       room_private_True  host_is_superhost_True  weekend_yes
# 0                     1                       1            0
# 1                     1                       0            0
# 2                     0                       0            0
# 3                     0                       0            0
# 4                     1                       0            0
# ...                 ...                     ...          ...
# 2622                  0                       1            1
# 2623                  0                       1            1
# 2624                  0                       1            1
# 2625                  0                       1            1
# 2626                  0                       0            1
#
# [51707 rows x 17 columns]

# %% [markdown]
# #### X-Y split

# %%
x = data_clean_numerical.drop('realSum', axis=1)
y = data_clean_numerical.realSum

# %% [markdown]
# #### Train - Test split

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TT_RATIO, random_state=RAND_STATE)
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train.describe()
# Out:
#        person_capacity         multi           biz  cleanliness_rating  \
# count     38780.000000  38780.000000  38780.000000        38780.000000
# mean          3.166039      0.292135      0.348659            9.392316
# std           1.300033      0.454750      0.476552            0.955026
# min           2.000000      0.000000      0.000000            2.000000
# 25%           2.000000      0.000000      0.000000            9.000000
# 50%           3.000000      0.000000      0.000000           10.000000
# 75%           4.000000      1.000000      1.000000           10.000000
# max           6.000000      1.000000      1.000000           10.000000
#
#        guest_satisfaction_overall      bedrooms          dist    metro_dist  \
# count                38780.000000  38780.000000  38780.000000  38780.000000
# mean                    92.661578      1.159025      3.197077      0.680839
# std                      8.905833      0.629445      2.403874      0.857698
# min                     20.000000      0.000000      0.020000      0.000000
# 25%                     90.000000      1.000000      1.460000      0.250000
# 50%                     95.000000      1.000000      2.610000      0.410000
# 75%                     99.000000      1.000000      4.270000      0.740000
# max                    100.000000     10.000000     25.280000     14.270000
#
#        attr_index_norm  rest_index_norm           lng           lat  \
# count     38780.000000     38780.000000  38780.000000  38780.000000
# mean         13.423504        22.735122      7.421775     45.673611
# std           9.807319        17.799960      9.805092      5.249982
# min           0.926301         0.592757     -9.226340     37.953000
# 25%           6.376706         8.727279     -0.073600     41.399907
# 50%          11.460722        17.438471      4.872540     47.507090
# 75%          17.423782        32.882718     13.552290     51.472120
# max         100.000000       100.000000     23.786020     52.641410
#
#        room_shared_True  room_private_True  host_is_superhost_True  \
# count      38780.000000       38780.000000            38780.000000
# mean           0.007220           0.359232                0.257143
# std            0.084666           0.479781                0.437064
# min            0.000000           0.000000                0.000000
# 25%            0.000000           0.000000                0.000000
# 50%            0.000000           0.000000                0.000000
# 75%            0.000000           1.000000                1.000000
# max            1.000000           1.000000                1.000000
#
#         weekend_yes
# count  38780.000000
# mean       0.508020
# std        0.499942
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# #### Standarize the data

# %%
sts = StandardScaler()

x_train_standarized = sts.fit_transform(x_train)
x_test_standarized = sts.transform(x_test)

x_train_standarized = pd.DataFrame(x_train_standarized)

# %% [markdown]
# #### Apply linear regression.

# %%
x_train_const = sm.add_constant(x_train) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.191
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     573.2
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:16:52   Log-Likelihood:            -2.7721e+05
# No. Observations:               38780   AIC:                         5.544e+05
# Df Residuals:                   38763   BIC:                         5.546e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       -541.4988     26.258    -20.622      0.000    -592.965    -490.033
# person_capacity               19.2105      1.713     11.217      0.000      15.854      22.567
# multi                          0.7286      3.995      0.182      0.855      -7.103       8.560
# biz                           12.8852      3.987      3.231      0.001       5.070      20.701
# cleanliness_rating             5.8686      2.370      2.476      0.013       1.223      10.514
# guest_satisfaction_overall     0.8287      0.259      3.198      0.001       0.321       1.337
# bedrooms                      96.5897      3.088     31.276      0.000      90.537     102.643
# dist                          -6.8016      1.056     -6.440      0.000      -8.872      -4.731
# metro_dist                    -4.8797      2.244     -2.175      0.030      -9.278      -0.482
# attr_index_norm                6.0097      0.225     26.669      0.000       5.568       6.451
# rest_index_norm               -0.2183      0.112     -1.947      0.052      -0.438       0.001
# lng                           -5.4468      0.177    -30.821      0.000      -5.793      -5.100
# lat                           11.9093      0.424     28.110      0.000      11.079      12.740
# room_shared_True            -200.3877     18.588    -10.780      0.000    -236.821    -163.954
# room_private_True           -109.1941      3.983    -27.416      0.000    -117.001    -101.387
# host_is_superhost_True        -4.8230      3.819     -1.263      0.207     -12.309       2.663
# weekend_yes                    2.8972      3.134      0.924      0.355      -3.246       9.040
# ==============================================================================
# Omnibus:                    98755.731   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2460065507.969
# Skew:                          28.614   Prob(JB):                         0.00
# Kurtosis:                    1235.558   Cond. No.                     1.81e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x_train_const = sm.add_constant(x_train_standarized.to_numpy()) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test_standarized) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.191
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     573.2
# Date:                Tue, 07 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:16:52   Log-Likelihood:            -2.7721e+05
# No. Observations:               38780   AIC:                         5.544e+05
# Df Residuals:                   38763   BIC:                         5.546e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        281.6014      1.563    180.156      0.000     278.538     284.665
# x1            24.9739      2.226     11.217      0.000      20.610      29.338
# x2             0.3313      1.817      0.182      0.855      -3.230       3.893
# x3             6.1404      1.900      3.231      0.001       2.416       9.865
# x4             5.6046      2.264      2.476      0.013       1.168      10.041
# x5             7.3803      2.308      3.198      0.001       2.857      11.904
# x6            60.7972      1.944     31.276      0.000      56.987      64.607
# x7           -16.3499      2.539     -6.440      0.000     -21.326     -11.374
# x8            -4.1853      1.925     -2.175      0.030      -7.958      -0.413
# x9            58.9378      2.210     26.669      0.000      54.606      63.269
# x10           -3.8858      1.996     -1.947      0.052      -7.798       0.026
# x11          -53.4060      1.733    -30.821      0.000     -56.802     -50.010
# x12           62.5227      2.224     28.110      0.000      58.163      66.882
# x13          -16.9657      1.574    -10.780      0.000     -20.050     -13.881
# x14          -52.3886      1.911    -27.416      0.000     -56.134     -48.643
# x15           -2.1079      1.669     -1.263      0.207      -5.380       1.164
# x16            1.4484      1.567      0.924      0.355      -1.623       4.519
# ==============================================================================
# Omnibus:                    98755.731   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2460065507.969
# Skew:                          28.614   Prob(JB):                         0.00
# Kurtosis:                    1235.558   Cond. No.                         3.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Linear Regression

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.coef_
model.intercept_
# Out:
# -541.4988071548489

# %%
model.score(x_train, y_train)
# Out:
# 0.1913287551344709

# %%
y_pred = pd.DataFrame(model.predict(x_test),columns = ['realSum'] )      # model prediction
y_pred_train =  pd.DataFrame(model.predict(x_train),columns = ['realSum'])

# %%
mse(y_test,y_pred)
# Out:
# 55617.84232588235

# %%
rmse = np.sqrt(mse(y_test,y_pred))
rmse
# Out:
# 235.83435357445774

# %%
##prediction on the train set
mse(y_train,y_pred_train)
# Out:
# 94708.30541727928

# %%
mae(y_test,y_pred)
# Out:
# 104.82669207459912

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.2942750980600377

# %%
R2_test=model.score(x_test,y_test)
R2_train=model.score(x_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
Adj_R2
# Out:
# 0.29340045836747075

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression
model_lasso=Lasso(alpha=0.05)

model_lasso.fit(x_train, y_train)
print(f"{model_lasso.__class__.__name__}: Train -> {model_lasso.score(x_train, y_train)}, Test -> {model_lasso.score(x_test, y_test)}")
# Out:
# Lasso: Train -> 0.19132462729945088, Test -> 0.2942672409408781

# %%
model_ridge=Ridge(alpha=1000)
model_ridge.fit(x_train, y_train)
print(f"{model_ridge.__class__.__name__}: Train -> {model_ridge.score(x_train, y_train)}, Test -> {model_ridge.score(x_test, y_test)}")
# Out:
# Ridge: Train -> 0.18933024666983223, Test -> 0.2916634901468842

# %% [markdown]
# #### KNN model

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

print("X_train has %d rows and %d columns"  %(x_train.shape[0],x_train.shape[1]))
print("-----------------------------------")
print("The coefficient of determination for the test data is R2=%.2f"
      %(model.score(x_test, y_test)))
print("The coefficient of determination for the train data is R2=%.2f"
      %(model.score(x_train, y_train)))
# Out:
# X_train has 38780 rows and 16 columns
# -----------------------------------
# The coefficient of determination for the test data is R2=-0.21
# The coefficient of determination for the train data is R2=1.00

# %%
scores=cross_val_score(model, x_train, y_train, cv=5)
print("Cross validation scores: ", scores)
print("Score stats: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Cross validation scores:  [ 0.38839243  0.67067829 -0.33237121  0.2306118  -0.48248241]
# Score stats: 0.09 accuracy with a standard deviation of 0.44

# %%
model1 = DecisionTreeRegressor()
model2 = LinearRegression()
model3 = KNeighborsRegressor()

model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, x_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.00893058004643681, 'Linear Regression': 0.20166995367870397, 'KNN': 0.22840010713024586}

# %% [markdown]
# #### split cities

# %%
def split_cities(cities):
    data_cities = data_clean[data_clean['city'] == cities]
    data_cities = data_cities.drop(['city'], axis=1)
    return data_cities

# %%
data_berlin = split_cities('Berlin')
data_berlin.columns
# Out:
# Index(['realSum', 'person_capacity', 'multi', 'biz', 'cleanliness_rating',
#        'guest_satisfaction_overall', 'bedrooms', 'dist', 'metro_dist',
#        'attr_index_norm', 'rest_index_norm', 'lng', 'lat', 'room_shared_True',
#        'room_private_True', 'host_is_superhost_True', 'weekend_yes'],
#       dtype='object')

# %%
data_berlin.to_csv("data_berlin.csv")

# %%
data_amsterdam = split_cities('Amsterdam')

# %%
data_amsterdam.to_csv('data_amsterdam.csv')

# %%
data_paris = split_cities('Paris')

# %%
data_paris.to_csv('data_paris.csv')

# %%
data_rome = split_cities('Rome')

# %%
data_rome.to_csv('data_rome.csv')

# %%
data_lisbon = split_cities('Lisbon')

# %%
data_lisbon.to_csv('data_lisbon.csv')

# %%
data_london = split_cities('London')
data_london.to_csv('data_london.csv')

# %%
data_barcelona = split_cities('Barcelona')
data_barcelona.to_csv('data_barcelona.csv')

# %%
data_athens = split_cities('Athens')
data_athens.to_csv('data_athens.csv')

# %%
data_budapest = split_cities('Budapest')
data_budapest.to_csv('data_budapest.csv')

# %%
data_vienna = split_cities('Vienna')
data_vienna.to_csv('data_vienna.csv')

# %%
# berlin, paris, rome, lisboa, londres, amsterdam(pocas observaciones), barcelona (), athens

# %%
geo_data = data_clean[['lng', 'lat']]
geo_data.to_csv('geo_data.csv')

# %% [markdown]
# #### Spatial econometrics

# %%
import pysal
from pysal.model import spreg
from pysal.lib import weights
from scipy import stats
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import osmnx as ox

# %%
gdf = gpd.read_file('geo_data.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14408\3846042304.py in <module>
# ----> 1 gdf = gpd.read_file('geo_data.csv')
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     240     index=None,
#     241     mode="w",
# --> 242     crs=None,
#     243     **kwargs,
#     244 ):
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _check_engine(engine, func)
#     110     >>> df = geopandas.read_file("nybb.shp", mask=polygon)  # doctest: +SKIP
#     111
# --> 112     Reading only geometries intersecting ``bbox``:
#     113
#     114     >>> df = geopandas.read_file("nybb.shp", bbox=(0, 10, 0, 20))  # doctest: +SKIP
#
# ImportError: The 'read_file' function requires the 'pyogrio' or 'fiona' package, but neither is installed or imports correctly.
# Importing fiona resulted in: DLL load failed while importing ogrext: No se puede encontrar el módulo especificado.
# Importing pyogrio resulted in: No module named 'pyogrio'

# %%
# Create spatial weights matrix
w = pysal.lib.weights.Queen.from_dataframe((data_clean_numerical), simplify=True)

# Create spatial lag variable
y_lag = pysal.lib.weights.lag_spatial(w, data['y'])

# Ordinary least squares (OLS) regression
model = pysal.model.spreg.OLS(y, x, w=w, name_y='y', name_x=['x1', 'x2'])

# Get summary of regression results
print(model.summary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628         this = self.unique()
# -> 3629
#    3630         indexer = this.get_indexer_for(other)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'geometry'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14408\35741906.py in <module>
#       1 # Create spatial weights matrix
# ----> 2 w = pysal.lib.weights.Queen.from_dataframe((data_clean_numerical), simplify=True)
#       3
#       4 # Create spatial lag variable
#       5 y_lag = pysal.lib.weights.lag_spatial(w, data['y'])
#
# ~\anaconda3\lib\site-packages\pysal\lib\weights\contiguity.py in from_dataframe(cls, df, geom_col, **kwargs)
#     315         elif isinstance(ids, str):
#     316             ids = df.get(ids).tolist()
# --> 317         w = cls.from_iterable(df[geom_col].tolist(), ids=ids, id_order=id_order, **kwargs)
#     318         return w
#     319
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503         details.
#    3504
# -> 3505         Examples
#    3506         --------
#    3507         >>> dtypes = ['int64', 'float64', 'complex128', 'object', 'bool']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629
#    3630         indexer = this.get_indexer_for(other)
# -> 3631         indexer = indexer.take((indexer != -1).nonzero()[0])
#    3632
#    3633         label_diff = np.setdiff1d(np.arange(this.size), indexer, assume_unique=True)
#
# KeyError: 'geometry'

# %%
import geopandas as gpd

# Load spatial data
data = gpd.read_file(data_clean_numerical)

# Plot spatial data
data.plot(column='value', cmap='OrRd')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14408\1166665703.py in <module>
#       2
#       3 # Load spatial data
# ----> 4 data = gpd.read_file(data_clean_numerical)
#       5
#       6 # Plot spatial data
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     240     index=None,
#     241     mode="w",
# --> 242     crs=None,
#     243     **kwargs,
#     244 ):
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _check_engine(engine, func)
#     110     >>> df = geopandas.read_file("nybb.shp", mask=polygon)  # doctest: +SKIP
#     111
# --> 112     Reading only geometries intersecting ``bbox``:
#     113
#     114     >>> df = geopandas.read_file("nybb.shp", bbox=(0, 10, 0, 20))  # doctest: +SKIP
#
# ImportError: The 'read_file' function requires the 'pyogrio' or 'fiona' package, but neither is installed or imports correctly.
# Importing fiona resulted in: DLL load failed while importing ogrext: No se puede encontrar el módulo especificado.
# Importing pyogrio resulted in: No module named 'pyogrio'

# %%
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# Load spatial data
data = np.loadtxt('path/to/data.csv', delimiter=',')

# Standardize data
scaler = StandardScaler()
data_std = scaler.fit_transform(data)

# Perform DBSCAN clustering
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(data_std)

# Plot clusters
plt.scatter(data[:,0], data[:,1], c=clusters, cmap='tab10')
