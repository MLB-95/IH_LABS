# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

RAND_STATE = 32 # for reproducible shuffling
TT_RATIO = 0.25 # test/train

from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
data_paris = pd.read_csv('data_paris.csv')

# %%
data_paris.corr()
# Out:
#                             Unnamed: 0   realSum  person_capacity     multi  \
# Unnamed: 0                    1.000000 -0.164703        -0.045212  0.023824
# realSum                      -0.164703  1.000000         0.395620  0.018087
# person_capacity              -0.045212  0.395620         1.000000 -0.010394
# multi                         0.023824  0.018087        -0.010394  1.000000
# biz                          -0.208457  0.104630         0.107246 -0.302755
# cleanliness_rating           -0.004463  0.068471        -0.046916  0.007057
# guest_satisfaction_overall    0.050962  0.058530        -0.016014 -0.011639
# bedrooms                      0.043074  0.353561         0.529153  0.053945
# dist                          0.624514 -0.099438        -0.062163  0.039875
# metro_dist                    0.200687 -0.025620        -0.019463  0.027128
# attr_index_norm              -0.640693  0.252671         0.056676  0.010550
# rest_index_norm              -0.730778  0.205716         0.058032 -0.015428
# room_shared_True              0.029037 -0.086654         0.063102 -0.023423
# room_private_True             0.027435 -0.153378        -0.295026  0.213285
# host_is_superhost_True       -0.027396  0.022569        -0.070217  0.043066
# weekend_yes                   0.109284 -0.017729         0.004913 -0.012288
#
#                                  biz  cleanliness_rating  \
# Unnamed: 0                 -0.208457           -0.004463
# realSum                     0.104630            0.068471
# person_capacity             0.107246           -0.046916
# multi                      -0.302755            0.007057
# biz                         1.000000           -0.040065
# cleanliness_rating         -0.040065            1.000000
# guest_satisfaction_overall -0.195606            0.655019
# bedrooms                   -0.067160            0.043241
# dist                       -0.139010            0.004036
# metro_dist                 -0.102780           -0.020198
# attr_index_norm             0.168461            0.016315
# rest_index_norm             0.206530            0.011902
# room_shared_True            0.114735           -0.027098
# room_private_True           0.081609            0.086487
# host_is_superhost_True     -0.112166            0.214551
# weekend_yes                -0.026867            0.009257
#
#                             guest_satisfaction_overall  bedrooms      dist  \
# Unnamed: 0                                    0.050962  0.043074  0.624514
# realSum                                       0.058530  0.353561 -0.099438
# person_capacity                              -0.016014  0.529153 -0.062163
# multi                                        -0.011639  0.053945  0.039875
# biz                                          -0.195606 -0.067160 -0.139010
# cleanliness_rating                            0.655019  0.043241  0.004036
# guest_satisfaction_overall                    1.000000  0.095243  0.041161
# bedrooms                                      0.095243  1.000000  0.009014
# dist                                          0.041161  0.009014  1.000000
# metro_dist                                    0.014135  0.009823  0.281302
# attr_index_norm                              -0.032589 -0.029479 -0.519953
# rest_index_norm                              -0.042689 -0.022054 -0.720074
# room_shared_True                              0.001076  0.005057  0.020926
# room_private_True                             0.016672  0.045214  0.064308
# host_is_superhost_True                        0.207250  0.034539  0.025191
# weekend_yes                                   0.019795  0.005514 -0.009628
#
#                             metro_dist  attr_index_norm  rest_index_norm  \
# Unnamed: 0                    0.200687        -0.640693        -0.730778
# realSum                      -0.025620         0.252671         0.205716
# person_capacity              -0.019463         0.056676         0.058032
# multi                         0.027128         0.010550        -0.015428
# biz                          -0.102780         0.168461         0.206530
# cleanliness_rating           -0.020198         0.016315         0.011902
# guest_satisfaction_overall    0.014135        -0.032589        -0.042689
# bedrooms                      0.009823        -0.029479        -0.022054
# dist                          0.281302        -0.519953        -0.720074
# metro_dist                    1.000000        -0.153206        -0.251922
# attr_index_norm              -0.153206         1.000000         0.768740
# rest_index_norm              -0.251922         0.768740         1.000000
# room_shared_True             -0.021448        -0.058984        -0.049640
# room_private_True            -0.003536        -0.066204        -0.039120
# host_is_superhost_True       -0.003465         0.002459        -0.008596
# weekend_yes                  -0.005199         0.010501        -0.317696
#
#                             room_shared_True  room_private_True  \
# Unnamed: 0                          0.029037           0.027435
# realSum                            -0.086654          -0.153378
# person_capacity                     0.063102          -0.295026
# multi                              -0.023423           0.213285
# biz                                 0.114735           0.081609
# cleanliness_rating                 -0.027098           0.086487
# guest_satisfaction_overall          0.001076           0.016672
# bedrooms                            0.005057           0.045214
# dist                                0.020926           0.064308
# metro_dist                         -0.021448          -0.003536
# attr_index_norm                    -0.058984          -0.066204
# rest_index_norm                    -0.049640          -0.039120
# room_shared_True                    1.000000          -0.064944
# room_private_True                  -0.064944           1.000000
# host_is_superhost_True             -0.019089           0.045231
# weekend_yes                        -0.007656          -0.030955
#
#                             host_is_superhost_True  weekend_yes
# Unnamed: 0                               -0.027396     0.109284
# realSum                                   0.022569    -0.017729
# person_capacity                          -0.070217     0.004913
# multi                                     0.043066    -0.012288
# biz                                      -0.112166    -0.026867
# cleanliness_rating                        0.214551     0.009257
# guest_satisfaction_overall                0.207250     0.019795
# bedrooms                                  0.034539     0.005514
# dist                                      0.025191    -0.009628
# metro_dist                               -0.003465    -0.005199
# attr_index_norm                           0.002459     0.010501
# rest_index_norm                          -0.008596    -0.317696
# room_shared_True                         -0.019089    -0.007656
# room_private_True                         0.045231    -0.030955
# host_is_superhost_True                    1.000000     0.009816
# weekend_yes                               0.009816     1.000000

# %%
data_paris = data_paris.drop(['Unnamed: 0'], axis=1)

# %%
x = data_paris.drop('realSum', axis=1)
y = data_paris.realSum

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TT_RATIO, random_state=RAND_STATE)
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train.describe()
# Out:
#        person_capacity        multi          biz  cleanliness_rating  \
# count      5016.000000  5016.000000  5016.000000         5016.000000
# mean          2.960726     0.221292     0.246212            9.257376
# std           1.217295     0.415158     0.430847            0.994775
# min           2.000000     0.000000     0.000000            2.000000
# 25%           2.000000     0.000000     0.000000            9.000000
# 50%           2.000000     0.000000     0.000000            9.000000
# 75%           4.000000     0.000000     0.000000           10.000000
# max           6.000000     1.000000     1.000000           10.000000
#
#        guest_satisfaction_overall     bedrooms         dist   metro_dist  \
# count                 5016.000000  5016.000000  5016.000000  5016.000000
# mean                    91.996611     0.975279     3.007069     0.227151
# std                      8.871082     0.649094     1.460419     0.122380
# min                     20.000000     0.000000     0.070000     0.000000
# 25%                     89.000000     1.000000     1.840000     0.140000
# 50%                     94.000000     1.000000     3.020000     0.210000
# 75%                     98.000000     1.000000     4.050000     0.290000
# max                    100.000000     5.000000     7.700000     1.050000
#
#        attr_index_norm  rest_index_norm  room_shared_True  room_private_True  \
# count      5016.000000      5016.000000       5016.000000        5016.000000
# mean         18.220481        42.593045          0.014753           0.224083
# std           7.870011        15.660348          0.120574           0.417019
# min           5.654976        11.933258          0.000000           0.000000
# 25%          12.764097        30.147741          0.000000           0.000000
# 50%          16.426945        40.614106          0.000000           0.000000
# 75%          22.185124        52.921407          0.000000           0.000000
# max         100.000000       100.000000          1.000000           1.000000
#
#        host_is_superhost_True  weekend_yes
# count             5016.000000  5016.000000
# mean                 0.141148     0.530303
# std                  0.348209     0.499131
# min                  0.000000     0.000000
# 25%                  0.000000     0.000000
# 50%                  0.000000     1.000000
# 75%                  0.000000     1.000000
# max                  1.000000     1.000000

# %%
x_train_const = sm.add_constant(x_train) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.437
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     277.5
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):               0.00
# Time:                        16:43:23   Log-Likelihood:                -33817.
# No. Observations:                5016   AIC:                         6.766e+04
# Df Residuals:                    5001   BIC:                         6.776e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       -500.9911     41.220    -12.154      0.000    -581.801    -420.182
# person_capacity               64.4122      3.135     20.548      0.000      58.267      70.558
# multi                         51.1620      7.696      6.648      0.000      36.074      66.250
# biz                           87.1787      7.833     11.129      0.000      71.822     102.536
# cleanliness_rating            18.8740      3.891      4.851      0.000      11.247      26.501
# guest_satisfaction_overall     0.7312      0.443      1.651      0.099      -0.137       1.600
# bedrooms                     128.3868      5.578     23.015      0.000     117.451     139.323
# dist                          21.3720      3.190      6.699      0.000      15.118      27.626
# metro_dist                    56.1649     24.814      2.263      0.024       7.518     104.812
# attr_index_norm                7.2897      0.642     11.357      0.000       6.031       8.548
# rest_index_norm                2.4883      0.455      5.473      0.000       1.597       3.380
# room_shared_True            -295.5927     24.411    -12.109      0.000    -343.449    -247.737
# room_private_True            -93.5234      7.947    -11.768      0.000    -109.103     -77.944
# host_is_superhost_True        26.3719      8.641      3.052      0.002       9.433      43.311
# weekend_yes                   16.4453      7.421      2.216      0.027       1.897      30.994
# ==============================================================================
# Omnibus:                     5757.780   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1090564.039
# Skew:                           5.712   Prob(JB):                         0.00
# Kurtosis:                      74.327   Cond. No.                     1.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sts = StandardScaler()

x_train_standarized = sts.fit_transform(x_train)
x_test_standarized = sts.transform(x_test)

x_train_standarized = pd.DataFrame(x_train_standarized)

# %%
x_train_const = sm.add_constant(x_train_standarized.to_numpy()) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test_standarized) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.437
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     277.5
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):               0.00
# Time:                        16:43:23   Log-Likelihood:                -33817.
# No. Observations:                5016   AIC:                         6.766e+04
# Df Residuals:                    5001   BIC:                         6.776e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        392.6653      2.898    135.483      0.000     386.983     398.347
# x1            78.4009      3.816     20.548      0.000      70.921      85.881
# x2            21.2382      3.195      6.648      0.000      14.975      27.502
# x3            37.5569      3.375     11.129      0.000      30.941      44.173
# x4            18.7735      3.870      4.851      0.000      11.187      26.360
# x5             6.4861      3.930      1.651      0.099      -1.218      14.190
# x6            83.3268      3.621     23.015      0.000      76.229      90.425
# x7            31.2089      4.659      6.699      0.000      22.076      40.342
# x8             6.8728      3.036      2.263      0.024       0.920      12.826
# x9            57.3643      5.051     11.357      0.000      47.462      67.266
# x10           38.9637      7.119      5.473      0.000      25.006      52.921
# x11          -35.6372      2.943    -12.109      0.000     -41.407     -29.868
# x12          -38.9971      3.314    -11.768      0.000     -45.494     -32.501
# x13            9.1820      3.008      3.052      0.002       3.284      15.080
# x14            8.2076      3.704      2.216      0.027       0.947      15.469
# ==============================================================================
# Omnibus:                     5757.780   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1090564.039
# Skew:                           5.712   Prob(JB):                         0.00
# Kurtosis:                      74.327   Cond. No.                         5.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.coef_
model.intercept_
# Out:
# -500.99113306879696

# %%
model.score(x_train, y_train)
# Out:
# 0.43717952964710727

# %%
y_pred = pd.DataFrame(model.predict(x_test),columns = ['realSum'] )      # model prediction
y_pred_train =  pd.DataFrame(model.predict(x_train),columns = ['realSum'])

# %%
mse(y_test,y_pred)
# Out:
# 190174.50158840412

# %%
rmse = np.sqrt(mse(y_test,y_pred))
rmse
# Out:
# 436.0900154651607

# %%
##prediction on the train set
mse(y_train,y_pred_train)
# Out:
# 42008.31507818011

# %%
mae(y_test,y_pred)
# Out:
# 122.41146129806208

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.11186534645635915

# %%
R2_test=model.score(x_test,y_test)
R2_train=model.score(x_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
Adj_R2
# Out:
# 0.10436149301664222

# %%
model_lasso=Lasso(alpha=0.05)

model_lasso.fit(x_train, y_train)
print(f"{model_lasso.__class__.__name__}: Train -> {model_lasso.score(x_train, y_train)}, Test -> {model_lasso.score(x_test, y_test)}")
# Out:
# Lasso: Train -> 0.4371725705061966, Test -> 0.11195708641902602

# %%
model_ridge=Ridge(alpha=1000)
model_ridge.fit(x_train, y_train)
print(f"{model_ridge.__class__.__name__}: Train -> {model_ridge.score(x_train, y_train)}, Test -> {model_ridge.score(x_test, y_test)}")
# Out:
# Ridge: Train -> 0.40393971731826683, Test -> 0.10558381999432187

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

print("X_train has %d rows and %d columns"  %(x_train.shape[0],x_train.shape[1]))
print("-----------------------------------")
print("The coefficient of determination for the test data is R2=%.2f"
      %(model.score(x_test, y_test)))
print("The coefficient of determination for the train data is R2=%.2f"
      %(model.score(x_train, y_train)))
# Out:
# X_train has 5016 rows and 14 columns
# -----------------------------------
# The coefficient of determination for the test data is R2=0.09
# The coefficient of determination for the train data is R2=1.00

# %%
scores=cross_val_score(model, x_train, y_train, cv=5)
print("Cross validation scores: ", scores)
print("Score stats: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Cross validation scores:  [-0.06078817  0.42230531  0.50992573  0.64046643  0.02132424]
# Score stats: 0.31 accuracy with a standard deviation of 0.28

# %%
model1 = DecisionTreeRegressor()
model2 = LinearRegression()
model3 = KNeighborsRegressor()

model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, x_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.34443889681130824, 'Linear Regression': 0.43591704407833054, 'KNN': 0.26984489623313146}
