# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

RAND_STATE = 32 # for reproducible shuffling
TT_RATIO = 0.25 # test/train

from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
data_lisbon = pd.read_csv('data_lisbon.csv')

# %%
data_lisbon.corr()
# Out:
#                             Unnamed: 0   realSum  person_capacity     multi  \
# Unnamed: 0                    1.000000 -0.027104         0.003875 -0.074577
# realSum                      -0.027104  1.000000         0.572876 -0.048793
# person_capacity               0.003875  0.572876         1.000000 -0.018117
# multi                        -0.074577 -0.048793        -0.018117  1.000000
# biz                           0.044854 -0.041396        -0.064970 -0.669704
# cleanliness_rating           -0.049813  0.140534         0.042824  0.045552
# guest_satisfaction_overall   -0.032528  0.138249         0.052730  0.095190
# bedrooms                      0.017059  0.379515         0.564945  0.012307
# dist                         -0.141035 -0.141221        -0.035728  0.064905
# metro_dist                   -0.164375 -0.000781         0.049808  0.028105
# attr_index_norm              -0.197584  0.195738         0.060219 -0.017435
# rest_index_norm              -0.118059  0.248556         0.073258 -0.051616
# room_shared_True              0.032012 -0.141457         0.100435  0.001011
# room_private_True             0.022012 -0.554832        -0.575360  0.026575
# host_is_superhost_True       -0.025779  0.073975         0.043314  0.121704
# weekend_yes                   0.014723  0.016971        -0.019085 -0.000705
#
#                                  biz  cleanliness_rating  \
# Unnamed: 0                  0.044854           -0.049813
# realSum                    -0.041396            0.140534
# person_capacity            -0.064970            0.042824
# multi                      -0.669704            0.045552
# biz                         1.000000           -0.098798
# cleanliness_rating         -0.098798            1.000000
# guest_satisfaction_overall -0.162725            0.717671
# bedrooms                   -0.090696            0.043075
# dist                       -0.105746            0.000324
# metro_dist                 -0.072405            0.021824
# attr_index_norm             0.053135            0.041491
# rest_index_norm             0.108929            0.026228
# room_shared_True            0.032942           -0.077441
# room_private_True           0.101720           -0.081405
# host_is_superhost_True     -0.140480            0.271552
# weekend_yes                -0.003098            0.008608
#
#                             guest_satisfaction_overall  bedrooms      dist  \
# Unnamed: 0                                   -0.032528  0.017059 -0.141035
# realSum                                       0.138249  0.379515 -0.141221
# person_capacity                               0.052730  0.564945 -0.035728
# multi                                         0.095190  0.012307  0.064905
# biz                                          -0.162725 -0.090696 -0.105746
# cleanliness_rating                            0.717671  0.043075  0.000324
# guest_satisfaction_overall                    1.000000  0.046602  0.009143
# bedrooms                                      0.046602  1.000000  0.039312
# dist                                          0.009143  0.039312  1.000000
# metro_dist                                    0.019300  0.014688  0.495592
# attr_index_norm                               0.045778 -0.049939 -0.564733
# rest_index_norm                               0.022667 -0.031874 -0.723245
# room_shared_True                             -0.074126 -0.042651  0.035619
# room_private_True                            -0.066077 -0.183884  0.156073
# host_is_superhost_True                        0.286804  0.016320 -0.008294
# weekend_yes                                   0.005016 -0.016519  0.003258
#
#                             metro_dist  attr_index_norm  rest_index_norm  \
# Unnamed: 0                   -0.164375        -0.197584        -0.118059
# realSum                      -0.000781         0.195738         0.248556
# person_capacity               0.049808         0.060219         0.073258
# multi                         0.028105        -0.017435        -0.051616
# biz                          -0.072405         0.053135         0.108929
# cleanliness_rating            0.021824         0.041491         0.026228
# guest_satisfaction_overall    0.019300         0.045778         0.022667
# bedrooms                      0.014688        -0.049939        -0.031874
# dist                          0.495592        -0.564733        -0.723245
# metro_dist                    1.000000        -0.213966        -0.345482
# attr_index_norm              -0.213966         1.000000         0.748505
# rest_index_norm              -0.345482         0.748505         1.000000
# room_shared_True             -0.040260        -0.048813        -0.041977
# room_private_True            -0.080024        -0.208247        -0.190211
# host_is_superhost_True        0.025306         0.024876         0.039751
# weekend_yes                   0.008626        -0.007319         0.168094
#
#                             room_shared_True  room_private_True  \
# Unnamed: 0                          0.032012           0.022012
# realSum                            -0.141457          -0.554832
# person_capacity                     0.100435          -0.575360
# multi                               0.001011           0.026575
# biz                                 0.032942           0.101720
# cleanliness_rating                 -0.077441          -0.081405
# guest_satisfaction_overall         -0.074126          -0.066077
# bedrooms                           -0.042651          -0.183884
# dist                                0.035619           0.156073
# metro_dist                         -0.040260          -0.080024
# attr_index_norm                    -0.048813          -0.208247
# rest_index_norm                    -0.041977          -0.190211
# room_shared_True                    1.000000          -0.077206
# room_private_True                  -0.077206           1.000000
# host_is_superhost_True             -0.006887          -0.062405
# weekend_yes                         0.005195           0.002842
#
#                             host_is_superhost_True  weekend_yes
# Unnamed: 0                               -0.025779     0.014723
# realSum                                   0.073975     0.016971
# person_capacity                           0.043314    -0.019085
# multi                                     0.121704    -0.000705
# biz                                      -0.140480    -0.003098
# cleanliness_rating                        0.271552     0.008608
# guest_satisfaction_overall                0.286804     0.005016
# bedrooms                                  0.016320    -0.016519
# dist                                     -0.008294     0.003258
# metro_dist                                0.025306     0.008626
# attr_index_norm                           0.024876    -0.007319
# rest_index_norm                           0.039751     0.168094
# room_shared_True                         -0.006887     0.005195
# room_private_True                        -0.062405     0.002842
# host_is_superhost_True                    1.000000     0.001065
# weekend_yes                               0.001065     1.000000

# %%
data_lisbon = data_lisbon.drop(['Unnamed: 0', 'biz', 'host_is_superhost_True', 'weekend_yes' ], axis=1)

# %%
x = data_lisbon.drop('realSum', axis=1)
y = data_lisbon.realSum

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TT_RATIO, random_state=RAND_STATE)
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train.describe()
# Out:
#        person_capacity        multi  cleanliness_rating  \
# count      4322.000000  4322.000000         4322.000000
# mean          3.350069     0.237390            9.370662
# std           1.346423     0.425533            0.911776
# min           2.000000     0.000000            2.000000
# 25%           2.000000     0.000000            9.000000
# 50%           3.000000     0.000000           10.000000
# 75%           4.000000     0.000000           10.000000
# max           6.000000     1.000000           10.000000
#
#        guest_satisfaction_overall     bedrooms         dist   metro_dist  \
# count                 4322.000000  4322.000000  4322.000000  4322.000000
# mean                    91.150856     1.280657     1.973260     0.702601
# std                      8.991081     0.737554     1.744528     0.902371
# min                     20.000000     0.000000     0.040000     0.010000
# 25%                     88.000000     1.000000     0.800000     0.280000
# 50%                     93.000000     1.000000     1.390000     0.440000
# 75%                     97.000000     2.000000     2.450000     0.680000
# max                    100.000000    10.000000     9.570000     6.160000
#
#        attr_index_norm  rest_index_norm  room_shared_True  room_private_True
# count      4322.000000      4322.000000       4322.000000        4322.000000
# mean          7.277677        28.142905          0.013882           0.314438
# std           4.992253        17.795677          0.117017           0.464345
# min           1.364900         3.387587          0.000000           0.000000
# 25%           3.763451        14.924343          0.000000           0.000000
# 50%           5.467558        24.233492          0.000000           0.000000
# 75%           9.993602        37.805143          0.000000           1.000000
# max         100.000000       100.000000          1.000000           1.000000

# %%
x_train_const = sm.add_constant(x_train) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     379.4
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):               0.00
# Time:                        16:50:01   Log-Likelihood:                -24965.
# No. Observations:                4322   AIC:                         4.995e+04
# Df Residuals:                    4310   BIC:                         5.003e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         18.0821     14.518      1.245      0.213     -10.381      46.546
# person_capacity               23.7285      1.338     17.728      0.000      21.104      26.353
# multi                        -10.1271      2.817     -3.595      0.000     -15.650      -4.605
# cleanliness_rating             5.6783      1.846      3.076      0.002       2.059       9.298
# guest_satisfaction_overall     0.5117      0.188      2.727      0.006       0.144       0.880
# bedrooms                      21.0986      2.028     10.401      0.000      17.122      25.075
# dist                           5.5898      1.075      5.200      0.000       3.482       7.697
# metro_dist                    -2.9741      1.545     -1.925      0.054      -6.004       0.055
# attr_index_norm               -0.6074      0.373     -1.627      0.104      -1.339       0.125
# rest_index_norm                1.4330      0.124     11.591      0.000       1.191       1.675
# room_shared_True            -177.9998     10.405    -17.107      0.000    -198.399    -157.601
# room_private_True            -81.0543      3.327    -24.362      0.000     -87.577     -74.531
# ==============================================================================
# Omnibus:                     3870.340   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           333297.955
# Skew:                           3.899   Prob(JB):                         0.00
# Kurtosis:                      45.308   Cond. No.                     1.19e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sts = StandardScaler()

x_train_standarized = sts.fit_transform(x_train)
x_test_standarized = sts.transform(x_test)

x_train_standarized = pd.DataFrame(x_train_standarized)

# %%
x_train_const = sm.add_constant(x_train_standarized.to_numpy()) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test_standarized) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     379.4
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):               0.00
# Time:                        16:50:01   Log-Likelihood:                -24965.
# No. Observations:                4322   AIC:                         4.995e+04
# Df Residuals:                    4310   BIC:                         5.003e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        238.9350      1.189    200.998      0.000     236.604     241.266
# x1            31.9450      1.802     17.728      0.000      28.412      35.478
# x2            -4.3089      1.199     -3.595      0.000      -6.659      -1.959
# x3             5.1768      1.683      3.076      0.002       1.877       8.477
# x4             4.6003      1.687      2.727      0.006       1.293       7.908
# x5            15.5595      1.496     10.401      0.000      12.627      18.492
# x6             9.7504      1.875      5.200      0.000       6.074      13.426
# x7            -2.6835      1.394     -1.925      0.054      -5.417       0.050
# x8            -3.0318      1.864     -1.627      0.104      -6.685       0.622
# x9            25.4989      2.200     11.591      0.000      21.186      29.812
# x10          -20.8265      1.217    -17.107      0.000     -23.213     -18.440
# x11          -37.6328      1.545    -24.362      0.000     -40.661     -34.604
# ==============================================================================
# Omnibus:                     3870.340   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           333297.955
# Skew:                           3.899   Prob(JB):                         0.00
# Kurtosis:                      45.308   Cond. No.                         3.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.coef_
model.intercept_
# Out:
# 18.082118796900232

# %%
model.score(x_train, y_train)
# Out:
# 0.4919260881497334

# %%
y_pred = pd.DataFrame(model.predict(x_test),columns = ['realSum'] )      # model prediction
y_pred_train =  pd.DataFrame(model.predict(x_train),columns = ['realSum'])

# %%
mse(y_test,y_pred)
# Out:
# 5799.745584775512

# %%
rmse = np.sqrt(mse(y_test,y_pred))
rmse
# Out:
# 76.15606072254205

# %%
##prediction on the train set
mse(y_train,y_pred_train)
# Out:
# 6090.519314763539

# %%
mae(y_test,y_pred)
# Out:
# 51.57223589391521

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.4967090740671093

# %%
R2_test=model.score(x_test,y_test)
R2_train=model.score(x_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
Adj_R2
# Out:
# 0.4928348961907889

# %%
model_lasso=Lasso(alpha=0.05)

model_lasso.fit(x_train, y_train)
print(f"{model_lasso.__class__.__name__}: Train -> {model_lasso.score(x_train, y_train)}, Test -> {model_lasso.score(x_test, y_test)}")
# Out:
# Lasso: Train -> 0.4919056831219628, Test -> 0.4968861773496801

# %%
model_ridge=Ridge(alpha=1000)
model_ridge.fit(x_train, y_train)
print(f"{model_ridge.__class__.__name__}: Train -> {model_ridge.score(x_train, y_train)}, Test -> {model_ridge.score(x_test, y_test)}")
# Out:
# Ridge: Train -> 0.43284605545929156, Test -> 0.45452869720273315

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

print("X_train has %d rows and %d columns"  %(x_train.shape[0],x_train.shape[1]))
print("-----------------------------------")
print("The coefficient of determination for the test data is R2=%.2f"
      %(model.score(x_test, y_test)))
print("The coefficient of determination for the train data is R2=%.2f"
      %(model.score(x_train, y_train)))
# Out:
# X_train has 4322 rows and 11 columns
# -----------------------------------
# The coefficient of determination for the test data is R2=0.46
# The coefficient of determination for the train data is R2=1.00

# %%
scores=cross_val_score(model, x_train, y_train, cv=5)
print("Cross validation scores: ", scores)
print("Score stats: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Cross validation scores:  [0.40920841 0.36586928 0.49190857 0.30512667 0.38633693]
# Score stats: 0.39 accuracy with a standard deviation of 0.06

# %%
model1 = DecisionTreeRegressor()
model2 = LinearRegression()
model3 = KNeighborsRegressor()

model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, x_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.35470044168828857, 'Linear Regression': 0.4936620094845391, 'KNN': 0.35775478656924153}
