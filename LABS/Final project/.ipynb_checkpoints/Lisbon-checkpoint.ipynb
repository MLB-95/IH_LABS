# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

RAND_STATE = 32 # for reproducible shuffling
TT_RATIO = 0.25 # test/train

from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
data_rome = pd.read_csv('data_rome.csv')

# %%
data_rome.corr()
# Out:
#                             Unnamed: 0   realSum  person_capacity     multi  \
# Unnamed: 0                    1.000000  0.023414         0.010820 -0.000715
# realSum                       0.023414  1.000000         0.403907 -0.065923
# person_capacity               0.010820  0.403907         1.000000 -0.094933
# multi                        -0.000715 -0.065923        -0.094933  1.000000
# biz                          -0.015856  0.057400        -0.007686 -0.561577
# cleanliness_rating            0.026060  0.005998        -0.015427  0.042467
# guest_satisfaction_overall    0.019661  0.036047         0.015047  0.054421
# bedrooms                      0.013546  0.336617         0.597036 -0.042833
# dist                          0.006587 -0.183023         0.022424  0.036889
# metro_dist                    0.003059  0.032553         0.041276 -0.007044
# attr_index_norm               0.018313  0.402306         0.117925 -0.065168
# rest_index_norm               0.021186  0.402724         0.137297 -0.083941
# room_shared_True             -0.010534 -0.033423         0.020234  0.002302
# room_private_True            -0.025772 -0.375700        -0.585820  0.155870
# host_is_superhost_True        0.004583  0.034289         0.041342  0.085794
# weekend_yes                   0.008250  0.031666         0.004624 -0.001501
#
#                                  biz  cleanliness_rating  \
# Unnamed: 0                 -0.015856            0.026060
# realSum                     0.057400            0.005998
# person_capacity            -0.007686           -0.015427
# multi                      -0.561577            0.042467
# biz                         1.000000           -0.129658
# cleanliness_rating         -0.129658            1.000000
# guest_satisfaction_overall -0.184677            0.706916
# bedrooms                   -0.059793            0.004377
# dist                       -0.205920            0.054313
# metro_dist                 -0.044512           -0.023382
# attr_index_norm             0.215446           -0.041654
# rest_index_norm             0.237018           -0.053077
# room_shared_True            0.019278           -0.015707
# room_private_True           0.084559           -0.007528
# host_is_superhost_True     -0.161892            0.297224
# weekend_yes                 0.010248           -0.001662
#
#                             guest_satisfaction_overall  bedrooms      dist  \
# Unnamed: 0                                    0.019661  0.013546  0.006587
# realSum                                       0.036047  0.336617 -0.183023
# person_capacity                               0.015047  0.597036  0.022424
# multi                                         0.054421 -0.042833  0.036889
# biz                                          -0.184677 -0.059793 -0.205920
# cleanliness_rating                            0.706916  0.004377  0.054313
# guest_satisfaction_overall                    1.000000  0.029357  0.079691
# bedrooms                                      0.029357  1.000000  0.040150
# dist                                          0.079691  0.040150  1.000000
# metro_dist                                    0.015549  0.011601  0.346068
# attr_index_norm                              -0.034342  0.009073 -0.467529
# rest_index_norm                              -0.053597  0.006744 -0.470964
# room_shared_True                             -0.026638 -0.015250  0.001178
# room_private_True                            -0.061291 -0.284690 -0.025375
# host_is_superhost_True                        0.332278  0.030274  0.019758
# weekend_yes                                  -0.009913  0.004458 -0.010746
#
#                             metro_dist  attr_index_norm  rest_index_norm  \
# Unnamed: 0                    0.003059         0.018313         0.021186
# realSum                       0.032553         0.402306         0.402724
# person_capacity               0.041276         0.117925         0.137297
# multi                        -0.007044        -0.065168        -0.083941
# biz                          -0.044512         0.215446         0.237018
# cleanliness_rating           -0.023382        -0.041654        -0.053077
# guest_satisfaction_overall    0.015549        -0.034342        -0.053597
# bedrooms                      0.011601         0.009073         0.006744
# dist                          0.346068        -0.467529        -0.470964
# metro_dist                    1.000000        -0.030664         0.111299
# attr_index_norm              -0.030664         1.000000         0.804241
# rest_index_norm               0.111299         0.804241         1.000000
# room_shared_True             -0.001332        -0.022957        -0.021550
# room_private_True            -0.113753        -0.192505        -0.221888
# host_is_superhost_True       -0.041129         0.018770        -0.005651
# weekend_yes                  -0.025774         0.016623         0.001054
#
#                             room_shared_True  room_private_True  \
# Unnamed: 0                         -0.010534          -0.025772
# realSum                            -0.033423          -0.375700
# person_capacity                     0.020234          -0.585820
# multi                               0.002302           0.155870
# biz                                 0.019278           0.084559
# cleanliness_rating                 -0.015707          -0.007528
# guest_satisfaction_overall         -0.026638          -0.061291
# bedrooms                           -0.015250          -0.284690
# dist                                0.001178          -0.025375
# metro_dist                         -0.001332          -0.113753
# attr_index_norm                    -0.022957          -0.192505
# rest_index_norm                    -0.021550          -0.221888
# room_shared_True                    1.000000          -0.028723
# room_private_True                  -0.028723           1.000000
# host_is_superhost_True             -0.018931          -0.065790
# weekend_yes                        -0.006255          -0.005574
#
#                             host_is_superhost_True  weekend_yes
# Unnamed: 0                                0.004583     0.008250
# realSum                                   0.034289     0.031666
# person_capacity                           0.041342     0.004624
# multi                                     0.085794    -0.001501
# biz                                      -0.161892     0.010248
# cleanliness_rating                        0.297224    -0.001662
# guest_satisfaction_overall                0.332278    -0.009913
# bedrooms                                  0.030274     0.004458
# dist                                      0.019758    -0.010746
# metro_dist                               -0.041129    -0.025774
# attr_index_norm                           0.018770     0.016623
# rest_index_norm                          -0.005651     0.001054
# room_shared_True                         -0.018931    -0.006255
# room_private_True                        -0.065790    -0.005574
# host_is_superhost_True                    1.000000    -0.020561
# weekend_yes                              -0.020561     1.000000

# %%
data_rome = data_rome.drop(['Unnamed: 0'], axis=1)

# %%
x = data_rome.drop('realSum', axis=1)
y = data_rome.realSum

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TT_RATIO, random_state=RAND_STATE)
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train.describe()
# Out:
#        person_capacity        multi          biz  cleanliness_rating  \
# count      6770.000000  6770.000000  6770.000000         6770.000000
# mean          3.370015     0.386115     0.336780            9.512408
# std           1.304113     0.486893     0.472644            0.812760
# min           2.000000     0.000000     0.000000            2.000000
# 25%           2.000000     0.000000     0.000000            9.000000
# 50%           3.000000     0.000000     0.000000           10.000000
# 75%           4.000000     1.000000     1.000000           10.000000
# max           6.000000     1.000000     1.000000           10.000000
#
#        guest_satisfaction_overall     bedrooms         dist   metro_dist  \
# count                 6770.000000  6770.000000  6770.000000  6770.000000
# mean                    93.051403     1.228656     3.010529     0.815390
# std                      7.877967     0.549250     1.628708     0.627754
# min                     20.000000     0.000000     0.040000     0.010000
# 25%                     90.000000     1.000000     1.880000     0.330000
# 50%                     95.000000     1.000000     2.815000     0.610000
# 75%                     98.000000     1.000000     4.010000     1.220000
# max                    100.000000     5.000000     9.550000     4.150000
#
#        attr_index_norm  rest_index_norm  room_shared_True  room_private_True  \
# count      6770.000000      6770.000000       6770.000000        6770.000000
# mean         10.444306        25.166024          0.001329           0.377105
# std           6.726752        13.429044          0.036439           0.484697
# min           2.006476         5.535266          0.000000           0.000000
# 25%           5.389982        14.343042          0.000000           0.000000
# 50%           9.034893        21.571617          0.000000           0.000000
# 75%          13.937868        33.718199          0.000000           1.000000
# max         100.000000       100.000000          1.000000           1.000000
#
#        host_is_superhost_True  weekend_yes
# count             6770.000000  6770.000000
# mean                 0.328508     0.499114
# std                  0.469705     0.500036
# min                  0.000000     0.000000
# 25%                  0.000000     0.000000
# 50%                  0.000000     0.000000
# 75%                  1.000000     1.000000
# max                  1.000000     1.000000

# %%
x_train_const = sm.add_constant(x_train) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     239.8
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):               0.00
# Time:                        16:46:21   Log-Likelihood:                -40681.
# No. Observations:                6770   AIC:                         8.139e+04
# Df Residuals:                    6755   BIC:                         8.149e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         22.2129     17.760      1.251      0.211     -12.601      57.027
# person_capacity               12.3420      1.377      8.962      0.000       9.642      15.042
# multi                          2.0382      3.121      0.653      0.514      -4.080       8.157
# biz                            2.3208      3.378      0.687      0.492      -4.301       8.943
# cleanliness_rating            -2.9867      2.130     -1.402      0.161      -7.163       1.190
# guest_satisfaction_overall     0.6107      0.224      2.731      0.006       0.172       1.049
# bedrooms                      45.9977      2.754     16.701      0.000      40.599      51.397
# dist                          -2.2898      0.948     -2.415      0.016      -4.149      -0.431
# metro_dist                    -0.5957      2.187     -0.272      0.785      -4.883       3.692
# attr_index_norm                3.2327      0.299     10.813      0.000       2.647       3.819
# rest_index_norm                1.6758      0.160     10.488      0.000       1.363       1.989
# room_shared_True             -93.3869     32.988     -2.831      0.005    -158.054     -28.720
# room_private_True            -37.7280      3.292    -11.462      0.000     -44.180     -31.275
# host_is_superhost_True        -0.2550      2.759     -0.092      0.926      -5.664       5.154
# weekend_yes                    3.7415      2.400      1.559      0.119      -0.964       8.447
# ==============================================================================
# Omnibus:                    10407.784   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7849025.246
# Skew:                           9.484   Prob(JB):                         0.00
# Kurtosis:                     168.727   Cond. No.                     2.70e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sts = StandardScaler()

x_train_standarized = sts.fit_transform(x_train)
x_test_standarized = sts.transform(x_test)

x_train_standarized = pd.DataFrame(x_train_standarized)

# %%
x_train_const = sm.add_constant(x_train_standarized.to_numpy()) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test_standarized) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     239.8
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):               0.00
# Time:                        16:46:21   Log-Likelihood:                -40681.
# No. Observations:                6770   AIC:                         8.139e+04
# Df Residuals:                    6755   BIC:                         8.149e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        206.2925      1.199    172.121      0.000     203.943     208.642
# x1            16.0942      1.796      8.962      0.000      12.574      19.615
# x2             0.9923      1.520      0.653      0.514      -1.987       3.971
# x3             1.0968      1.596      0.687      0.492      -2.033       4.226
# x4            -2.4273      1.731     -1.402      0.161      -5.821       0.967
# x5             4.8105      1.762      2.731      0.006       1.357       8.264
# x6            25.2624      1.513     16.701      0.000      22.297      28.228
# x7            -3.7291      1.544     -2.415      0.016      -6.756      -0.702
# x8            -0.3739      1.373     -0.272      0.785      -3.065       2.317
# x9            21.7443      2.011     10.813      0.000      17.802      25.686
# x10           22.5028      2.146     10.488      0.000      18.297      26.709
# x11           -3.4027      1.202     -2.831      0.005      -5.759      -1.046
# x12          -18.2853      1.595    -11.462      0.000     -21.413     -15.158
# x13           -0.1198      1.296     -0.092      0.926      -2.660       2.421
# x14            1.8707      1.200      1.559      0.119      -0.482       4.223
# ==============================================================================
# Omnibus:                    10407.784   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7849025.246
# Skew:                           9.484   Prob(JB):                         0.00
# Kurtosis:                     168.727   Cond. No.                         3.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.coef_
model.intercept_
# Out:
# 22.21294375935406

# %%
model.score(x_train, y_train)
# Out:
# 0.3320183798099966

# %%
y_pred = pd.DataFrame(model.predict(x_test),columns = ['realSum'] )      # model prediction
y_pred_train =  pd.DataFrame(model.predict(x_train),columns = ['realSum'])

# %%
mse(y_test,y_pred)
# Out:
# 7849.8099647460185

# %%
rmse = np.sqrt(mse(y_test,y_pred))
rmse
# Out:
# 88.59915329587534

# %%
##prediction on the train set
mse(y_train,y_pred_train)
# Out:
# 9703.380416028027

# %%
mae(y_test,y_pred)
# Out:
# 49.47975341933798

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.3812223749965795

# %%
R2_test=model.score(x_test,y_test)
R2_train=model.score(x_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
Adj_R2
# Out:
# 0.377358464760162

# %%
model_lasso=Lasso(alpha=0.05)

model_lasso.fit(x_train, y_train)
print(f"{model_lasso.__class__.__name__}: Train -> {model_lasso.score(x_train, y_train)}, Test -> {model_lasso.score(x_test, y_test)}")
# Out:
# Lasso: Train -> 0.33187688064821586, Test -> 0.3811183726537102

# %%
model_ridge=Ridge(alpha=1000)
model_ridge.fit(x_train, y_train)
print(f"{model_ridge.__class__.__name__}: Train -> {model_ridge.score(x_train, y_train)}, Test -> {model_ridge.score(x_test, y_test)}")
# Out:
# Ridge: Train -> 0.3237927780435266, Test -> 0.37486619555459477

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

print("X_train has %d rows and %d columns"  %(x_train.shape[0],x_train.shape[1]))
print("-----------------------------------")
print("The coefficient of determination for the test data is R2=%.2f"
      %(model.score(x_test, y_test)))
print("The coefficient of determination for the train data is R2=%.2f"
      %(model.score(x_train, y_train)))
# Out:
# X_train has 6770 rows and 14 columns
# -----------------------------------
# The coefficient of determination for the test data is R2=0.65
# The coefficient of determination for the train data is R2=1.00

# %%
scores=cross_val_score(model, x_train, y_train, cv=5)
print("Cross validation scores: ", scores)
print("Score stats: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Cross validation scores:  [0.15861749 0.34148844 0.20705546 0.44916116 0.49673395]
# Score stats: 0.33 accuracy with a standard deviation of 0.13

# %%
model1 = DecisionTreeRegressor()
model2 = LinearRegression()
model3 = KNeighborsRegressor()

model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, x_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.2901123916341746, 'Linear Regression': 0.33517135075773297, 'KNN': 0.33402736251884163}
