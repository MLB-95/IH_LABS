# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

RAND_STATE = 32 # for reproducible shuffling
TT_RATIO = 0.25 # test/train

from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
data_london = pd.read_csv('data_london.csv')

# %%
data_london = data_london.drop(['Unnamed: 0'], axis=1)

# %%
from scipy import stats

# Assuming df is the name of your dataframe
z_scores = np.abs(stats.zscore(data_london))

# Remove rows where any of the columns have a z-score greater than 3
data_london_cleaned = data_london[(z_scores < 3).all(axis=1)]

# %%
data_london_cleaned.corr()
# Out:
#                              realSum  person_capacity     multi       biz  \
# realSum                     1.000000         0.580099 -0.070148  0.167625
# person_capacity             0.580099         1.000000 -0.042160  0.194056
# multi                      -0.070148        -0.042160  1.000000 -0.491027
# biz                         0.167625         0.194056 -0.491027  1.000000
# cleanliness_rating          0.041665        -0.101692  0.093483 -0.264331
# guest_satisfaction_overall -0.001627        -0.118046  0.133228 -0.385892
# bedrooms                    0.414362         0.535683  0.033034 -0.053330
# dist                       -0.325779        -0.153533  0.080218 -0.263642
# metro_dist                 -0.247571        -0.120137  0.099092 -0.282480
# attr_index_norm             0.345362         0.139969 -0.082998  0.284048
# rest_index_norm             0.377869         0.156161 -0.094130  0.309444
# lng                        -0.164613        -0.056051  0.002152 -0.026634
# lat                         0.104409         0.083750 -0.046795  0.109293
# room_shared_True                 NaN              NaN       NaN       NaN
# room_private_True          -0.625314        -0.531851  0.126649 -0.136114
# host_is_superhost_True     -0.053956        -0.096647  0.151826 -0.186626
# weekend_yes                 0.020006         0.010228  0.013211 -0.068843
#
#                             cleanliness_rating  guest_satisfaction_overall  \
# realSum                               0.041665                   -0.001627
# person_capacity                      -0.101692                   -0.118046
# multi                                 0.093483                    0.133228
# biz                                  -0.264331                   -0.385892
# cleanliness_rating                    1.000000                    0.704568
# guest_satisfaction_overall            0.704568                    1.000000
# bedrooms                              0.008246                    0.057843
# dist                                  0.088836                    0.133229
# metro_dist                            0.109104                    0.164057
# attr_index_norm                      -0.078220                   -0.130408
# rest_index_norm                      -0.093384                   -0.143159
# lng                                  -0.001820                    0.029014
# lat                                  -0.061642                   -0.050548
# room_shared_True                           NaN                         NaN
# room_private_True                     0.032427                    0.098482
# host_is_superhost_True                0.259908                    0.265213
# weekend_yes                           0.021486                    0.032393
#
#                             bedrooms      dist  metro_dist  attr_index_norm  \
# realSum                     0.414362 -0.325779   -0.247571         0.345362
# person_capacity             0.535683 -0.153533   -0.120137         0.139969
# multi                       0.033034  0.080218    0.099092        -0.082998
# biz                        -0.053330 -0.263642   -0.282480         0.284048
# cleanliness_rating          0.008246  0.088836    0.109104        -0.078220
# guest_satisfaction_overall  0.057843  0.133229    0.164057        -0.130408
# bedrooms                    1.000000 -0.007336    0.027293        -0.001897
# dist                       -0.007336  1.000000    0.531820        -0.887268
# metro_dist                  0.027293  0.531820    1.000000        -0.457272
# attr_index_norm            -0.001897 -0.887268   -0.457272         1.000000
# rest_index_norm            -0.006216 -0.873037   -0.492960         0.924298
# lng                         0.020234  0.156612    0.394785        -0.054506
# lat                         0.002321 -0.344146   -0.292986         0.222107
# room_shared_True                 NaN       NaN         NaN              NaN
# room_private_True          -0.157129  0.173051    0.158795        -0.157299
# host_is_superhost_True      0.012064  0.070199    0.059744        -0.077088
# weekend_yes                 0.011944  0.000960    0.015873        -0.005851
#
#                             rest_index_norm       lng       lat  \
# realSum                            0.377869 -0.164613  0.104409
# person_capacity                    0.156161 -0.056051  0.083750
# multi                             -0.094130  0.002152 -0.046795
# biz                                0.309444 -0.026634  0.109293
# cleanliness_rating                -0.093384 -0.001820 -0.061642
# guest_satisfaction_overall        -0.143159  0.029014 -0.050548
# bedrooms                          -0.006216  0.020234  0.002321
# dist                              -0.873037  0.156612 -0.344146
# metro_dist                        -0.492960  0.394785 -0.292986
# attr_index_norm                    0.924298 -0.054506  0.222107
# rest_index_norm                    1.000000 -0.125781  0.297031
# lng                               -0.125781  1.000000  0.181152
# lat                                0.297031  0.181152  1.000000
# room_shared_True                        NaN       NaN       NaN
# room_private_True                 -0.190901  0.155296 -0.104916
# host_is_superhost_True            -0.079858 -0.010012 -0.038854
# weekend_yes                       -0.008037  0.001382  0.004537
#
#                             room_shared_True  room_private_True  \
# realSum                                  NaN          -0.625314
# person_capacity                          NaN          -0.531851
# multi                                    NaN           0.126649
# biz                                      NaN          -0.136114
# cleanliness_rating                       NaN           0.032427
# guest_satisfaction_overall               NaN           0.098482
# bedrooms                                 NaN          -0.157129
# dist                                     NaN           0.173051
# metro_dist                               NaN           0.158795
# attr_index_norm                          NaN          -0.157299
# rest_index_norm                          NaN          -0.190901
# lng                                      NaN           0.155296
# lat                                      NaN          -0.104916
# room_shared_True                         NaN                NaN
# room_private_True                        NaN           1.000000
# host_is_superhost_True                   NaN           0.112571
# weekend_yes                              NaN          -0.027681
#
#                             host_is_superhost_True  weekend_yes
# realSum                                  -0.053956     0.020006
# person_capacity                          -0.096647     0.010228
# multi                                     0.151826     0.013211
# biz                                      -0.186626    -0.068843
# cleanliness_rating                        0.259908     0.021486
# guest_satisfaction_overall                0.265213     0.032393
# bedrooms                                  0.012064     0.011944
# dist                                      0.070199     0.000960
# metro_dist                                0.059744     0.015873
# attr_index_norm                          -0.077088    -0.005851
# rest_index_norm                          -0.079858    -0.008037
# lng                                      -0.010012     0.001382
# lat                                      -0.038854     0.004537
# room_shared_True                               NaN          NaN
# room_private_True                         0.112571    -0.027681
# host_is_superhost_True                    1.000000     0.026874
# weekend_yes                               0.026874     1.000000

# %%
data_london_cleaned_reg = data_london_cleaned.drop(['host_is_superhost_True', 'weekend_yes', 'room_shared_True', 'lng', 'lat'], axis=1)

# %%
x = data_london_cleaned_reg.drop('realSum', axis=1)
y = data_london_cleaned_reg.realSum

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TT_RATIO, random_state=RAND_STATE)
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train.describe()
# Out:
#        person_capacity        multi          biz  cleanliness_rating  \
# count      6573.000000  6573.000000  6573.000000         6573.000000
# mean          2.753994     0.277803     0.385669            9.245398
# std           1.156448     0.447950     0.486790            0.915077
# min           2.000000     0.000000     0.000000            6.000000
# 25%           2.000000     0.000000     0.000000            9.000000
# 50%           2.000000     0.000000     0.000000            9.000000
# 75%           4.000000     1.000000     1.000000           10.000000
# max           6.000000     1.000000     1.000000           10.000000
#
#        guest_satisfaction_overall     bedrooms         dist   metro_dist  \
# count                 6573.000000  6573.000000  6573.000000  6573.000000
# mean                    91.524266     1.069983     5.145430     0.811273
# std                      8.735682     0.462503     2.139717     0.796857
# min                     57.000000     0.000000     0.740000     0.010000
# 25%                     87.000000     1.000000     3.610000     0.320000
# 50%                     94.000000     1.000000     4.890000     0.520000
# 75%                     99.000000     1.000000     6.580000     0.960000
# max                    100.000000     2.000000    13.340000     4.760000
#
#        attr_index_norm  rest_index_norm  room_private_True
# count      6573.000000      6573.000000        6573.000000
# mean         19.783086        10.705587           0.579340
# std           8.887796         4.625025           0.493703
# min           6.526297         3.418707           0.000000
# 25%          12.716209         7.148735           0.000000
# 50%          17.461079         9.517477           1.000000
# 75%          24.800887        13.569344           1.000000
# max          56.178680        32.078354           1.000000

# %%
x_train_const = sm.add_constant(x_train) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.590
# Method:                 Least Squares   F-statistic:                     859.9
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:21:52   Log-Likelihood:                -41767.
# No. Observations:                6573   AIC:                         8.356e+04
# Df Residuals:                    6561   BIC:                         8.364e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       -279.3661     28.578     -9.776      0.000    -335.388    -223.344
# person_capacity               31.8440      2.169     14.685      0.000      27.593      36.095
# multi                         12.6332      4.480      2.820      0.005       3.851      21.416
# biz                           18.8010      4.661      4.034      0.000       9.664      27.938
# cleanliness_rating            15.2934      2.658      5.753      0.000      10.082      20.505
# guest_satisfaction_overall     1.5001      0.292      5.146      0.000       0.929       2.072
# bedrooms                     119.8116      4.583     26.140      0.000     110.827     128.797
# dist                          10.4438      1.904      5.485      0.000       6.711      14.176
# metro_dist                   -16.6079      2.597     -6.395      0.000     -21.699     -11.517
# attr_index_norm                1.8221      0.562      3.241      0.001       0.720       2.924
# rest_index_norm               12.4667      1.031     12.089      0.000      10.445      14.488
# room_private_True           -192.8057      4.274    -45.114      0.000    -201.184    -184.428
# ==============================================================================
# Omnibus:                     4458.695   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            97044.207
# Skew:                           2.948   Prob(JB):                         0.00
# Kurtosis:                      20.876   Cond. No.                     1.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sts = StandardScaler()

x_train_standarized = sts.fit_transform(x_train)
x_test_standarized = sts.transform(x_test)

x_train_standarized = pd.DataFrame(x_train_standarized)

# %%
x_train_const = sm.add_constant(x_train_standarized.to_numpy()) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test_standarized) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.590
# Method:                 Least Squares   F-statistic:                     859.9
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:21:52   Log-Likelihood:                -41767.
# No. Observations:                6573   AIC:                         8.356e+04
# Df Residuals:                    6561   BIC:                         8.364e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        324.0533      1.718    188.667      0.000     320.686     327.420
# x1            36.8231      2.508     14.685      0.000      31.907      41.739
# x2             5.6586      2.007      2.820      0.005       1.725       9.592
# x3             9.1515      2.269      4.034      0.000       4.704      13.599
# x4            13.9936      2.432      5.753      0.000       9.225      18.762
# x5            13.1034      2.547      5.146      0.000       8.111      18.095
# x6            55.4090      2.120     26.140      0.000      51.254      59.564
# x7            22.3450      4.074      5.485      0.000      14.359      30.331
# x8           -13.2331      2.069     -6.395      0.000     -17.289      -9.177
# x9            16.1936      4.997      3.241      0.001       6.399      25.989
# x10           57.6545      4.769     12.089      0.000      48.305      67.004
# x11          -95.1814      2.110    -45.114      0.000     -99.317     -91.046
# ==============================================================================
# Omnibus:                     4458.695   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            97044.207
# Skew:                           2.948   Prob(JB):                         0.00
# Kurtosis:                      20.876   Cond. No.                         6.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.coef_
model.intercept_
# Out:
# -279.36614908387645

# %%
model.score(x_train, y_train)
# Out:
# 0.5904523857976492

# %%
y_pred = pd.DataFrame(model.predict(x_test),columns = ['realSum'] )      # model prediction
y_pred_train =  pd.DataFrame(model.predict(x_train),columns = ['realSum'])

# %%
mse(y_test,y_pred)
# Out:
# 16508.58245320737

# %%
rmse = np.sqrt(mse(y_test,y_pred))
rmse
# Out:
# 128.48572859741026

# %%
##prediction on the train set
mse(y_train,y_pred_train)
# Out:
# 19355.88825347259

# %%
mae(y_test,y_pred)
# Out:
# 84.53392568359057

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.6220435230870284

# %%
R2_test=model.score(x_test,y_test)
R2_train=model.score(x_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
Adj_R2
# Out:
# 0.6201364032493941

# %%
model_lasso=Lasso(alpha=0.05)

model_lasso.fit(x_train, y_train)
print(f"{model_lasso.__class__.__name__}: Train -> {model_lasso.score(x_train, y_train)}, Test -> {model_lasso.score(x_test, y_test)}")
# Out:
# Lasso: Train -> 0.5904503009556363, Test -> 0.6220388331383226

# %%
model_ridge=Ridge(alpha=1000)
model_ridge.fit(x_train, y_train)
print(f"{model_ridge.__class__.__name__}: Train -> {model_ridge.score(x_train, y_train)}, Test -> {model_ridge.score(x_test, y_test)}")
# Out:
# Ridge: Train -> 0.55406360235704, Test -> 0.5800694945164202

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

print("X_train has %d rows and %d columns"  %(x_train.shape[0],x_train.shape[1]))
print("-----------------------------------")
print("The coefficient of determination for the test data is R2=%.2f"
      %(model.score(x_test, y_test)))
print("The coefficient of determination for the train data is R2=%.2f"
      %(model.score(x_train, y_train)))
# Out:
# X_train has 6573 rows and 11 columns
# -----------------------------------
# The coefficient of determination for the test data is R2=0.68
# The coefficient of determination for the train data is R2=1.00

# %%
scores=cross_val_score(model, x_train, y_train, cv=5)
print("Cross validation scores: ", scores)
print("Score stats: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Cross validation scores:  [0.58040183 0.63945509 0.6628115  0.63999352 0.54781489]
# Score stats: 0.61 accuracy with a standard deviation of 0.04

# %%
model1 = DecisionTreeRegressor()
model2 = LinearRegression()
model3 = KNeighborsRegressor()

model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, x_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.6257295987200567, 'Linear Regression': 0.5891422361872909, 'KNN': 0.5149535914020275}

# %%
data_london_cleaned.to_excel('data_london.xlsx')
