# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

RAND_STATE = 32 # for reproducible shuffling
TT_RATIO = 0.25 # test/train

from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
data_barcelona = pd.read_csv('data_barcelona.csv')

# %%
data_barcelona = data_barcelona.drop(['Unnamed: 0'], axis=1)

# %%
from scipy import stats

# Assuming df is the name of your dataframe
z_scores = np.abs(stats.zscore(data_barcelona))

# Remove rows where any of the columns have a z-score greater than 3
data_barcelona_cleaned = data_barcelona[(z_scores < 3).all(axis=1)]

# %%
data_barcelona_cleaned.corr()
# Out:
#                              realSum  person_capacity     multi       biz  \
# realSum                     1.000000         0.646489 -0.191883  0.374416
# person_capacity             0.646489         1.000000 -0.162492  0.348268
# multi                      -0.191883        -0.162492  1.000000 -0.550334
# biz                         0.374416         0.348268 -0.550334  1.000000
# cleanliness_rating          0.110072        -0.011359 -0.038589 -0.017995
# guest_satisfaction_overall  0.062784        -0.071620  0.028175 -0.148712
# bedrooms                    0.450178         0.616982 -0.094045  0.180129
# dist                       -0.212775        -0.052728  0.060266 -0.183487
# metro_dist                 -0.047858        -0.024435  0.022383 -0.080118
# attr_index_norm             0.220585         0.084639 -0.028110  0.106983
# rest_index_norm             0.169099         0.018089 -0.034094  0.138043
# lng                         0.024603        -0.035170  0.052465 -0.055360
# lat                        -0.065427         0.014067  0.016589 -0.100168
# room_shared_True                 NaN              NaN       NaN       NaN
# room_private_True          -0.677138        -0.671827  0.217021 -0.382671
# host_is_superhost_True      0.043846        -0.055013  0.061402 -0.087953
# weekend_yes                 0.040042        -0.105857  0.016708 -0.051076
#
#                             cleanliness_rating  guest_satisfaction_overall  \
# realSum                               0.110072                    0.062784
# person_capacity                      -0.011359                   -0.071620
# multi                                -0.038589                    0.028175
# biz                                  -0.017995                   -0.148712
# cleanliness_rating                    1.000000                    0.645606
# guest_satisfaction_overall            0.645606                    1.000000
# bedrooms                              0.027223                    0.013072
# dist                                  0.007404                    0.039236
# metro_dist                           -0.002667                    0.059109
# attr_index_norm                      -0.022256                   -0.016744
# rest_index_norm                      -0.017797                   -0.033591
# lng                                   0.009144                    0.054053
# lat                                   0.006569                    0.062528
# room_shared_True                           NaN                         NaN
# room_private_True                    -0.015248                    0.064843
# host_is_superhost_True                0.276839                    0.328277
# weekend_yes                           0.002426                    0.012611
#
#                             bedrooms      dist  metro_dist  attr_index_norm  \
# realSum                     0.450178 -0.212775   -0.047858         0.220585
# person_capacity             0.616982 -0.052728   -0.024435         0.084639
# multi                      -0.094045  0.060266    0.022383        -0.028110
# biz                         0.180129 -0.183487   -0.080118         0.106983
# cleanliness_rating          0.027223  0.007404   -0.002667        -0.022256
# guest_satisfaction_overall  0.013072  0.039236    0.059109        -0.016744
# bedrooms                    1.000000  0.011364    0.015238        -0.007435
# dist                        0.011364  1.000000    0.397158        -0.745695
# metro_dist                  0.015238  0.397158    1.000000        -0.341229
# attr_index_norm            -0.007435 -0.745695   -0.341229         1.000000
# rest_index_norm            -0.067380 -0.862465   -0.378648         0.810192
# lng                        -0.044948  0.070788    0.316701         0.100190
# lat                         0.045048  0.592745    0.445237        -0.293811
# room_shared_True                 NaN       NaN         NaN              NaN
# room_private_True          -0.456477  0.078870    0.031493        -0.089173
# host_is_superhost_True      0.040228  0.019555    0.009690        -0.022964
# weekend_yes                -0.082430  0.004498    0.034220         0.098303
#
#                             rest_index_norm       lng       lat  \
# realSum                            0.169099  0.024603 -0.065427
# person_capacity                    0.018089 -0.035170  0.014067
# multi                             -0.034094  0.052465  0.016589
# biz                                0.138043 -0.055360 -0.100168
# cleanliness_rating                -0.017797  0.009144  0.006569
# guest_satisfaction_overall        -0.033591  0.054053  0.062528
# bedrooms                          -0.067380 -0.044948  0.045048
# dist                              -0.862465  0.070788  0.592745
# metro_dist                        -0.378648  0.316701  0.445237
# attr_index_norm                    0.810192  0.100190 -0.293811
# rest_index_norm                    1.000000  0.049447 -0.518045
# lng                                0.049447  1.000000  0.399833
# lat                               -0.518045  0.399833  1.000000
# room_shared_True                        NaN       NaN       NaN
# room_private_True                 -0.026803  0.030761  0.013507
# host_is_superhost_True            -0.017397  0.019828  0.044825
# weekend_yes                       -0.006309  0.022628  0.024243
#
#                             room_shared_True  room_private_True  \
# realSum                                  NaN          -0.677138
# person_capacity                          NaN          -0.671827
# multi                                    NaN           0.217021
# biz                                      NaN          -0.382671
# cleanliness_rating                       NaN          -0.015248
# guest_satisfaction_overall               NaN           0.064843
# bedrooms                                 NaN          -0.456477
# dist                                     NaN           0.078870
# metro_dist                               NaN           0.031493
# attr_index_norm                          NaN          -0.089173
# rest_index_norm                          NaN          -0.026803
# lng                                      NaN           0.030761
# lat                                      NaN           0.013507
# room_shared_True                         NaN                NaN
# room_private_True                        NaN           1.000000
# host_is_superhost_True                   NaN           0.008398
# weekend_yes                              NaN           0.092126
#
#                             host_is_superhost_True  weekend_yes
# realSum                                   0.043846     0.040042
# person_capacity                          -0.055013    -0.105857
# multi                                     0.061402     0.016708
# biz                                      -0.087953    -0.051076
# cleanliness_rating                        0.276839     0.002426
# guest_satisfaction_overall                0.328277     0.012611
# bedrooms                                  0.040228    -0.082430
# dist                                      0.019555     0.004498
# metro_dist                                0.009690     0.034220
# attr_index_norm                          -0.022964     0.098303
# rest_index_norm                          -0.017397    -0.006309
# lng                                       0.019828     0.022628
# lat                                       0.044825     0.024243
# room_shared_True                               NaN          NaN
# room_private_True                         0.008398     0.092126
# host_is_superhost_True                    1.000000     0.001034
# weekend_yes                               0.001034     1.000000

# %%
data_barcelona_cleaned_reg = data_barcelona_cleaned.drop(['rest_index_norm', 'lng', 'lat', 'multi', 'metro_dist', 'room_shared_True'], axis=1)

# %%
x = data_barcelona_cleaned_reg.drop('realSum', axis=1)
y = data_barcelona_cleaned_reg.realSum

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TT_RATIO, random_state=RAND_STATE)
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train.describe()
# Out:
#        person_capacity          biz  cleanliness_rating  \
# count      1901.000000  1901.000000         1901.000000
# mean          2.490268     0.305629            9.394529
# std           1.001859     0.460794            0.772591
# min           2.000000     0.000000            7.000000
# 25%           2.000000     0.000000            9.000000
# 50%           2.000000     0.000000           10.000000
# 75%           2.000000     1.000000           10.000000
# max           6.000000     1.000000           10.000000
#
#        guest_satisfaction_overall     bedrooms         dist  attr_index_norm  \
# count                 1901.000000  1901.000000  1901.000000      1901.000000
# mean                    91.938979     1.083114     2.080531        16.167493
# std                      6.471757     0.358996     1.314313         7.820922
# min                     67.000000     0.000000     0.100000         4.602831
# 25%                     88.000000     1.000000     1.080000        10.528499
# 50%                     93.000000     1.000000     1.720000        13.995029
# 75%                     97.000000     1.000000     2.900000        21.260123
# max                    100.000000     2.000000     6.060000        45.201404
#
#        room_private_True  host_is_superhost_True  weekend_yes
# count         1901.00000             1901.000000  1901.000000
# mean             0.84324                0.185692     0.464492
# std              0.36367                0.388960     0.498869
# min              0.00000                0.000000     0.000000
# 25%              1.00000                0.000000     0.000000
# 50%              1.00000                0.000000     0.000000
# 75%              1.00000                0.000000     1.000000
# max              1.00000                1.000000     1.000000

# %%
x_train_const = sm.add_constant(x_train) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     266.7
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:15:32   Log-Likelihood:                -11541.
# No. Observations:                1901   AIC:                         2.310e+04
# Df Residuals:                    1890   BIC:                         2.317e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                        -68.7691     42.702     -1.610      0.107    -152.517      14.979
# person_capacity               48.1223      3.799     12.665      0.000      40.671      55.574
# biz                           37.7906      5.823      6.490      0.000      26.370      49.211
# cleanliness_rating            11.5112      4.145      2.777      0.006       3.382      19.640
# guest_satisfaction_overall     2.0597      0.507      4.062      0.000       1.065       3.054
# bedrooms                      28.6295      8.625      3.320      0.001      11.715      45.544
# dist                         -11.2839      2.822     -3.998      0.000     -16.819      -5.749
# attr_index_norm                1.6585      0.474      3.502      0.000       0.730       2.587
# room_private_True           -181.8101      9.267    -19.620      0.000    -199.984    -163.636
# host_is_superhost_True        14.2611      6.639      2.148      0.032       1.240      27.282
# weekend_yes                   35.2816      4.925      7.164      0.000      25.623      44.941
# ==============================================================================
# Omnibus:                     1024.841   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11611.408
# Skew:                           2.293   Prob(JB):                         0.00
# Kurtosis:                      14.205   Cond. No.                     1.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sts = StandardScaler()

x_train_standarized = sts.fit_transform(x_train)
x_test_standarized = sts.transform(x_test)

x_train_standarized = pd.DataFrame(x_train_standarized)

# %%
x_train_const = sm.add_constant(x_train_standarized.to_numpy()) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test_standarized) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     266.7
# Date:                Wed, 08 Mar 2023   Prob (F-statistic):               0.00
# Time:                        12:15:32   Log-Likelihood:                -11541.
# No. Observations:                1901   AIC:                         2.310e+04
# Df Residuals:                    1890   BIC:                         2.317e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        260.2012      2.411    107.936      0.000     255.473     264.929
# x1            48.1991      3.806     12.665      0.000      40.736      55.663
# x2            17.4091      2.682      6.490      0.000      12.148      22.670
# x3             8.8911      3.201      2.777      0.006       2.612      15.170
# x4            13.3264      3.281      4.062      0.000       6.892      19.761
# x5            10.2752      3.095      3.320      0.001       4.204      16.346
# x6           -14.8267      3.708     -3.998      0.000     -22.099      -7.554
# x7            12.9679      3.703      3.502      0.000       5.706      20.230
# x8           -66.1014      3.369    -19.620      0.000     -72.709     -59.494
# x9             5.5455      2.582      2.148      0.032       0.482      10.609
# x10           17.5963      2.456      7.164      0.000      12.779      22.414
# ==============================================================================
# Omnibus:                     1024.841   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11611.408
# Skew:                           2.293   Prob(JB):                         0.00
# Kurtosis:                      14.205   Cond. No.                         3.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.coef_
model.intercept_
# Out:
# -68.76910237401398

# %%
model.score(x_train, y_train)
# Out:
# 0.5852294048054126

# %%
y_pred = pd.DataFrame(model.predict(x_test),columns = ['realSum'] )      # model prediction
y_pred_train =  pd.DataFrame(model.predict(x_train),columns = ['realSum'])

# %%
mse(y_test,y_pred)
# Out:
# 11388.129260218931

# %%
rmse = np.sqrt(mse(y_test,y_pred))
rmse
# Out:
# 106.71517820918884

# %%
##prediction on the train set
mse(y_train,y_pred_train)
# Out:
# 10983.72445219976

# %%
mae(y_test,y_pred)
# Out:
# 70.6838539230211

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.6080748000947525

# %%
R2_test=model.score(x_test,y_test)
R2_train=model.score(x_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
Adj_R2
# Out:
# 0.6017838659068673

# %%
model_lasso=Lasso(alpha=0.05)

model_lasso.fit(x_train, y_train)
print(f"{model_lasso.__class__.__name__}: Train -> {model_lasso.score(x_train, y_train)}, Test -> {model_lasso.score(x_test, y_test)}")
# Out:
# Lasso: Train -> 0.5852264092422599, Test -> 0.6080556093289757

# %%
model_ridge=Ridge(alpha=1000)
model_ridge.fit(x_train, y_train)
print(f"{model_ridge.__class__.__name__}: Train -> {model_ridge.score(x_train, y_train)}, Test -> {model_ridge.score(x_test, y_test)}")
# Out:
# Ridge: Train -> 0.4772684411870791, Test -> 0.4785671877628479

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

print("X_train has %d rows and %d columns"  %(x_train.shape[0],x_train.shape[1]))
print("-----------------------------------")
print("The coefficient of determination for the test data is R2=%.2f"
      %(model.score(x_test, y_test)))
print("The coefficient of determination for the train data is R2=%.2f"
      %(model.score(x_train, y_train)))
# Out:
# X_train has 1901 rows and 10 columns
# -----------------------------------
# The coefficient of determination for the test data is R2=0.53
# The coefficient of determination for the train data is R2=1.00

# %%
scores=cross_val_score(model, x_train, y_train, cv=5)
print("Cross validation scores: ", scores)
print("Score stats: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Cross validation scores:  [0.19998206 0.46920105 0.25259499 0.19130944 0.53417693]
# Score stats: 0.33 accuracy with a standard deviation of 0.14

# %%
model1 = DecisionTreeRegressor()
model2 = LinearRegression()
model3 = KNeighborsRegressor()

model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, x_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': 0.32729766846533703, 'Linear Regression': 0.57480745735138, 'KNN': 0.43429060349331394}

# %%
data_barcelona_cleaned.to_excel('data_barcelona.xlsx')
