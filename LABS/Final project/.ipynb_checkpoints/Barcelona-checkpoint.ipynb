# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

RAND_STATE = 32 # for reproducible shuffling
TT_RATIO = 0.25 # test/train

from sklearn.linear_model import Lasso,Ridge,ElasticNet, LinearRegression

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
data_barcelona = pd.read_csv('data_barcelona.csv')

# %%
data_barcelona.corr()
# Out:
#                             Unnamed: 0   realSum  person_capacity     multi  \
# Unnamed: 0                    1.000000 -0.002987         0.055059 -0.005826
# realSum                      -0.002987  1.000000         0.374672 -0.150752
# person_capacity               0.055059  0.374672         1.000000 -0.185463
# multi                        -0.005826 -0.150752        -0.185463  1.000000
# biz                          -0.060303  0.261730         0.365559 -0.549697
# cleanliness_rating           -0.037052  0.015031        -0.054135  0.006367
# guest_satisfaction_overall   -0.026683 -0.025710        -0.111910  0.061617
# bedrooms                      0.069278  0.381269         0.707166 -0.129066
# dist                          0.637230 -0.036529        -0.034859  0.038117
# metro_dist                    0.372151 -0.015846        -0.005281 -0.011848
# attr_index_norm              -0.494008  0.052208         0.040612 -0.015637
# rest_index_norm              -0.560981  0.027179        -0.010480 -0.014141
# room_shared_True              0.066976 -0.031139         0.012257 -0.029277
# room_private_True            -0.003790 -0.451064        -0.709682  0.242047
# host_is_superhost_True       -0.040555  0.004984        -0.050022  0.062221
# weekend_yes                  -0.163928  0.016642        -0.133572  0.018713
#
#                                  biz  cleanliness_rating  \
# Unnamed: 0                 -0.060303           -0.037052
# realSum                     0.261730            0.015031
# person_capacity             0.365559           -0.054135
# multi                      -0.549697            0.006367
# biz                         1.000000           -0.044428
# cleanliness_rating         -0.044428            1.000000
# guest_satisfaction_overall -0.160341            0.732201
# bedrooms                    0.220420           -0.021702
# dist                       -0.169672            0.010978
# metro_dist                 -0.089270            0.001088
# attr_index_norm             0.086974           -0.002134
# rest_index_norm             0.113085           -0.013912
# room_shared_True            0.059097           -0.024104
# room_private_True          -0.413508            0.032923
# host_is_superhost_True     -0.102203            0.246626
# weekend_yes                -0.058932            0.006560
#
#                             guest_satisfaction_overall  bedrooms      dist  \
# Unnamed: 0                                   -0.026683  0.069278  0.637230
# realSum                                      -0.025710  0.381269 -0.036529
# person_capacity                              -0.111910  0.707166 -0.034859
# multi                                         0.061617 -0.129066  0.038117
# biz                                          -0.160341  0.220420 -0.169672
# cleanliness_rating                            0.732201 -0.021702  0.010978
# guest_satisfaction_overall                    1.000000 -0.051238  0.025465
# bedrooms                                     -0.051238  1.000000  0.032257
# dist                                          0.025465  0.032257  1.000000
# metro_dist                                    0.038496  0.028804  0.431923
# attr_index_norm                               0.010253 -0.037039 -0.650339
# rest_index_norm                              -0.012203 -0.086784 -0.826475
# room_shared_True                             -0.013458 -0.020350  0.082276
# room_private_True                             0.107597 -0.545034  0.057327
# host_is_superhost_True                        0.290455  0.019638  0.041585
# weekend_yes                                   0.023048 -0.118212 -0.000266
#
#                             metro_dist  attr_index_norm  rest_index_norm  \
# Unnamed: 0                    0.372151        -0.494008        -0.560981
# realSum                      -0.015846         0.052208         0.027179
# person_capacity              -0.005281         0.040612        -0.010480
# multi                        -0.011848        -0.015637        -0.014141
# biz                          -0.089270         0.086974         0.113085
# cleanliness_rating            0.001088        -0.002134        -0.013912
# guest_satisfaction_overall    0.038496         0.010253        -0.012203
# bedrooms                      0.028804        -0.037039        -0.086784
# dist                          0.431923        -0.650339        -0.826475
# metro_dist                    1.000000        -0.357704        -0.387814
# attr_index_norm              -0.357704         1.000000         0.713502
# rest_index_norm              -0.387814         0.713502         1.000000
# room_shared_True              0.044411        -0.035533        -0.047715
# room_private_True             0.017559        -0.057524         0.003171
# host_is_superhost_True        0.069735        -0.038965        -0.039624
# weekend_yes                   0.024707         0.093130         0.006071
#
#                             room_shared_True  room_private_True  \
# Unnamed: 0                          0.066976          -0.003790
# realSum                            -0.031139          -0.451064
# person_capacity                     0.012257          -0.709682
# multi                              -0.029277           0.242047
# biz                                 0.059097          -0.413508
# cleanliness_rating                 -0.024104           0.032923
# guest_satisfaction_overall         -0.013458           0.107597
# bedrooms                           -0.020350          -0.545034
# dist                                0.082276           0.057327
# metro_dist                          0.044411           0.017559
# attr_index_norm                    -0.035533          -0.057524
# rest_index_norm                    -0.047715           0.003171
# room_shared_True                    1.000000          -0.132284
# room_private_True                  -0.132284           1.000000
# host_is_superhost_True             -0.016602           0.017352
# weekend_yes                        -0.015437           0.117891
#
#                             host_is_superhost_True  weekend_yes
# Unnamed: 0                               -0.040555    -0.163928
# realSum                                   0.004984     0.016642
# person_capacity                          -0.050022    -0.133572
# multi                                     0.062221     0.018713
# biz                                      -0.102203    -0.058932
# cleanliness_rating                        0.246626     0.006560
# guest_satisfaction_overall                0.290455     0.023048
# bedrooms                                  0.019638    -0.118212
# dist                                      0.041585    -0.000266
# metro_dist                                0.069735     0.024707
# attr_index_norm                          -0.038965     0.093130
# rest_index_norm                          -0.039624     0.006071
# room_shared_True                         -0.016602    -0.015437
# room_private_True                         0.017352     0.117891
# host_is_superhost_True                    1.000000     0.002077
# weekend_yes                               0.002077     1.000000

# %%
data_barcelona = data_barcelona.drop(['Unnamed: 0', 'multi', 'cleanliness_rating', 'guest_satisfaction_overall'], axis=1)

# %%
x = data_barcelona.drop('realSum', axis=1)
y = data_barcelona.realSum

# %%
# test-train split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=TT_RATIO, random_state=RAND_STATE)
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
x_train.describe()
# Out:
#        person_capacity        multi          biz  cleanliness_rating  \
# count      2124.000000  2124.000000  2124.000000          2124.00000
# mean          2.619115     0.386535     0.320151             9.30838
# std           1.159219     0.487070     0.466644             1.02144
# min           2.000000     0.000000     0.000000             2.00000
# 25%           2.000000     0.000000     0.000000             9.00000
# 50%           2.000000     0.000000     0.000000            10.00000
# 75%           3.000000     1.000000     1.000000            10.00000
# max           6.000000     1.000000     1.000000            10.00000
#
#        guest_satisfaction_overall     bedrooms         dist   metro_dist  \
# count                 2124.000000  2124.000000  2124.000000  2124.000000
# mean                    91.228343     1.164783     2.119449     0.441064
# std                      8.626610     0.524629     1.366240     0.275174
# min                     20.000000     0.000000     0.100000     0.010000
# 25%                     88.000000     1.000000     1.087500     0.260000
# 50%                     93.000000     1.000000     1.750000     0.380000
# 75%                     97.000000     1.000000     2.985000     0.560000
# max                    100.000000     6.000000     8.440000     2.400000
#
#        attr_index_norm  rest_index_norm  room_shared_True  room_private_True  \
# count      2124.000000      2124.000000       2124.000000        2124.000000
# mean         16.648806        19.300803          0.003296           0.805085
# std           9.809536        10.162773          0.057327           0.396229
# min           3.197553         3.518471          0.000000           0.000000
# 25%          10.156094        10.733975          0.000000           1.000000
# 50%          14.007060        17.630011          0.000000           1.000000
# 75%          21.368794        26.692060          0.000000           1.000000
# max         100.000000       100.000000          1.000000           1.000000
#
#        host_is_superhost_True  weekend_yes
# count             2124.000000  2124.000000
# mean                 0.185970     0.451036
# std                  0.389174     0.497714
# min                  0.000000     0.000000
# 25%                  0.000000     0.000000
# 50%                  0.000000     0.000000
# 75%                  0.000000     1.000000
# max                  1.000000     1.000000

# %%
x_train_const = sm.add_constant(x_train) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.298
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     64.01
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):          9.60e-151
# Time:                        16:56:32   Log-Likelihood:                -14776.
# No. Observations:                2124   AIC:                         2.958e+04
# Df Residuals:                    2109   BIC:                         2.967e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                        114.6530     79.970      1.434      0.152     -42.174     271.480
# person_capacity               19.6292      8.401      2.336      0.020       3.154      36.105
# multi                         -5.8423     13.608     -0.429      0.668     -32.528      20.844
# biz                           54.8713     15.589      3.520      0.000      24.299      85.444
# cleanliness_rating             5.7734      8.012      0.721      0.471      -9.940      21.486
# guest_satisfaction_overall     0.7156      0.972      0.736      0.462      -1.190       2.622
# bedrooms                      89.4954     15.426      5.802      0.000      59.243     119.748
# dist                          10.9124      7.634      1.430      0.153      -4.058      25.882
# metro_dist                    -7.1139     22.418     -0.317      0.751     -51.077      36.849
# attr_index_norm                0.0801      0.820      0.098      0.922      -1.527       1.687
# rest_index_norm                2.4968      1.092      2.286      0.022       0.355       4.639
# room_shared_True            -371.5991     98.597     -3.769      0.000    -564.957    -178.241
# room_private_True           -265.4348     20.997    -12.641      0.000    -306.612    -224.257
# host_is_superhost_True        24.3652     14.968      1.628      0.104      -4.989      53.719
# weekend_yes                   56.1723     11.385      4.934      0.000      33.846      78.499
# ==============================================================================
# Omnibus:                     4408.091   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14578599.129
# Skew:                          17.117   Prob(JB):                         0.00
# Kurtosis:                     407.423   Cond. No.                     1.71e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sts = StandardScaler()

x_train_standarized = sts.fit_transform(x_train)
x_test_standarized = sts.transform(x_test)

x_train_standarized = pd.DataFrame(x_train_standarized)

# %%
x_train_const = sm.add_constant(x_train_standarized.to_numpy()) # adding a constant

model = sm.OLS(y_train, x_train_const).fit()
predictions_train = model.predict(x_train_const)

x_test_const = sm.add_constant(x_test_standarized) # adding a constant
predictions_test = model.predict(x_test_const)
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                realSum   R-squared:                       0.298
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     64.01
# Date:                Mon, 06 Mar 2023   Prob (F-statistic):          9.60e-151
# Time:                        16:56:32   Log-Likelihood:                -14776.
# No. Observations:                2124   AIC:                         2.958e+04
# Df Residuals:                    2109   BIC:                         2.967e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        289.0973      5.534     52.241      0.000     278.245     299.950
# x1            22.7492      9.736      2.336      0.020       3.655      41.843
# x2            -2.8449      6.626     -0.429      0.668     -15.840      10.150
# x3            25.5994      7.273      3.520      0.000      11.336      39.862
# x4             5.8958      8.182      0.721      0.471     -10.150      21.942
# x5             6.1715      8.382      0.736      0.462     -10.266      22.609
# x6            46.9409      8.091      5.802      0.000      31.073      62.808
# x7            14.9055     10.427      1.430      0.153      -5.542      35.353
# x8            -1.9571      6.167     -0.317      0.751     -14.052      10.138
# x9             0.7858      8.038      0.098      0.922     -14.977      16.549
# x10           25.3688     11.098      2.286      0.022       3.604      47.134
# x11          -21.2975      5.651     -3.769      0.000     -32.380     -10.216
# x12         -105.1481      8.318    -12.641      0.000    -121.460     -88.836
# x13            9.4801      5.824      1.628      0.104      -1.941      20.901
# x14           27.9512      5.665      4.934      0.000      16.842      39.061
# ==============================================================================
# Omnibus:                     4408.091   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14578599.129
# Skew:                          17.117   Prob(JB):                         0.00
# Kurtosis:                     407.423   Cond. No.                         4.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm = LinearRegression()
model = lm.fit(x_train,y_train)
model.coef_
model.intercept_
# Out:
# 114.65302299144432

# %%
model.score(x_train, y_train)
# Out:
# 0.2981877720075553

# %%
y_pred = pd.DataFrame(model.predict(x_test),columns = ['realSum'] )      # model prediction
y_pred_train =  pd.DataFrame(model.predict(x_train),columns = ['realSum'])

# %%
mse(y_test,y_pred)
# Out:
# 186869.79275498993

# %%
rmse = np.sqrt(mse(y_test,y_pred))
rmse
# Out:
# 432.28438874772

# %%
##prediction on the train set
mse(y_train,y_pred_train)
# Out:
# 64586.46309713628

# %%
mae(y_test,y_pred)
# Out:
# 109.31135150333394

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.18312799026315563

# %%
R2_test=model.score(x_test,y_test)
R2_train=model.score(x_train,y_train)
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
Adj_R2
# Out:
# 0.16664930418777257

# %%
model_lasso=Lasso(alpha=0.05)

model_lasso.fit(x_train, y_train)
print(f"{model_lasso.__class__.__name__}: Train -> {model_lasso.score(x_train, y_train)}, Test -> {model_lasso.score(x_test, y_test)}")
# Out:
# Lasso: Train -> 0.29817746106661125, Test -> 0.18287599024837053

# %%
model_ridge=Ridge(alpha=1000)
model_ridge.fit(x_train, y_train)
print(f"{model_ridge.__class__.__name__}: Train -> {model_ridge.score(x_train, y_train)}, Test -> {model_ridge.score(x_test, y_test)}")
# Out:
# Ridge: Train -> 0.2388995522066346, Test -> 0.1070185948902942

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

print("X_train has %d rows and %d columns"  %(x_train.shape[0],x_train.shape[1]))
print("-----------------------------------")
print("The coefficient of determination for the test data is R2=%.2f"
      %(model.score(x_test, y_test)))
print("The coefficient of determination for the train data is R2=%.2f"
      %(model.score(x_train, y_train)))
# Out:
# X_train has 2124 rows and 14 columns
# -----------------------------------
# The coefficient of determination for the test data is R2=0.46
# The coefficient of determination for the train data is R2=1.00

# %%
scores=cross_val_score(model, x_train, y_train, cv=5)
print("Cross validation scores: ", scores)
print("Score stats: %0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# Cross validation scores:  [-0.92543602  0.02425679  0.11539419 -2.95130829 -0.2191104 ]
# Score stats: -0.79 accuracy with a standard deviation of 1.14

# %%
model1 = DecisionTreeRegressor()
model2 = LinearRegression()
model3 = KNeighborsRegressor()

model_pipeline = [model1, model2, model3]
model_names = ['Regression Tree', 'Linear Regression', 'KNN']
scores = {}
i=0
for model in model_pipeline:
    mean_score = np.mean(cross_val_score(model, x_train, y_train, cv=5))
    scores[model_names[i]] = mean_score
    i = i+1
print(scores)
# Out:
# {'Regression Tree': -0.7543981621248406, 'Linear Regression': 0.34572275290162313, 'KNN': 0.13101368952511014}
