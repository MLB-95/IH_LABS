# %%
import pandas as pd
import numpy as np

# %%
amsterdam_weekend = pd.read_csv("Data/Amsterdam_Weekends.csv")

# %%
barcelona_weekend = pd.read_csv("Data/Barcelona_Weekends.csv")

# %%
barcelona_weekend
# Out:
#       Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0              0  532.036214  Entire home/apt        False         False
# 1              1  169.897829     Private room        False          True
# 2              2  196.895292     Private room        False          True
# 3              3  141.271208     Private room        False          True
# 4              4  715.200037  Entire home/apt        False         False
# ...          ...         ...              ...          ...           ...
# 1273        1273  327.460609     Private room        False          True
# 1274        1274  242.977169     Private room        False          True
# 1275        1275  138.943841     Private room        False          True
# 1276        1276  185.258454     Private room        False          True
# 1277        1277  254.614006     Private room        False          True
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                 4.0              False      0    1                10.0
# 1                 2.0               True      1    0                10.0
# 2                 2.0              False      1    0                 9.0
# 3                 3.0              False      0    1                 9.0
# 4                 4.0               True      0    1                 9.0
# ...               ...                ...    ...  ...                 ...
# 1273              2.0               True      0    0                 9.0
# 1274              2.0              False      0    0                 9.0
# 1275              2.0              False      0    0                10.0
# 1276              2.0              False      0    0                 2.0
# 1277              2.0              False      0    0                10.0
#
#       guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# 0                           91.0         1  1.111998    0.630504  526.471472
# 1                           88.0         1  1.751831    0.124013  320.128264
# 2                           90.0         1  0.621731    0.297516  503.354025
# 3                           86.0         1  1.648311    0.089442  342.595820
# 4                           95.0         2  0.693560    0.357653  537.803135
# ...                          ...       ...       ...         ...         ...
# 1273                        96.0         1  2.608873    0.932342  271.642736
# 1274                        80.0         0  1.859134    0.555944  343.045595
# 1275                        96.0         2  2.670450    0.968673  266.091811
# 1276                        60.0         1  2.266090    0.387429  290.526738
# 1277                       100.0         1  2.394845    0.954950  284.900718
#
#       attr_index_norm   rest_index  rest_index_norm      lng       lat
# 0           20.327672   915.591455        20.112468  2.17556  41.39624
# 1           12.360522   794.279660        17.447656  2.14906  41.38714
# 2           19.435081  1242.434221        27.292106  2.16500  41.38300
# 3           13.228021   820.921958        18.032897  2.15342  41.37912
# 4           20.765201  1081.560116        23.758242  2.17498  41.39214
# ...               ...          ...              ...      ...       ...
# 1273        10.488440   537.512628        11.807347  2.19672  41.39929
# 1274        13.245387   679.561854        14.927691  2.19099  41.39269
# 1275        10.274112   534.080063        11.731945  2.19738  41.39954
# 1276        11.217573   627.521382        13.784536  2.19679  41.39029
# 1277        11.000346   564.678656        12.404093  2.19590  41.39637
#
# [1278 rows x 20 columns]

# %%
athens_weekend = pd.read_csv("Data/Athens_Weekends.csv")

# %%
london_weekend = pd.read_csv("Data/London_Weekends.csv")

# %%
berlin_weekend = pd.read_csv("Data/Berlin_Weekends.csv")

# %%
budapest_weekend = pd.read_csv("Data/Budapest_Weekends.csv")

# %%
lisbon_weekend = pd.read_csv("Data/Lisbon_Weekends.csv")

# %%
paris_weekend = pd.read_csv("Data/Paris_Weekends.csv")

# %%
rome_weekend = pd.read_csv("Data/Rome_Weekends.csv")

# %%
vienna_weekend = pd.read_csv("Data/Vienna_Weekends.csv")

# %%
weekend_data = pd.concat((amsterdam_weekend, berlin_weekend, barcelona_weekend, london_weekend, budapest_weekend, lisbon_weekend, paris_weekend, rome_weekend, vienna_weekend, athens_weekend))

# %%
weekend_data
# Out:
#       Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0              0   319.640053     Private room        False          True
# 1              1   347.995219     Private room        False          True
# 2              2   482.975183     Private room        False          True
# 3              3   485.552926     Private room        False          True
# 4              4  2771.541724  Entire home/apt        False         False
# ...          ...          ...              ...          ...           ...
# 2622        2622    74.051508  Entire home/apt        False         False
# 2623        2623   295.737351  Entire home/apt        False         False
# 2624        2624   169.193635  Entire home/apt        False         False
# 2625        2625   160.991728  Entire home/apt        False         False
# 2626        2626   192.393317  Entire home/apt        False         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                 2.0              False      0    1                 9.0
# 1                 2.0              False      0    1                 9.0
# 2                 4.0              False      0    1                 9.0
# 3                 2.0               True      0    0                10.0
# 4                 4.0               True      0    0                10.0
# ...               ...                ...    ...  ...                 ...
# 2622              3.0               True      0    0                10.0
# 2623              4.0               True      0    1                10.0
# 2624              4.0               True      0    1                10.0
# 2625              4.0               True      1    0                10.0
# 2626              4.0              False      0    1                10.0
#
#       guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# 0                           88.0         1  4.763360    0.852117  110.906123
# 1                           87.0         1  5.748310    3.651591   75.275937
# 2                           90.0         2  0.384872    0.439852  493.272517
# 3                           98.0         1  0.544723    0.318688  552.849514
# 4                          100.0         3  1.686798    1.458399  208.809162
# ...                          ...       ...       ...         ...         ...
# 2622                        98.0         1  3.311976    1.856865   49.097725
# 2623                       100.0         1  1.800556    0.571033  146.240703
# 2624                        99.0         2  3.845100    0.786416   42.260382
# 2625                       100.0         1  4.827460    0.141952   35.700540
# 2626                        99.0         1  1.776319    0.317120  107.126909
#
#       attr_index_norm  rest_index  rest_index_norm       lng       lat
# 0            5.871971  136.982208        11.941560   4.84639  52.34137
# 1            3.985516   95.386468         8.315410   4.97512  52.36103
# 2           26.116521  875.114817        76.289005   4.89417  52.37663
# 3           29.270850  815.303994        71.074937   4.90051  52.37508
# 4           11.055489  272.315202        23.739349   4.88467  52.38749
# ...               ...         ...              ...       ...       ...
# 2622         1.849891   71.119758         1.062098  23.75000  38.00306
# 2623         5.510019  203.884287         3.044796  23.71500  37.97400
# 2624         1.592276   60.948754         0.910205  23.76657  37.99986
# 2625         1.345116   52.659912         0.786420  23.73300  38.01900
# 2626         4.036300  149.191222         2.228013  23.72863  37.99064
#
# [26207 rows x 20 columns]

# %%
weekend_data['weekend'] = ('yes')

# %%
weekend_data['weekend'].value_counts()
# Out:
# yes    26207
# Name: weekend, dtype: int64

# %%
weekdays = pd.concat(map(pd.read_csv, ["Data/Rome_Weekdays.csv", "Data/Berlin_Weekdays.csv", "Data/London_Weekdays.csv", "Data/Lisbon_Weekdays.csv", "Data/Amsterdam_Weekdays.csv", "Data/Barcelona_Weekdays.csv", "Data/Budapest_Weekdays.csv", "Data/Athens_Weekdays.csv", "Data/Vienna_Weekdays.csv"]))

# %%
weekdays['weekend'] = ('no')

# %%
weekdays
# Out:
#       Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0              0  156.874664     Private room        False          True
# 1              1  172.772543     Private room        False          True
# 2              2  277.745307  Entire home/apt        False         False
# 3              3  444.906834  Entire home/apt        False         False
# 4              4  131.391298     Private room        False          True
# ...          ...         ...              ...          ...           ...
# 1733        1733  219.012224  Entire home/apt        False         False
# 1734        1734  191.197438  Entire home/apt        False         False
# 1735        1735  251.501765  Entire home/apt        False         False
# 1736        1736  637.636444  Entire home/apt        False         False
# 1737        1737  133.230489     Private room        False          True
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0                 2.0               True      1    0                10.0  ...
# 1                 2.0              False      1    0                 9.0  ...
# 2                 4.0              False      0    1                 9.0  ...
# 3                 6.0              False      1    0                 9.0  ...
# 4                 3.0              False      1    0                 9.0  ...
# ...               ...                ...    ...  ...                 ...  ...
# 1733              4.0              False      0    0                 8.0  ...
# 1734              4.0              False      0    1                10.0  ...
# 1735              2.0              False      0    0                 8.0  ...
# 1736              2.0              False      0    0                10.0  ...
# 1737              4.0               True      1    0                10.0  ...
#
#       bedrooms      dist  metro_dist  attr_index  attr_index_norm  \
# 0            1  2.978468    1.595733  281.163932         6.230648
# 1            1  0.935371    0.649269  482.707193        10.696887
# 2            1  2.203025    0.494697  691.708998        15.328408
# 3            2  2.703010    1.295153  805.592641        17.852092
# 4            1  1.295968    0.867455  317.076369         7.026475
# ...        ...       ...         ...         ...              ...
# 1733         0  0.298179    0.257904  851.189543        60.958556
# 1734         2  1.052982    0.332054  195.654600        14.011946
# 1735         1  0.810224    0.100844  204.967222        14.678876
# 1736         1  0.994039    0.202537  169.074867        12.108419
# 1737         1  1.263948    0.480922  150.449976        10.774584
#
#        rest_index  rest_index_norm       lng       lat  weekend
# 0      697.727246        15.191486  12.48654  41.92498       no
# 1     1251.524333        27.249208  12.49627  41.90801       no
# 2     1625.897266        35.400361  12.47700  41.90700       no
# 3     2035.819533        44.325522  12.46969  41.90019       no
# 4      836.622814        18.215634  12.51544  41.89463       no
# ...           ...              ...       ...       ...      ...
# 1733   593.167136        14.180090  16.37766  48.20875       no
# 1734   305.781569         7.309930  16.37892  48.19973       no
# 1735   342.177253         8.179995  16.38070  48.20296       no
# 1736   282.299117         6.748565  16.38568  48.20460       no
# 1737   225.245048         5.384646  16.39066  48.20811       no
#
# [22370 rows x 21 columns]

# %%
data = pd.concat((weekdays, weekend_data))

# %%
data.drop(['lng', 'Unnamed: 0', 'lat'], axis=1, inplace=True)

# %%
data.get_dummy(['room_type', 'room_shared', 'room_private', 'host_is_superhost', 'weekend'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7692\1489775826.py in <module>
# ----> 1 data.get_dummy(['room_type', 'room_shared', 'room_private', 'host_is_superhost', 'weekend'], drop_first=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dummy'
