# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

results = sp.search(q="Blue Moon",limit=3, market='DE')
results
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['external_urls']["spotify"]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Blue+Moon&type=track&market=DE&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#        'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#        'id': '1YzCsTRb22dQkh9lghPIrp',
#        'name': 'Billie Holiday',
#        'type': 'artist',
#        'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4izD3SCRElbkO06i8yf4Zp'},
#      'href': 'https://api.spotify.com/v1/albums/4izD3SCRElbkO06i8yf4Zp',
#      'id': '4izD3SCRElbkO06i8yf4Zp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334708df3636189370a12e6c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234708df3636189370a12e6c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134708df3636189370a12e6c1',
#        'width': 64}],
#      'name': 'Solitude',
#      'release_date': '1956-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4izD3SCRElbkO06i8yf4Zp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#       'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#       'id': '1YzCsTRb22dQkh9lghPIrp',
#       'name': 'Billie Holiday',
#       'type': 'artist',
#       'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#     'disc_number': 1,
#     'duration_ms': 207826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USPR35200069'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1pZn8AX1WulW8IO338hE5D'},
#     'href': 'https://api.spotify.com/v1/tracks/1pZn8AX1WulW8IO338hE5D',
#     'id': '1pZn8AX1WulW8IO338hE5D',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Blue Moon',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d9bb36a07327a08774bcef97789ef494214b3505?cid=b95275128a104b84aeadfa666320994b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1pZn8AX1WulW8IO338hE5D'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WK3H9OErSn5zKOkOV5egm'},
#        'href': 'https://api.spotify.com/v1/artists/0WK3H9OErSn5zKOkOV5egm',
#        'id': '0WK3H9OErSn5zKOkOV5egm',
#        'name': 'DDG',
#        'type': 'artist',
#        'uri': 'spotify:artist:0WK3H9OErSn5zKOkOV5egm'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5hhgghBFkLDdMn93GW4x3I'},
#        'href': 'https://api.spotify.com/v1/artists/5hhgghBFkLDdMn93GW4x3I',
#        'id': '5hhgghBFkLDdMn93GW4x3I',
#        'name': 'OG Parker',
#        'type': 'artist',
#        'uri': 'spotify:artist:5hhgghBFkLDdMn93GW4x3I'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4TzzpYnIMI8opSO9koKKVG'},
#      'href': 'https://api.spotify.com/v1/albums/4TzzpYnIMI8opSO9koKKVG',
#      'id': '4TzzpYnIMI8opSO9koKKVG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739ea849484864329633574323',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029ea849484864329633574323',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519ea849484864329633574323',
#        'width': 64}],
#      'name': 'Die 4 Respect',
#      'release_date': '2021-06-15',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4TzzpYnIMI8opSO9koKKVG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WK3H9OErSn5zKOkOV5egm'},
#       'href': 'https://api.spotify.com/v1/artists/0WK3H9OErSn5zKOkOV5egm',
#       'id': '0WK3H9OErSn5zKOkOV5egm',
#       'name': 'DDG',
#       'type': 'artist',
#       'uri': 'spotify:artist:0WK3H9OErSn5zKOkOV5egm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fl1V19tmjt57oBdxXKAjJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Fl1V19tmjt57oBdxXKAjJ',
#       'id': '3Fl1V19tmjt57oBdxXKAjJ',
#       'name': 'Blueface',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Fl1V19tmjt57oBdxXKAjJ'}],
#     'disc_number': 1,
#     'duration_ms': 170232,
#     'explicit': True,
#     'external_ids': {'isrc': 'CA5KR2079526'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/73xjJ1TIE6WP3HNKczQE4F'},
#     'href': 'https://api.spotify.com/v1/tracks/73xjJ1TIE6WP3HNKczQE4F',
#     'id': '73xjJ1TIE6WP3HNKczQE4F',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Moonwalking in Calabasas (feat. Blueface) - Remix',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/82ae773febc5937a9105a1201e835be13c1969d7?cid=b95275128a104b84aeadfa666320994b',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:73xjJ1TIE6WP3HNKczQE4F'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#        'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#        'id': '3qUMmh5biaB5hqpF4LqS3m',
#        'name': 'Julie London',
#        'type': 'artist',
#        'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0PXtSUifcfNg45o3FOEg31'},
#      'href': 'https://api.spotify.com/v1/albums/0PXtSUifcfNg45o3FOEg31',
#      'id': '0PXtSUifcfNg45o3FOEg31',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362fe7a67cbbe41760eef88dd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262fe7a67cbbe41760eef88dd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162fe7a67cbbe41760eef88dd',
#        'width': 64}],
#      'name': 'Julie Is Her Name, Vol. 2',
#      'release_date': '1958',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0PXtSUifcfNg45o3FOEg31'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#       'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#       'id': '3qUMmh5biaB5hqpF4LqS3m',
#       'name': 'Julie London',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#     'disc_number': 1,
#     'duration_ms': 153253,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA25800334'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5qfEAELRtcWyKjaheHHWQb'},
#     'href': 'https://api.spotify.com/v1/tracks/5qfEAELRtcWyKjaheHHWQb',
#     'id': '5qfEAELRtcWyKjaheHHWQb',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Blue Moon',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a62d8f95b5dd110af50a4585606ad7270fd8295f?cid=b95275128a104b84aeadfa666320994b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5qfEAELRtcWyKjaheHHWQb'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=Blue+Moon&type=track&market=DE&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
results["tracks"]["items"][0]["artists"][0]["id"]
# Out:
# '1YzCsTRb22dQkh9lghPIrp'

# %%
results["tracks"]["items"][0]["artists"][0]["href"]
# Out:
# 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp'

# %%
results["tracks"]["items"][0]["external_urls"]["spotify"]
# Out:
# 'https://open.spotify.com/track/1pZn8AX1WulW8IO338hE5D'

# %%
results["tracks"]["items"][0]["id"]
# Out:
# '1pZn8AX1WulW8IO338hE5D'

# %%
#https://open.spotify.com/playlist/37i9dQZF1DWV7EzJMK2FUI

# %%
from IPython.display import IFrame

# %%
track_id = '1pZn8AX1WulW8IO338hE5D'

IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1pZn8AX1WulW8IO338hE5D?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Blue+Moon&type=track&market=ES&offset=0&limit=3',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#                                               'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#                                               'id': '1YzCsTRb22dQkh9lghPIrp',
#                                               'name': 'Billie Holiday',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4izD3SCRElbkO06i8yf4Zp'},
#                                  'href': 'https://api.spotify.com/v1/albums/4izD3SCRElbkO06i8yf4Zp',
#                                  'id': '4izD3SCRElbkO06i8yf4Zp',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27334708df3636189370a12e6c1',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0234708df3636189370a12e6c1',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485134708df3636189370a12e6c1',
#                                              'width': 64}],
#                                  'name': 'Solitude',
#                                  'release_date': '1956-01-01',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 12,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4izD3SCRElbkO06i8yf4Zp'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#                                     'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#                                     'id': '1YzCsTRb22dQkh9lghPIrp',
#                                     'name': 'Billie Holiday',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#                        'disc_number': 1,
#                        'duration_ms': 207826,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USPR35200069'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1pZn8AX1WulW8IO338hE5D'},
#                        'href': 'https://api.spotify.com/v1/tracks/1pZn8AX1WulW8IO338hE5D',
#                        'id': '1pZn8AX1WulW8IO338hE5D',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Blue Moon',
#                        'popularity': 60,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/d9bb36a07327a08774bcef97789ef494214b3505?cid=b95275128a104b84aeadfa666320994b',
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:1pZn8AX1WulW8IO338hE5D'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uothxMWeLWIhsGeF7cyo4'},
#                                               'href': 'https://api.spotify.com/v1/artists/6uothxMWeLWIhsGeF7cyo4',
#                                               'id': '6uothxMWeLWIhsGeF7cyo4',
#                                               'name': 'Enya',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6uothxMWeLWIhsGeF7cyo4'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6ZuPbMe6CvQKl1nvAy0nZm'},
#                                  'href': 'https://api.spotify.com/v1/albums/6ZuPbMe6CvQKl1nvAy0nZm',
#                                  'id': '6ZuPbMe6CvQKl1nvAy0nZm',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2733184c671068d02838d47b277',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e023184c671068d02838d47b277',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048513184c671068d02838d47b277',
#                                              'width': 64}],
#                                  'name': 'Shepherd Moons',
#                                  'release_date': '1991-11-15',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 15,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6ZuPbMe6CvQKl1nvAy0nZm'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uothxMWeLWIhsGeF7cyo4'},
#                                     'href': 'https://api.spotify.com/v1/artists/6uothxMWeLWIhsGeF7cyo4',
#                                     'id': '6uothxMWeLWIhsGeF7cyo4',
#                                     'name': 'Enya',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6uothxMWeLWIhsGeF7cyo4'}],
#                        'disc_number': 1,
#                        'duration_ms': 239586,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBAHT0900019'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5KZ4DC772dYcRBAizx0yYk'},
#                        'href': 'https://api.spotify.com/v1/tracks/5KZ4DC772dYcRBAizx0yYk',
#                        'id': '5KZ4DC772dYcRBAizx0yYk',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Caribbean Blue - 2009 Remaster',
#                        'popularity': 60,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/652851a16ef37611c4a34d5ef7e647fc0f7f29b0?cid=b95275128a104b84aeadfa666320994b',
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:5KZ4DC772dYcRBAizx0yYk'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#                                               'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#                                               'id': '3qUMmh5biaB5hqpF4LqS3m',
#                                               'name': 'Julie London',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/0PXtSUifcfNg45o3FOEg31'},
#                                  'href': 'https://api.spotify.com/v1/albums/0PXtSUifcfNg45o3FOEg31',
#                                  'id': '0PXtSUifcfNg45o3FOEg31',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27362fe7a67cbbe41760eef88dd',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0262fe7a67cbbe41760eef88dd',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485162fe7a67cbbe41760eef88dd',
#                                              'width': 64}],
#                                  'name': 'Julie Is Her Name, Vol. 2',
#                                  'release_date': '1958',
#                                  'release_date_precision': 'year',
#                                  'total_tracks': 12,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:0PXtSUifcfNg45o3FOEg31'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#                                     'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#                                     'id': '3qUMmh5biaB5hqpF4LqS3m',
#                                     'name': 'Julie London',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#                        'disc_number': 1,
#                        'duration_ms': 153253,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USCA25800334'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5qfEAELRtcWyKjaheHHWQb'},
#                        'href': 'https://api.spotify.com/v1/tracks/5qfEAELRtcWyKjaheHHWQb',
#                        'id': '5qfEAELRtcWyKjaheHHWQb',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Blue Moon',
#                        'popularity': 56,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/a62d8f95b5dd110af50a4585606ad7270fd8295f?cid=b95275128a104b84aeadfa666320994b',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:5qfEAELRtcWyKjaheHHWQb'}],
#             'limit': 3,
#             'next': 'https://api.spotify.com/v1/search?query=Blue+Moon&type=track&market=ES&offset=3&limit=3',
#             'offset': 0,
#             'previous': None,
#             'total': 1000}}

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#     'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#     'id': '1YzCsTRb22dQkh9lghPIrp',
#     'name': 'Billie Holiday',
#     'type': 'artist',
#     'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4izD3SCRElbkO06i8yf4Zp'},
#   'href': 'https://api.spotify.com/v1/albums/4izD3SCRElbkO06i8yf4Zp',
#   'id': '4izD3SCRElbkO06i8yf4Zp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27334708df3636189370a12e6c1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0234708df3636189370a12e6c1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485134708df3636189370a12e6c1',
#     'width': 64}],
#   'name': 'Solitude',
#   'release_date': '1956-01-01',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:4izD3SCRElbkO06i8yf4Zp'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#    'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#    'id': '1YzCsTRb22dQkh9lghPIrp',
#    'name': 'Billie Holiday',
#    'type': 'artist',
#    'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#  'disc_number': 1,
#  'duration_ms': 207826,
#  'explicit': False,
#  'external_ids': {'isrc': 'USPR35200069'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1pZn8AX1WulW8IO338hE5D'},
#  'href': 'https://api.spotify.com/v1/tracks/1pZn8AX1WulW8IO338hE5D',
#  'id': '1pZn8AX1WulW8IO338hE5D',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Blue Moon',
#  'popularity': 60,
#  'preview_url': 'https://p.scdn.co/mp3-preview/d9bb36a07327a08774bcef97789ef494214b3505?cid=b95275128a104b84aeadfa666320994b',
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:1pZn8AX1WulW8IO338hE5D'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# Get track id

# %%
results['tracks']['items'][0]['id']
# Out:
# '1pZn8AX1WulW8IO338hE5D'

# %%
import pandas as pd

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'Blue Moon' and the id is: 1pZn8AX1WulW8IO338hE5D
# The name of song is: 'Caribbean Blue - 2009 Remaster' and the id is: 5KZ4DC772dYcRBAizx0yYk
# The name of song is: 'Blue Moon' and the id is: 5qfEAELRtcWyKjaheHHWQb

# %%
song = sp.search(q="Blue Moon", limit=3,market="DE") 
song
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Blue+Moon&type=track&market=DE&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#        'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#        'id': '1YzCsTRb22dQkh9lghPIrp',
#        'name': 'Billie Holiday',
#        'type': 'artist',
#        'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4izD3SCRElbkO06i8yf4Zp'},
#      'href': 'https://api.spotify.com/v1/albums/4izD3SCRElbkO06i8yf4Zp',
#      'id': '4izD3SCRElbkO06i8yf4Zp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334708df3636189370a12e6c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234708df3636189370a12e6c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134708df3636189370a12e6c1',
#        'width': 64}],
#      'name': 'Solitude',
#      'release_date': '1956-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4izD3SCRElbkO06i8yf4Zp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#       'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#       'id': '1YzCsTRb22dQkh9lghPIrp',
#       'name': 'Billie Holiday',
#       'type': 'artist',
#       'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#     'disc_number': 1,
#     'duration_ms': 207826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USPR35200069'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1pZn8AX1WulW8IO338hE5D'},
#     'href': 'https://api.spotify.com/v1/tracks/1pZn8AX1WulW8IO338hE5D',
#     'id': '1pZn8AX1WulW8IO338hE5D',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Blue Moon',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d9bb36a07327a08774bcef97789ef494214b3505?cid=b95275128a104b84aeadfa666320994b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1pZn8AX1WulW8IO338hE5D'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WK3H9OErSn5zKOkOV5egm'},
#        'href': 'https://api.spotify.com/v1/artists/0WK3H9OErSn5zKOkOV5egm',
#        'id': '0WK3H9OErSn5zKOkOV5egm',
#        'name': 'DDG',
#        'type': 'artist',
#        'uri': 'spotify:artist:0WK3H9OErSn5zKOkOV5egm'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5hhgghBFkLDdMn93GW4x3I'},
#        'href': 'https://api.spotify.com/v1/artists/5hhgghBFkLDdMn93GW4x3I',
#        'id': '5hhgghBFkLDdMn93GW4x3I',
#        'name': 'OG Parker',
#        'type': 'artist',
#        'uri': 'spotify:artist:5hhgghBFkLDdMn93GW4x3I'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4TzzpYnIMI8opSO9koKKVG'},
#      'href': 'https://api.spotify.com/v1/albums/4TzzpYnIMI8opSO9koKKVG',
#      'id': '4TzzpYnIMI8opSO9koKKVG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739ea849484864329633574323',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029ea849484864329633574323',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519ea849484864329633574323',
#        'width': 64}],
#      'name': 'Die 4 Respect',
#      'release_date': '2021-06-15',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4TzzpYnIMI8opSO9koKKVG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WK3H9OErSn5zKOkOV5egm'},
#       'href': 'https://api.spotify.com/v1/artists/0WK3H9OErSn5zKOkOV5egm',
#       'id': '0WK3H9OErSn5zKOkOV5egm',
#       'name': 'DDG',
#       'type': 'artist',
#       'uri': 'spotify:artist:0WK3H9OErSn5zKOkOV5egm'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fl1V19tmjt57oBdxXKAjJ'},
#       'href': 'https://api.spotify.com/v1/artists/3Fl1V19tmjt57oBdxXKAjJ',
#       'id': '3Fl1V19tmjt57oBdxXKAjJ',
#       'name': 'Blueface',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Fl1V19tmjt57oBdxXKAjJ'}],
#     'disc_number': 1,
#     'duration_ms': 170232,
#     'explicit': True,
#     'external_ids': {'isrc': 'CA5KR2079526'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/73xjJ1TIE6WP3HNKczQE4F'},
#     'href': 'https://api.spotify.com/v1/tracks/73xjJ1TIE6WP3HNKczQE4F',
#     'id': '73xjJ1TIE6WP3HNKczQE4F',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Moonwalking in Calabasas (feat. Blueface) - Remix',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/82ae773febc5937a9105a1201e835be13c1969d7?cid=b95275128a104b84aeadfa666320994b',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:73xjJ1TIE6WP3HNKczQE4F'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#        'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#        'id': '3qUMmh5biaB5hqpF4LqS3m',
#        'name': 'Julie London',
#        'type': 'artist',
#        'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0PXtSUifcfNg45o3FOEg31'},
#      'href': 'https://api.spotify.com/v1/albums/0PXtSUifcfNg45o3FOEg31',
#      'id': '0PXtSUifcfNg45o3FOEg31',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362fe7a67cbbe41760eef88dd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262fe7a67cbbe41760eef88dd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162fe7a67cbbe41760eef88dd',
#        'width': 64}],
#      'name': 'Julie Is Her Name, Vol. 2',
#      'release_date': '1958',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0PXtSUifcfNg45o3FOEg31'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#       'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#       'id': '3qUMmh5biaB5hqpF4LqS3m',
#       'name': 'Julie London',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#     'disc_number': 1,
#     'duration_ms': 153253,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA25800334'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5qfEAELRtcWyKjaheHHWQb'},
#     'href': 'https://api.spotify.com/v1/tracks/5qfEAELRtcWyKjaheHHWQb',
#     'id': '5qfEAELRtcWyKjaheHHWQb',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Blue Moon',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a62d8f95b5dd110af50a4585606ad7270fd8295f?cid=b95275128a104b84aeadfa666320994b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5qfEAELRtcWyKjaheHHWQb'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=Blue+Moon&type=track&market=DE&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
song["tracks"]["items"][2]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#     'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#     'id': '3qUMmh5biaB5hqpF4LqS3m',
#     'name': 'Julie London',
#     'type': 'artist',
#     'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0PXtSUifcfNg45o3FOEg31'},
#   'href': 'https://api.spotify.com/v1/albums/0PXtSUifcfNg45o3FOEg31',
#   'id': '0PXtSUifcfNg45o3FOEg31',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27362fe7a67cbbe41760eef88dd',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0262fe7a67cbbe41760eef88dd',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485162fe7a67cbbe41760eef88dd',
#     'width': 64}],
#   'name': 'Julie Is Her Name, Vol. 2',
#   'release_date': '1958',
#   'release_date_precision': 'year',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:0PXtSUifcfNg45o3FOEg31'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#    'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#    'id': '3qUMmh5biaB5hqpF4LqS3m',
#    'name': 'Julie London',
#    'type': 'artist',
#    'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#  'disc_number': 1,
#  'duration_ms': 153253,
#  'explicit': False,
#  'external_ids': {'isrc': 'USCA25800334'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5qfEAELRtcWyKjaheHHWQb'},
#  'href': 'https://api.spotify.com/v1/tracks/5qfEAELRtcWyKjaheHHWQb',
#  'id': '5qfEAELRtcWyKjaheHHWQb',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Blue Moon',
#  'popularity': 56,
#  'preview_url': 'https://p.scdn.co/mp3-preview/a62d8f95b5dd110af50a4585606ad7270fd8295f?cid=b95275128a104b84aeadfa666320994b',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:5qfEAELRtcWyKjaheHHWQb'}

# %%
jazz_playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DWV7EzJMK2FUI",market="DE")

# %%
jazz_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV7EzJMK2FUI/tracks?offset=0&limit=100&market=DE&additional_types=track',
#  'items': [{'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vmN5DgVFk2GDBHDu1ZJeb'},
#        'href': 'https://api.spotify.com/v1/artists/4vmN5DgVFk2GDBHDu1ZJeb',
#        'id': '4vmN5DgVFk2GDBHDu1ZJeb',
#        'name': 'The Groove Trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:4vmN5DgVFk2GDBHDu1ZJeb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63Y51ZVDizFQyxA8znmmbn'},
#      'href': 'https://api.spotify.com/v1/albums/63Y51ZVDizFQyxA8znmmbn',
#      'id': '63Y51ZVDizFQyxA8znmmbn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736abf1b888ce307bb6b15669c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026abf1b888ce307bb6b15669c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516abf1b888ce307bb6b15669c',
#        'width': 64}],
#      'name': 'Life in Space',
#      'release_date': '2022-11-20',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:63Y51ZVDizFQyxA8znmmbn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vmN5DgVFk2GDBHDu1ZJeb'},
#       'href': 'https://api.spotify.com/v1/artists/4vmN5DgVFk2GDBHDu1ZJeb',
#       'id': '4vmN5DgVFk2GDBHDu1ZJeb',
#       'name': 'The Groove Trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:4vmN5DgVFk2GDBHDu1ZJeb'}],
#     'disc_number': 1,
#     'duration_ms': 183776,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZAKB2208501'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4SPtyeZCNeiPsquKP8B8ip'},
#     'href': 'https://api.spotify.com/v1/tracks/4SPtyeZCNeiPsquKP8B8ip',
#     'id': '4SPtyeZCNeiPsquKP8B8ip',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Barney's",
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b5e9ade22eb220a9f3f39c667a6941f7fbe3eb87?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4SPtyeZCNeiPsquKP8B8ip'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Rk4ZISv9eXs3Thg7rco7h'},
#        'href': 'https://api.spotify.com/v1/artists/0Rk4ZISv9eXs3Thg7rco7h',
#        'id': '0Rk4ZISv9eXs3Thg7rco7h',
#        'name': 'The Three Queens',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Rk4ZISv9eXs3Thg7rco7h'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0mQjoCyVFtEqpTbNjahd8J'},
#      'href': 'https://api.spotify.com/v1/albums/0mQjoCyVFtEqpTbNjahd8J',
#      'id': '0mQjoCyVFtEqpTbNjahd8J',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739c86a1429e9265b389bc2ccf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029c86a1429e9265b389bc2ccf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519c86a1429e9265b389bc2ccf',
#        'width': 64}],
#      'name': 'Muddy Trail',
#      'release_date': '2023-01-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0mQjoCyVFtEqpTbNjahd8J'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Rk4ZISv9eXs3Thg7rco7h'},
#       'href': 'https://api.spotify.com/v1/artists/0Rk4ZISv9eXs3Thg7rco7h',
#       'id': '0Rk4ZISv9eXs3Thg7rco7h',
#       'name': 'The Three Queens',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Rk4ZISv9eXs3Thg7rco7h'}],
#     'disc_number': 1,
#     'duration_ms': 220879,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEXGF2203869'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7xi4NE5HjjIU4sjk2OP466'},
#     'href': 'https://api.spotify.com/v1/tracks/7xi4NE5HjjIU4sjk2OP466',
#     'id': '7xi4NE5HjjIU4sjk2OP466',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Muddy Trail',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e47788552fbc0269e32a5da50874bfb785af9ca7?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7xi4NE5HjjIU4sjk2OP466'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nr44rcCUJR2qL0SKfCOYF'},
#        'href': 'https://api.spotify.com/v1/artists/1nr44rcCUJR2qL0SKfCOYF',
#        'id': '1nr44rcCUJR2qL0SKfCOYF',
#        'name': 'Figgy Mold',
#        'type': 'artist',
#        'uri': 'spotify:artist:1nr44rcCUJR2qL0SKfCOYF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5kICb2TJOeFRTCvJsI1ldJ'},
#      'href': 'https://api.spotify.com/v1/albums/5kICb2TJOeFRTCvJsI1ldJ',
#      'id': '5kICb2TJOeFRTCvJsI1ldJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27368c3413293607105f9f03503',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0268c3413293607105f9f03503',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485168c3413293607105f9f03503',
#        'width': 64}],
#      'name': 'All My Tomorrows',
#      'release_date': '2023-01-06',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5kICb2TJOeFRTCvJsI1ldJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1nr44rcCUJR2qL0SKfCOYF'},
#       'href': 'https://api.spotify.com/v1/artists/1nr44rcCUJR2qL0SKfCOYF',
#       'id': '1nr44rcCUJR2qL0SKfCOYF',
#       'name': 'Figgy Mold',
#       'type': 'artist',
#       'uri': 'spotify:artist:1nr44rcCUJR2qL0SKfCOYF'}],
#     'disc_number': 1,
#     'duration_ms': 201515,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB2300006'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4WnBYBYzYhS2I838VTxhaN'},
#     'href': 'https://api.spotify.com/v1/tracks/4WnBYBYzYhS2I838VTxhaN',
#     'id': '4WnBYBYzYhS2I838VTxhaN',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'All My Tomorrows',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5337eda3ca77f4036ce3afaf09a60e92db4982c2?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4WnBYBYzYhS2I838VTxhaN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xgSoGgPQpQvOK5XOyoOAm'},
#        'href': 'https://api.spotify.com/v1/artists/3xgSoGgPQpQvOK5XOyoOAm',
#        'id': '3xgSoGgPQpQvOK5XOyoOAm',
#        'name': 'Meadow Park',
#        'type': 'artist',
#        'uri': 'spotify:artist:3xgSoGgPQpQvOK5XOyoOAm'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7KckOMQ11H9HTjolar2ch7'},
#      'href': 'https://api.spotify.com/v1/albums/7KckOMQ11H9HTjolar2ch7',
#      'id': '7KckOMQ11H9HTjolar2ch7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27325041fd22ad58af94b04207c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0225041fd22ad58af94b04207c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485125041fd22ad58af94b04207c',
#        'width': 64}],
#      'name': 'Without A Song',
#      'release_date': '2022-09-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7KckOMQ11H9HTjolar2ch7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xgSoGgPQpQvOK5XOyoOAm'},
#       'href': 'https://api.spotify.com/v1/artists/3xgSoGgPQpQvOK5XOyoOAm',
#       'id': '3xgSoGgPQpQvOK5XOyoOAm',
#       'name': 'Meadow Park',
#       'type': 'artist',
#       'uri': 'spotify:artist:3xgSoGgPQpQvOK5XOyoOAm'}],
#     'disc_number': 1,
#     'duration_ms': 236785,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32202955'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1nsMASRDWwUwlBMmOuh80d'},
#     'href': 'https://api.spotify.com/v1/tracks/1nsMASRDWwUwlBMmOuh80d',
#     'id': '1nsMASRDWwUwlBMmOuh80d',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Without A Song',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8cca8200b0826f03d34a65013d60bc8f71b98aaf?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1nsMASRDWwUwlBMmOuh80d'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7b5QwOkTlJ9LVWJfofwAWV'},
#        'href': 'https://api.spotify.com/v1/artists/7b5QwOkTlJ9LVWJfofwAWV',
#        'id': '7b5QwOkTlJ9LVWJfofwAWV',
#        'name': 'The Southern Belle',
#        'type': 'artist',
#        'uri': 'spotify:artist:7b5QwOkTlJ9LVWJfofwAWV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2L8LchgYAzo2n0vuR5kYk7'},
#      'href': 'https://api.spotify.com/v1/albums/2L8LchgYAzo2n0vuR5kYk7',
#      'id': '2L8LchgYAzo2n0vuR5kYk7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b2be365358bd0c890e967796',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b2be365358bd0c890e967796',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b2be365358bd0c890e967796',
#        'width': 64}],
#      'name': 'Fools Rush In',
#      'release_date': '2022-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:2L8LchgYAzo2n0vuR5kYk7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7b5QwOkTlJ9LVWJfofwAWV'},
#       'href': 'https://api.spotify.com/v1/artists/7b5QwOkTlJ9LVWJfofwAWV',
#       'id': '7b5QwOkTlJ9LVWJfofwAWV',
#       'name': 'The Southern Belle',
#       'type': 'artist',
#       'uri': 'spotify:artist:7b5QwOkTlJ9LVWJfofwAWV'}],
#     'disc_number': 1,
#     'duration_ms': 273123,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32204637'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1POSSxzIB7fLcHDDfbmjDZ'},
#     'href': 'https://api.spotify.com/v1/tracks/1POSSxzIB7fLcHDDfbmjDZ',
#     'id': '1POSSxzIB7fLcHDDfbmjDZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fools Rush In',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f74534b257bac324757d30b71a9d5d6ed2a1d109?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1POSSxzIB7fLcHDDfbmjDZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CerxxaCrkjDa5ShjsTwcX'},
#        'href': 'https://api.spotify.com/v1/artists/5CerxxaCrkjDa5ShjsTwcX',
#        'id': '5CerxxaCrkjDa5ShjsTwcX',
#        'name': 'Al Fowler Trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:5CerxxaCrkjDa5ShjsTwcX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4cSn217ednrXznxx6lIKvA'},
#      'href': 'https://api.spotify.com/v1/albums/4cSn217ednrXznxx6lIKvA',
#      'id': '4cSn217ednrXznxx6lIKvA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273df9ee82e6788665019b60c71',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02df9ee82e6788665019b60c71',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851df9ee82e6788665019b60c71',
#        'width': 64}],
#      'name': 'Prelude To A Kiss',
#      'release_date': '2022-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4cSn217ednrXznxx6lIKvA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CerxxaCrkjDa5ShjsTwcX'},
#       'href': 'https://api.spotify.com/v1/artists/5CerxxaCrkjDa5ShjsTwcX',
#       'id': '5CerxxaCrkjDa5ShjsTwcX',
#       'name': 'Al Fowler Trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:5CerxxaCrkjDa5ShjsTwcX'}],
#     'disc_number': 1,
#     'duration_ms': 275743,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32203102'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Csbgu7LMDGPLjhPgHfQmZ'},
#     'href': 'https://api.spotify.com/v1/tracks/4Csbgu7LMDGPLjhPgHfQmZ',
#     'id': '4Csbgu7LMDGPLjhPgHfQmZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Prelude To A Kiss',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8f84ae0fd0f16ea31d850fa23567af5a9a9b0275?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4Csbgu7LMDGPLjhPgHfQmZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5puwAFDyA8ztu2yucgdWKY'},
#        'href': 'https://api.spotify.com/v1/artists/5puwAFDyA8ztu2yucgdWKY',
#        'id': '5puwAFDyA8ztu2yucgdWKY',
#        'name': 'The Central Park North',
#        'type': 'artist',
#        'uri': 'spotify:artist:5puwAFDyA8ztu2yucgdWKY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2U3BM2wzkqr0aKtZm4bNyP'},
#      'href': 'https://api.spotify.com/v1/albums/2U3BM2wzkqr0aKtZm4bNyP',
#      'id': '2U3BM2wzkqr0aKtZm4bNyP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eabc49b42f6681e70f25d6a7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eabc49b42f6681e70f25d6a7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eabc49b42f6681e70f25d6a7',
#        'width': 64}],
#      'name': 'Twenty Somethings',
#      'release_date': '2022-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2U3BM2wzkqr0aKtZm4bNyP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5puwAFDyA8ztu2yucgdWKY'},
#       'href': 'https://api.spotify.com/v1/artists/5puwAFDyA8ztu2yucgdWKY',
#       'id': '5puwAFDyA8ztu2yucgdWKY',
#       'name': 'The Central Park North',
#       'type': 'artist',
#       'uri': 'spotify:artist:5puwAFDyA8ztu2yucgdWKY'}],
#     'disc_number': 1,
#     'duration_ms': 152695,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32293602'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4eaogpCx2UNkKylwlDNGJ7'},
#     'href': 'https://api.spotify.com/v1/tracks/4eaogpCx2UNkKylwlDNGJ7',
#     'id': '4eaogpCx2UNkKylwlDNGJ7',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Twenty Somethings',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bb074d4b39e1007a5f3e0b85374dd877d07f2ad8?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4eaogpCx2UNkKylwlDNGJ7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HwmLSofJhnA1bdPIREqAj'},
#        'href': 'https://api.spotify.com/v1/artists/3HwmLSofJhnA1bdPIREqAj',
#        'id': '3HwmLSofJhnA1bdPIREqAj',
#        'name': 'Cole Peers trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:3HwmLSofJhnA1bdPIREqAj'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2uSWzyGyq7Iw3pVgQtjytr'},
#      'href': 'https://api.spotify.com/v1/albums/2uSWzyGyq7Iw3pVgQtjytr',
#      'id': '2uSWzyGyq7Iw3pVgQtjytr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a8273b5fa7d856e3e0e4b3e8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a8273b5fa7d856e3e0e4b3e8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a8273b5fa7d856e3e0e4b3e8',
#        'width': 64}],
#      'name': 'Home town',
#      'release_date': '2023-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2uSWzyGyq7Iw3pVgQtjytr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3HwmLSofJhnA1bdPIREqAj'},
#       'href': 'https://api.spotify.com/v1/artists/3HwmLSofJhnA1bdPIREqAj',
#       'id': '3HwmLSofJhnA1bdPIREqAj',
#       'name': 'Cole Peers trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:3HwmLSofJhnA1bdPIREqAj'}],
#     'disc_number': 1,
#     'duration_ms': 178250,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEXGF2300186'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/26UQyr3L71oAnXQIJf18gr'},
#     'href': 'https://api.spotify.com/v1/tracks/26UQyr3L71oAnXQIJf18gr',
#     'id': '26UQyr3L71oAnXQIJf18gr',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Home town',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fa20171891f5fbe02bf62f9bd950242ef2abb863?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:26UQyr3L71oAnXQIJf18gr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bucqt2BrsK6W5p1H4Edu4'},
#        'href': 'https://api.spotify.com/v1/artists/2bucqt2BrsK6W5p1H4Edu4',
#        'id': '2bucqt2BrsK6W5p1H4Edu4',
#        'name': 'Madeleine West',
#        'type': 'artist',
#        'uri': 'spotify:artist:2bucqt2BrsK6W5p1H4Edu4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3gDtm0TuOChwQxe1sg1W9q'},
#      'href': 'https://api.spotify.com/v1/albums/3gDtm0TuOChwQxe1sg1W9q',
#      'id': '3gDtm0TuOChwQxe1sg1W9q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f460c78cc33de820bfb4ede',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f460c78cc33de820bfb4ede',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f460c78cc33de820bfb4ede',
#        'width': 64}],
#      'name': 'Sometime Ago',
#      'release_date': '2022-08-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3gDtm0TuOChwQxe1sg1W9q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bucqt2BrsK6W5p1H4Edu4'},
#       'href': 'https://api.spotify.com/v1/artists/2bucqt2BrsK6W5p1H4Edu4',
#       'id': '2bucqt2BrsK6W5p1H4Edu4',
#       'name': 'Madeleine West',
#       'type': 'artist',
#       'uri': 'spotify:artist:2bucqt2BrsK6W5p1H4Edu4'}],
#     'disc_number': 1,
#     'duration_ms': 160919,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32202702'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6HZgxhesyOy8jkTiAFfQmR'},
#     'href': 'https://api.spotify.com/v1/tracks/6HZgxhesyOy8jkTiAFfQmR',
#     'id': '6HZgxhesyOy8jkTiAFfQmR',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sometime Ago',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5aa4ee1e8c77133fbdf1a33a641d49458a780ae4?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6HZgxhesyOy8jkTiAFfQmR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7z19cN47vHnay3CoShIp1b'},
#        'href': 'https://api.spotify.com/v1/artists/7z19cN47vHnay3CoShIp1b',
#        'id': '7z19cN47vHnay3CoShIp1b',
#        'name': 'South North',
#        'type': 'artist',
#        'uri': 'spotify:artist:7z19cN47vHnay3CoShIp1b'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BIs50usgDMHmPBj63mtk6'},
#      'href': 'https://api.spotify.com/v1/albums/0BIs50usgDMHmPBj63mtk6',
#      'id': '0BIs50usgDMHmPBj63mtk6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27324ac8aee1d77f61698851900',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0224ac8aee1d77f61698851900',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485124ac8aee1d77f61698851900',
#        'width': 64}],
#      'name': 'The next day',
#      'release_date': '2023-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0BIs50usgDMHmPBj63mtk6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7z19cN47vHnay3CoShIp1b'},
#       'href': 'https://api.spotify.com/v1/artists/7z19cN47vHnay3CoShIp1b',
#       'id': '7z19cN47vHnay3CoShIp1b',
#       'name': 'South North',
#       'type': 'artist',
#       'uri': 'spotify:artist:7z19cN47vHnay3CoShIp1b'}],
#     'disc_number': 1,
#     'duration_ms': 133419,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32300047'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3HBNf1kBZB3Sn4idl26aJK'},
#     'href': 'https://api.spotify.com/v1/tracks/3HBNf1kBZB3Sn4idl26aJK',
#     'id': '3HBNf1kBZB3Sn4idl26aJK',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The next day',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0d511e68d412808f6f97d5a2b12952db21d8633a?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3HBNf1kBZB3Sn4idl26aJK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kzntvfEnEvuhMeA3IcaZi'},
#        'href': 'https://api.spotify.com/v1/artists/1kzntvfEnEvuhMeA3IcaZi',
#        'id': '1kzntvfEnEvuhMeA3IcaZi',
#        'name': 'Mino Conte & Co',
#        'type': 'artist',
#        'uri': 'spotify:artist:1kzntvfEnEvuhMeA3IcaZi'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4LYUSTQLCYtx3DZTfsXFly'},
#      'href': 'https://api.spotify.com/v1/albums/4LYUSTQLCYtx3DZTfsXFly',
#      'id': '4LYUSTQLCYtx3DZTfsXFly',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b034b693e1d6ae485a81be21',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b034b693e1d6ae485a81be21',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b034b693e1d6ae485a81be21',
#        'width': 64}],
#      'name': 'The Fate of Love',
#      'release_date': '2023-01-19',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4LYUSTQLCYtx3DZTfsXFly'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1kzntvfEnEvuhMeA3IcaZi'},
#       'href': 'https://api.spotify.com/v1/artists/1kzntvfEnEvuhMeA3IcaZi',
#       'id': '1kzntvfEnEvuhMeA3IcaZi',
#       'name': 'Mino Conte & Co',
#       'type': 'artist',
#       'uri': 'spotify:artist:1kzntvfEnEvuhMeA3IcaZi'}],
#     'disc_number': 1,
#     'duration_ms': 170177,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB2300120'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/59VY0huVKd5pSuJLI9RrMO'},
#     'href': 'https://api.spotify.com/v1/tracks/59VY0huVKd5pSuJLI9RrMO',
#     'id': '59VY0huVKd5pSuJLI9RrMO',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Fate of Love',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ade77b4c4a43945966bf3d3f39b11f0969527508?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:59VY0huVKd5pSuJLI9RrMO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/33hLFARszQC3uxE93PiNeE'},
#        'href': 'https://api.spotify.com/v1/artists/33hLFARszQC3uxE93PiNeE',
#        'id': '33hLFARszQC3uxE93PiNeE',
#        'name': 'Newington Green',
#        'type': 'artist',
#        'uri': 'spotify:artist:33hLFARszQC3uxE93PiNeE'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/30OyjkGuNWO3QGGtlcjZw3'},
#      'href': 'https://api.spotify.com/v1/albums/30OyjkGuNWO3QGGtlcjZw3',
#      'id': '30OyjkGuNWO3QGGtlcjZw3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737b09c80511632b0d5e65ceee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027b09c80511632b0d5e65ceee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517b09c80511632b0d5e65ceee',
#        'width': 64}],
#      'name': "Let's go uptown",
#      'release_date': '2023-01-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:30OyjkGuNWO3QGGtlcjZw3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/33hLFARszQC3uxE93PiNeE'},
#       'href': 'https://api.spotify.com/v1/artists/33hLFARszQC3uxE93PiNeE',
#       'id': '33hLFARszQC3uxE93PiNeE',
#       'name': 'Newington Green',
#       'type': 'artist',
#       'uri': 'spotify:artist:33hLFARszQC3uxE93PiNeE'}],
#     'disc_number': 1,
#     'duration_ms': 140648,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB2300012'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4zYPDHYsvTdUMMy8gRkBAA'},
#     'href': 'https://api.spotify.com/v1/tracks/4zYPDHYsvTdUMMy8gRkBAA',
#     'id': '4zYPDHYsvTdUMMy8gRkBAA',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Let's go uptown",
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/248a4782b8d4ccdd05689c62d3cc105e8aad7a49?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4zYPDHYsvTdUMMy8gRkBAA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e2ZpZDumV9AabK9rxpIUg'},
#        'href': 'https://api.spotify.com/v1/artists/6e2ZpZDumV9AabK9rxpIUg',
#        'id': '6e2ZpZDumV9AabK9rxpIUg',
#        'name': 'Arta Porting',
#        'type': 'artist',
#        'uri': 'spotify:artist:6e2ZpZDumV9AabK9rxpIUg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5uyJnjft5UrYelzlatQxJH'},
#      'href': 'https://api.spotify.com/v1/albums/5uyJnjft5UrYelzlatQxJH',
#      'id': '5uyJnjft5UrYelzlatQxJH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eddcd21cb8ca03a6cea67965',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eddcd21cb8ca03a6cea67965',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eddcd21cb8ca03a6cea67965',
#        'width': 64}],
#      'name': 'Beautiful Sunrise',
#      'release_date': '2023-01-29',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:5uyJnjft5UrYelzlatQxJH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e2ZpZDumV9AabK9rxpIUg'},
#       'href': 'https://api.spotify.com/v1/artists/6e2ZpZDumV9AabK9rxpIUg',
#       'id': '6e2ZpZDumV9AabK9rxpIUg',
#       'name': 'Arta Porting',
#       'type': 'artist',
#       'uri': 'spotify:artist:6e2ZpZDumV9AabK9rxpIUg'}],
#     'disc_number': 1,
#     'duration_ms': 291319,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZAKB2313390'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6vtzBYf1I2Ozsdp94A2t5i'},
#     'href': 'https://api.spotify.com/v1/tracks/6vtzBYf1I2Ozsdp94A2t5i',
#     'id': '6vtzBYf1I2Ozsdp94A2t5i',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Beautiful Sunrise',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a204dc8701d132fa6872a3db47a4d9530a58977a?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6vtzBYf1I2Ozsdp94A2t5i'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tUSGipRrxvpmZgUc13rd4'},
#        'href': 'https://api.spotify.com/v1/artists/3tUSGipRrxvpmZgUc13rd4',
#        'id': '3tUSGipRrxvpmZgUc13rd4',
#        'name': 'Mayfare Trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:3tUSGipRrxvpmZgUc13rd4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1bfAtOefGFjr2k6eQicSzJ'},
#      'href': 'https://api.spotify.com/v1/albums/1bfAtOefGFjr2k6eQicSzJ',
#      'id': '1bfAtOefGFjr2k6eQicSzJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737a48ec85759125ee2726d234',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027a48ec85759125ee2726d234',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517a48ec85759125ee2726d234',
#        'width': 64}],
#      'name': 'Autumn In New York',
#      'release_date': '2022-09-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1bfAtOefGFjr2k6eQicSzJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tUSGipRrxvpmZgUc13rd4'},
#       'href': 'https://api.spotify.com/v1/artists/3tUSGipRrxvpmZgUc13rd4',
#       'id': '3tUSGipRrxvpmZgUc13rd4',
#       'name': 'Mayfare Trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tUSGipRrxvpmZgUc13rd4'}],
#     'disc_number': 1,
#     'duration_ms': 259678,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32203232'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/62FrtiVepyS9UGfcTPhu7W'},
#     'href': 'https://api.spotify.com/v1/tracks/62FrtiVepyS9UGfcTPhu7W',
#     'id': '62FrtiVepyS9UGfcTPhu7W',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Autumn In New York',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/224dabd2cd004373bee9899ea396b4075a038199?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:62FrtiVepyS9UGfcTPhu7W'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TOpL8dUMkZ1oydrBsfuWf'},
#        'href': 'https://api.spotify.com/v1/artists/4TOpL8dUMkZ1oydrBsfuWf',
#        'id': '4TOpL8dUMkZ1oydrBsfuWf',
#        'name': 'Magpie Jazz Trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:4TOpL8dUMkZ1oydrBsfuWf'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4by10y5bBBZtlfRzUicL60'},
#      'href': 'https://api.spotify.com/v1/albums/4by10y5bBBZtlfRzUicL60',
#      'id': '4by10y5bBBZtlfRzUicL60',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eaf784b6dd51e62cc2e07ede',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eaf784b6dd51e62cc2e07ede',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eaf784b6dd51e62cc2e07ede',
#        'width': 64}],
#      'name': 'Love To Be Happy',
#      'release_date': '2022-10-09',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4by10y5bBBZtlfRzUicL60'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TOpL8dUMkZ1oydrBsfuWf'},
#       'href': 'https://api.spotify.com/v1/artists/4TOpL8dUMkZ1oydrBsfuWf',
#       'id': '4TOpL8dUMkZ1oydrBsfuWf',
#       'name': 'Magpie Jazz Trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:4TOpL8dUMkZ1oydrBsfuWf'}],
#     'disc_number': 1,
#     'duration_ms': 195276,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZAKB2200927'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3wMe1lySKxJeH9iMWXDqgx'},
#     'href': 'https://api.spotify.com/v1/tracks/3wMe1lySKxJeH9iMWXDqgx',
#     'id': '3wMe1lySKxJeH9iMWXDqgx',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Love To Be Happy',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3f7dc9b06a3ef5a99f53485e9feb5bf434cda78c?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3wMe1lySKxJeH9iMWXDqgx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2PmIl3LOJlfzGgWvxrj1Hd'},
#        'href': 'https://api.spotify.com/v1/artists/2PmIl3LOJlfzGgWvxrj1Hd',
#        'id': '2PmIl3LOJlfzGgWvxrj1Hd',
#        'name': 'The Lyon Hearts',
#        'type': 'artist',
#        'uri': 'spotify:artist:2PmIl3LOJlfzGgWvxrj1Hd'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7EOxOqItUbFeCrlC4xxgfR'},
#      'href': 'https://api.spotify.com/v1/albums/7EOxOqItUbFeCrlC4xxgfR',
#      'id': '7EOxOqItUbFeCrlC4xxgfR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d3c36077ea005f9569db6482',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d3c36077ea005f9569db6482',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d3c36077ea005f9569db6482',
#        'width': 64}],
#      'name': 'Banks of Noon',
#      'release_date': '2022-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7EOxOqItUbFeCrlC4xxgfR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2PmIl3LOJlfzGgWvxrj1Hd'},
#       'href': 'https://api.spotify.com/v1/artists/2PmIl3LOJlfzGgWvxrj1Hd',
#       'id': '2PmIl3LOJlfzGgWvxrj1Hd',
#       'name': 'The Lyon Hearts',
#       'type': 'artist',
#       'uri': 'spotify:artist:2PmIl3LOJlfzGgWvxrj1Hd'}],
#     'disc_number': 1,
#     'duration_ms': 215085,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEXGF2203082'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2HriYFonV6QkhctkB8DMxY'},
#     'href': 'https://api.spotify.com/v1/tracks/2HriYFonV6QkhctkB8DMxY',
#     'id': '2HriYFonV6QkhctkB8DMxY',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Banks of Noon',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/523bc09e404b74be20892f00f02d102e33b576ae?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2HriYFonV6QkhctkB8DMxY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vlyMzroosYUjkAfHLx6kF'},
#        'href': 'https://api.spotify.com/v1/artists/0vlyMzroosYUjkAfHLx6kF',
#        'id': '0vlyMzroosYUjkAfHLx6kF',
#        'name': "Pimm's Trio",
#        'type': 'artist',
#        'uri': 'spotify:artist:0vlyMzroosYUjkAfHLx6kF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ce6IAUlzsEe7elxVkRZqc'},
#      'href': 'https://api.spotify.com/v1/albums/4ce6IAUlzsEe7elxVkRZqc',
#      'id': '4ce6IAUlzsEe7elxVkRZqc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b8dff929b1779aa804208c8f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b8dff929b1779aa804208c8f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b8dff929b1779aa804208c8f',
#        'width': 64}],
#      'name': 'Waterfall',
#      'release_date': '2023-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4ce6IAUlzsEe7elxVkRZqc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vlyMzroosYUjkAfHLx6kF'},
#       'href': 'https://api.spotify.com/v1/artists/0vlyMzroosYUjkAfHLx6kF',
#       'id': '0vlyMzroosYUjkAfHLx6kF',
#       'name': "Pimm's Trio",
#       'type': 'artist',
#       'uri': 'spotify:artist:0vlyMzroosYUjkAfHLx6kF'}],
#     'disc_number': 1,
#     'duration_ms': 152099,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32300129'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Gyu7ttkfam04VeAgZEB3c'},
#     'href': 'https://api.spotify.com/v1/tracks/0Gyu7ttkfam04VeAgZEB3c',
#     'id': '0Gyu7ttkfam04VeAgZEB3c',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Waterfall',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a00378986fb61f6967130fc68b4e1b8c5403aff2?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0Gyu7ttkfam04VeAgZEB3c'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Lbuv3aiWkUkCnw0okZ4Fh'},
#        'href': 'https://api.spotify.com/v1/artists/1Lbuv3aiWkUkCnw0okZ4Fh',
#        'id': '1Lbuv3aiWkUkCnw0okZ4Fh',
#        'name': 'Songbird Trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Lbuv3aiWkUkCnw0okZ4Fh'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ae4cJFhCtFf2ZSO4UMewV'},
#      'href': 'https://api.spotify.com/v1/albums/0ae4cJFhCtFf2ZSO4UMewV',
#      'id': '0ae4cJFhCtFf2ZSO4UMewV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273362155b7e3bc0a2fb723d517',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02362155b7e3bc0a2fb723d517',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851362155b7e3bc0a2fb723d517',
#        'width': 64}],
#      'name': 'Memories Of Her Music',
#      'release_date': '2023-02-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0ae4cJFhCtFf2ZSO4UMewV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Lbuv3aiWkUkCnw0okZ4Fh'},
#       'href': 'https://api.spotify.com/v1/artists/1Lbuv3aiWkUkCnw0okZ4Fh',
#       'id': '1Lbuv3aiWkUkCnw0okZ4Fh',
#       'name': 'Songbird Trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Lbuv3aiWkUkCnw0okZ4Fh'}],
#     'disc_number': 1,
#     'duration_ms': 213037,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEXGF2399056'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/11Ya486KvEdIaYgsT8cwsw'},
#     'href': 'https://api.spotify.com/v1/tracks/11Ya486KvEdIaYgsT8cwsw',
#     'id': '11Ya486KvEdIaYgsT8cwsw',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Memories Of Her Music',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ac150a6bdcd22898c35408846d1b961e7a7c19ca?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:11Ya486KvEdIaYgsT8cwsw'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gk8knpaj4PjEEGHZ7UTYx'},
#        'href': 'https://api.spotify.com/v1/artists/7gk8knpaj4PjEEGHZ7UTYx',
#        'id': '7gk8knpaj4PjEEGHZ7UTYx',
#        'name': 'Les trois copines',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gk8knpaj4PjEEGHZ7UTYx'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4IJ2s5qJmU3XBSvxOWOPSF'},
#      'href': 'https://api.spotify.com/v1/albums/4IJ2s5qJmU3XBSvxOWOPSF',
#      'id': '4IJ2s5qJmU3XBSvxOWOPSF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b51c0304da9a258f9278f6d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b51c0304da9a258f9278f6d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b51c0304da9a258f9278f6d4',
#        'width': 64}],
#      'name': 'Equilibrio',
#      'release_date': '2022-12-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4IJ2s5qJmU3XBSvxOWOPSF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gk8knpaj4PjEEGHZ7UTYx'},
#       'href': 'https://api.spotify.com/v1/artists/7gk8knpaj4PjEEGHZ7UTYx',
#       'id': '7gk8knpaj4PjEEGHZ7UTYx',
#       'name': 'Les trois copines',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gk8knpaj4PjEEGHZ7UTYx'}],
#     'disc_number': 1,
#     'duration_ms': 151162,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB2299542'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/561vqucx8o1kmktdzuScCJ'},
#     'href': 'https://api.spotify.com/v1/tracks/561vqucx8o1kmktdzuScCJ',
#     'id': '561vqucx8o1kmktdzuScCJ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Equilibrio',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1e28aef2a4bfc6bd4511162fbd0d9f5f9967a970?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:561vqucx8o1kmktdzuScCJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
# ...
#     'disc_number': 1,
#     'duration_ms': 202115,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SEXGF2399044'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2IP1MFL8G8A5hIOIXhnaz1'},
#     'href': 'https://api.spotify.com/v1/tracks/2IP1MFL8G8A5hIOIXhnaz1',
#     'id': '2IP1MFL8G8A5hIOIXhnaz1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Meet Me In Mashatu',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f8a8e975977c4dda0142f3e14708c716c339afee?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2IP1MFL8G8A5hIOIXhnaz1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/201JTvpknVv2BZgtwDaQH6'},
#        'href': 'https://api.spotify.com/v1/artists/201JTvpknVv2BZgtwDaQH6',
#        'id': '201JTvpknVv2BZgtwDaQH6',
#        'name': 'Wildflower Trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:201JTvpknVv2BZgtwDaQH6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0Cy8DQQxtghkO1DrxydU4M'},
#      'href': 'https://api.spotify.com/v1/albums/0Cy8DQQxtghkO1DrxydU4M',
#      'id': '0Cy8DQQxtghkO1DrxydU4M',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27301ebd0e4557e54fe1d87b38d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0201ebd0e4557e54fe1d87b38d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485101ebd0e4557e54fe1d87b38d',
#        'width': 64}],
#      'name': 'The Wind',
#      'release_date': '2022-03-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0Cy8DQQxtghkO1DrxydU4M'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/201JTvpknVv2BZgtwDaQH6'},
#       'href': 'https://api.spotify.com/v1/artists/201JTvpknVv2BZgtwDaQH6',
#       'id': '201JTvpknVv2BZgtwDaQH6',
#       'name': 'Wildflower Trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:201JTvpknVv2BZgtwDaQH6'}],
#     'disc_number': 1,
#     'duration_ms': 237679,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32200944'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ssyhOkzW2tfNCiR7qihx4'},
#     'href': 'https://api.spotify.com/v1/tracks/3ssyhOkzW2tfNCiR7qihx4',
#     'id': '3ssyhOkzW2tfNCiR7qihx4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Wind',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f6ea9458e5a8c7e1b0513f8cc85db14a1b2797fb?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3ssyhOkzW2tfNCiR7qihx4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zNremLzDLV4qylYjP0nR2'},
#        'href': 'https://api.spotify.com/v1/artists/4zNremLzDLV4qylYjP0nR2',
#        'id': '4zNremLzDLV4qylYjP0nR2',
#        'name': 'Tore Lundblad',
#        'type': 'artist',
#        'uri': 'spotify:artist:4zNremLzDLV4qylYjP0nR2'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/74QY0bWf3DRBrHPujvE2IT'},
#      'href': 'https://api.spotify.com/v1/albums/74QY0bWf3DRBrHPujvE2IT',
#      'id': '74QY0bWf3DRBrHPujvE2IT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cfc13db8579ee551ba09b519',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cfc13db8579ee551ba09b519',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cfc13db8579ee551ba09b519',
#        'width': 64}],
#      'name': "We've Been Through This Before",
#      'release_date': '2023-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:74QY0bWf3DRBrHPujvE2IT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zNremLzDLV4qylYjP0nR2'},
#       'href': 'https://api.spotify.com/v1/artists/4zNremLzDLV4qylYjP0nR2',
#       'id': '4zNremLzDLV4qylYjP0nR2',
#       'name': 'Tore Lundblad',
#       'type': 'artist',
#       'uri': 'spotify:artist:4zNremLzDLV4qylYjP0nR2'}],
#     'disc_number': 1,
#     'duration_ms': 145028,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32300131'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5lk6Ro1xDJJyKAqjWd78JG'},
#     'href': 'https://api.spotify.com/v1/tracks/5lk6Ro1xDJJyKAqjWd78JG',
#     'id': '5lk6Ro1xDJJyKAqjWd78JG',
#     'is_local': False,
#     'is_playable': True,
#     'name': "We've Been Through This Before",
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8369e2ed8397091366400d708fd54e3847211729?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5lk6Ro1xDJJyKAqjWd78JG'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7297VsEKnQhcbuXvB3GJ68'},
#        'href': 'https://api.spotify.com/v1/artists/7297VsEKnQhcbuXvB3GJ68',
#        'id': '7297VsEKnQhcbuXvB3GJ68',
#        'name': 'Eddie Harper',
#        'type': 'artist',
#        'uri': 'spotify:artist:7297VsEKnQhcbuXvB3GJ68'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7DCCFRB1jWvUpP9lDZh03Y'},
#      'href': 'https://api.spotify.com/v1/albums/7DCCFRB1jWvUpP9lDZh03Y',
#      'id': '7DCCFRB1jWvUpP9lDZh03Y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273575301265f568a495b159d76',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02575301265f568a495b159d76',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851575301265f568a495b159d76',
#        'width': 64}],
#      'name': 'Everytime We Fall',
#      'release_date': '2023-02-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7DCCFRB1jWvUpP9lDZh03Y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7297VsEKnQhcbuXvB3GJ68'},
#       'href': 'https://api.spotify.com/v1/artists/7297VsEKnQhcbuXvB3GJ68',
#       'id': '7297VsEKnQhcbuXvB3GJ68',
#       'name': 'Eddie Harper',
#       'type': 'artist',
#       'uri': 'spotify:artist:7297VsEKnQhcbuXvB3GJ68'}],
#     'disc_number': 1,
#     'duration_ms': 223227,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32300469'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ZGlMy7TmvZNYTacuIyqSo'},
#     'href': 'https://api.spotify.com/v1/tracks/4ZGlMy7TmvZNYTacuIyqSo',
#     'id': '4ZGlMy7TmvZNYTacuIyqSo',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Everytime We Fall',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fc9b68608cb1958f6d1086fcc2d99d2fefbfd4c4?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4ZGlMy7TmvZNYTacuIyqSo'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hdiMvtIodxDuDN6Wq9Ibe'},
#        'href': 'https://api.spotify.com/v1/artists/0hdiMvtIodxDuDN6Wq9Ibe',
#        'id': '0hdiMvtIodxDuDN6Wq9Ibe',
#        'name': 'John B. Stewart',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hdiMvtIodxDuDN6Wq9Ibe'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/16uDEITezuspL8l4igLdHZ'},
#      'href': 'https://api.spotify.com/v1/albums/16uDEITezuspL8l4igLdHZ',
#      'id': '16uDEITezuspL8l4igLdHZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f78ab0a69d7616c3131f9e77',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f78ab0a69d7616c3131f9e77',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f78ab0a69d7616c3131f9e77',
#        'width': 64}],
#      'name': 'In A Sentimental Mood',
#      'release_date': '2022-10-21',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:16uDEITezuspL8l4igLdHZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hdiMvtIodxDuDN6Wq9Ibe'},
#       'href': 'https://api.spotify.com/v1/artists/0hdiMvtIodxDuDN6Wq9Ibe',
#       'id': '0hdiMvtIodxDuDN6Wq9Ibe',
#       'name': 'John B. Stewart',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hdiMvtIodxDuDN6Wq9Ibe'}],
#     'disc_number': 1,
#     'duration_ms': 242622,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32203872'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GLnrfMwiuJEqeb6IDsUMO'},
#     'href': 'https://api.spotify.com/v1/tracks/0GLnrfMwiuJEqeb6IDsUMO',
#     'id': '0GLnrfMwiuJEqeb6IDsUMO',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'In A Sentimental Mood',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/60ba844eb656bca2bad9e46db3481515e9e1a4ec?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0GLnrfMwiuJEqeb6IDsUMO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Al01GKqZ47q0irdqBXMQr'},
#        'href': 'https://api.spotify.com/v1/artists/2Al01GKqZ47q0irdqBXMQr',
#        'id': '2Al01GKqZ47q0irdqBXMQr',
#        'name': 'Nick Osman Trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Al01GKqZ47q0irdqBXMQr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/78uwjFsCIcHxqxxOWmx8kM'},
#      'href': 'https://api.spotify.com/v1/albums/78uwjFsCIcHxqxxOWmx8kM',
#      'id': '78uwjFsCIcHxqxxOWmx8kM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730114b214502669d7326c2c0b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020114b214502669d7326c2c0b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510114b214502669d7326c2c0b',
#        'width': 64}],
#      'name': 'I Saw The Sun',
#      'release_date': '2022-11-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:78uwjFsCIcHxqxxOWmx8kM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Al01GKqZ47q0irdqBXMQr'},
#       'href': 'https://api.spotify.com/v1/artists/2Al01GKqZ47q0irdqBXMQr',
#       'id': '2Al01GKqZ47q0irdqBXMQr',
#       'name': 'Nick Osman Trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Al01GKqZ47q0irdqBXMQr'}],
#     'disc_number': 1,
#     'duration_ms': 260540,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32204518'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3CpRRIHLxKHSBSvnCgGeD1'},
#     'href': 'https://api.spotify.com/v1/tracks/3CpRRIHLxKHSBSvnCgGeD1',
#     'id': '3CpRRIHLxKHSBSvnCgGeD1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'I Saw The Sun',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e247b730b5916f20be3137e96bceed39483fa9cb?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3CpRRIHLxKHSBSvnCgGeD1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-02-09T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4S1m9Gvs6oH0gHRnpkoAUT'},
#        'href': 'https://api.spotify.com/v1/artists/4S1m9Gvs6oH0gHRnpkoAUT',
#        'id': '4S1m9Gvs6oH0gHRnpkoAUT',
#        'name': 'Joanna Mason',
#        'type': 'artist',
#        'uri': 'spotify:artist:4S1m9Gvs6oH0gHRnpkoAUT'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UlBxNwVwKvU30I3RHUlAr'},
#      'href': 'https://api.spotify.com/v1/albums/0UlBxNwVwKvU30I3RHUlAr',
#      'id': '0UlBxNwVwKvU30I3RHUlAr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739428f618ce7a7ac9a3ff458a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029428f618ce7a7ac9a3ff458a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519428f618ce7a7ac9a3ff458a',
#        'width': 64}],
#      'name': 'Últimamente',
#      'release_date': '2022-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0UlBxNwVwKvU30I3RHUlAr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4S1m9Gvs6oH0gHRnpkoAUT'},
#       'href': 'https://api.spotify.com/v1/artists/4S1m9Gvs6oH0gHRnpkoAUT',
#       'id': '4S1m9Gvs6oH0gHRnpkoAUT',
#       'name': 'Joanna Mason',
#       'type': 'artist',
#       'uri': 'spotify:artist:4S1m9Gvs6oH0gHRnpkoAUT'}],
#     'disc_number': 1,
#     'duration_ms': 184186,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB2299546'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1BJmiWUEqMx2aqHqfIbeAQ'},
#     'href': 'https://api.spotify.com/v1/tracks/1BJmiWUEqMx2aqHqfIbeAQ',
#     'id': '1BJmiWUEqMx2aqHqfIbeAQ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Últimamente',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c055a3d60b7ae480b036a3c4b870afba93accc0e?cid=b95275128a104b84aeadfa666320994b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1BJmiWUEqMx2aqHqfIbeAQ'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV7EzJMK2FUI/tracks?offset=100&limit=100&market=DE&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 513}

# %%
jazz_playlist['items'][0]
# Out:
# {'added_at': '2023-02-09T23:01:00Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vmN5DgVFk2GDBHDu1ZJeb'},
#      'href': 'https://api.spotify.com/v1/artists/4vmN5DgVFk2GDBHDu1ZJeb',
#      'id': '4vmN5DgVFk2GDBHDu1ZJeb',
#      'name': 'The Groove Trio',
#      'type': 'artist',
#      'uri': 'spotify:artist:4vmN5DgVFk2GDBHDu1ZJeb'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/63Y51ZVDizFQyxA8znmmbn'},
#    'href': 'https://api.spotify.com/v1/albums/63Y51ZVDizFQyxA8znmmbn',
#    'id': '63Y51ZVDizFQyxA8znmmbn',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736abf1b888ce307bb6b15669c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026abf1b888ce307bb6b15669c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516abf1b888ce307bb6b15669c',
#      'width': 64}],
#    'name': 'Life in Space',
#    'release_date': '2022-11-20',
#    'release_date_precision': 'day',
#    'total_tracks': 3,
#    'type': 'album',
#    'uri': 'spotify:album:63Y51ZVDizFQyxA8znmmbn'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vmN5DgVFk2GDBHDu1ZJeb'},
#     'href': 'https://api.spotify.com/v1/artists/4vmN5DgVFk2GDBHDu1ZJeb',
#     'id': '4vmN5DgVFk2GDBHDu1ZJeb',
#     'name': 'The Groove Trio',
#     'type': 'artist',
#     'uri': 'spotify:artist:4vmN5DgVFk2GDBHDu1ZJeb'}],
#   'disc_number': 1,
#   'duration_ms': 183776,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'QZAKB2208501'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4SPtyeZCNeiPsquKP8B8ip'},
#   'href': 'https://api.spotify.com/v1/tracks/4SPtyeZCNeiPsquKP8B8ip',
#   'id': '4SPtyeZCNeiPsquKP8B8ip',
#   'is_local': False,
#   'is_playable': True,
#   'name': "Barney's",
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/b5e9ade22eb220a9f3f39c667a6941f7fbe3eb87?cid=b95275128a104b84aeadfa666320994b',
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4SPtyeZCNeiPsquKP8B8ip'},
#  'video_thumbnail': {'url': None}}

# %%
jazz_playlist["items"][0]["track"]["id"]
# Out:
# '4SPtyeZCNeiPsquKP8B8ip'

# %%
play_song('4SPtyeZCNeiPsquKP8B8ip')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/4SPtyeZCNeiPsquKP8B8ip?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(list(jazz_playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",jazz_playlist["total"]) #  Let's check items:
len(jazz_playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  513
# 100

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "37i9dQZF1DWV7EzJMK2FUI")

# %%
len(tracks)
# Out:
# 513

# %%
list_of_audio_features=[]
for item in range(0,513):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df=pd.DataFrame(list_of_audio_features)    
df
# Out:
#      danceability   energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.481  0.18800    7   -13.449     1       0.0400         0.979
# 1           0.348  0.15900    7   -18.122     1       0.0339         0.978
# 2           0.458  0.19000    7   -16.454     1       0.0362         0.955
# 3           0.475  0.13800    5   -17.099     0       0.0424         0.965
# 4           0.508  0.12600    0   -18.687     1       0.0422         0.947
# ..            ...      ...  ...       ...   ...          ...           ...
# 508         0.412  0.09020    5   -22.841     0       0.0304         0.830
# 509         0.355  0.00643    5   -26.746     1       0.0408         0.936
# 510         0.475  0.12300    5   -19.717     1       0.0372         0.939
# 511         0.533  0.04920    9   -19.517     1       0.0319         0.912
# 512         0.557  0.05930   10   -23.714     1       0.0383         0.827
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0               0.935    0.1040   0.2000   52.127  audio_features
# 1               0.973    0.1120   0.2900  106.682  audio_features
# 2               0.947    0.1560   0.1830   67.360  audio_features
# 3               0.884    0.0971   0.1230  118.338  audio_features
# 4               0.902    0.3660   0.0950  117.126  audio_features
# ..                ...       ...      ...      ...             ...
# 508             0.366    0.0889   0.0744   68.767  audio_features
# 509             0.952    0.1090   0.1590  139.781  audio_features
# 510             0.878    0.1140   0.2540   85.435  audio_features
# 511             0.862    0.1190   0.1660   96.842  audio_features
# 512             0.772    0.1080   0.1500  117.939  audio_features
#
#                          id                                   uri  \
# 0    4SPtyeZCNeiPsquKP8B8ip  spotify:track:4SPtyeZCNeiPsquKP8B8ip
# 1    7xi4NE5HjjIU4sjk2OP466  spotify:track:7xi4NE5HjjIU4sjk2OP466
# 2    4WnBYBYzYhS2I838VTxhaN  spotify:track:4WnBYBYzYhS2I838VTxhaN
# 3    1nsMASRDWwUwlBMmOuh80d  spotify:track:1nsMASRDWwUwlBMmOuh80d
# 4    1POSSxzIB7fLcHDDfbmjDZ  spotify:track:1POSSxzIB7fLcHDDfbmjDZ
# ..                      ...                                   ...
# 508  0oeUGF5YJJrH8I8dNKTLvl  spotify:track:0oeUGF5YJJrH8I8dNKTLvl
# 509  6ZDLHi8UtQeT203JjiQU6N  spotify:track:6ZDLHi8UtQeT203JjiQU6N
# 510  4oOkC6iNHVNtJJWHD8fqiL  spotify:track:4oOkC6iNHVNtJJWHD8fqiL
# 511  40ydDb82UYQzcZlqNsVj7N  spotify:track:40ydDb82UYQzcZlqNsVj7N
# 512  36cspwQPiIL9ElURDU7bGX  spotify:track:36cspwQPiIL9ElURDU7bGX
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4SPtyeZCNeiP...
# 1    https://api.spotify.com/v1/tracks/7xi4NE5HjjIU...
# 2    https://api.spotify.com/v1/tracks/4WnBYBYzYhS2...
# 3    https://api.spotify.com/v1/tracks/1nsMASRDWwUw...
# 4    https://api.spotify.com/v1/tracks/1POSSxzIB7fL...
# ..                                                 ...
# 508  https://api.spotify.com/v1/tracks/0oeUGF5YJJrH...
# 509  https://api.spotify.com/v1/tracks/6ZDLHi8UtQeT...
# 510  https://api.spotify.com/v1/tracks/4oOkC6iNHVNt...
# 511  https://api.spotify.com/v1/tracks/40ydDb82UYQz...
# 512  https://api.spotify.com/v1/tracks/36cspwQPiIL9...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4SPt...       183776
# 1    https://api.spotify.com/v1/audio-analysis/7xi4...       220879
# 2    https://api.spotify.com/v1/audio-analysis/4WnB...       201515
# 3    https://api.spotify.com/v1/audio-analysis/1nsM...       236785
# 4    https://api.spotify.com/v1/audio-analysis/1POS...       273124
# ..                                                 ...          ...
# 508  https://api.spotify.com/v1/audio-analysis/0oeU...       262210
# 509  https://api.spotify.com/v1/audio-analysis/6ZDL...       133208
# 510  https://api.spotify.com/v1/audio-analysis/4oOk...       186871
# 511  https://api.spotify.com/v1/audio-analysis/40yd...       167271
# 512  https://api.spotify.com/v1/audio-analysis/36cs...       229885
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 508               4
# 509               3
# 510               4
# 511               4
# 512               4
#
# [513 rows x 18 columns]

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("37i9dQZF1DWV7EzJMK2FUI")
# Out:
# ['Norris Walker Trio',
#  'John B. Stewart',
#  'Elvin Vanguard',
#  'Jenny Jones',
#  'Claus Waidtløw',
#  'Louie Hobbs Trio',
#  'Lachlan Wright Trio',
#  'Tiril Brandt',
#  'Måns & Dotter',
#  'Younglights',
#  'Billy Charlotte',
#  'Darlington',
#  'Mabon Clarke Quartet',
#  'Sarah Troedsson',
#  'Tannenbaum Trio',
#  'Green Trio',
#  'Jasmine Patterson',
#  'Tanner King Trio',
#  'Bedford and 7th',
#  'Dinner Club Band',
#  'Burt Mitchell',
#  'Jacky Bonnet Group',
#  'Leo Krepper',
#  'Baker St.',
#  'Jill & Henry',
#  'Fortune Morel Trio',
#  'Grayville Trio',
#  'Nordic Swing',
#  'Bill Walton',
#  'Akio',
#  'Magpie Jazz Trio',
#  'Mandevilla',
#  'Gaige Myers',
#  'Ted Ross Quartet',
#  'Marc Henley Trio',
#  'Soft Brush Touches',
#  'Mr. Right Time',
#  'Annie Berenson',
#  'LaSalle Street Trio',
#  'Charlie James-Walker',
#  'Urskogen Jazz',
#  'The Tealeaf Jazz Trio',
#  'Timothy Kay Band',
#  'Pablo Ilanda Trio',
#  'High North Trio',
#  'Henry Albert Trio',
#  'Matt Marantz Quartet',
#  'Eira Eld',
#  'Dan Evans-Parker',
#  'Or Bareket',
#  'Manor Blue',
#  'Midtown Trio',
#  'Andy Luma Trio',
#  'Tommies Trio',
#  'Alec Taylor Trio',
#  'Paul Chambers',
#  'Kevin Waters Group',
#  'Charles Daisey & Friends',
#  'Streetlight Trio',
#  'Turning Trio',
#  'Trio Del Norte',
#  'Southside Players',
#  'James Earle Trio',
#  'Saginaw Society',
#  'The Uptown Players',
#  'North West Trio',
#  'Lennie Weston',
#  'The North Sea Trio',
#  "Brandon's Three",
#  'Jonas Olofsson',
#  'Andy Miller Group',
#  'Reese Quartet',
#  'Noel Hayes',
#  'Coal Diamond Trio',
#  'Gottfried Barber Trio',
#  'Moonlight Jazz Trio',
#  'Alex Decante',
#  'Erik Moreau',
#  'Jazmina Tozer Three',
#  'Marcio Philomena',
#  'Andreas Gidlund',
#  'Tom Stills Quartet',
#  'Astor Shelby',
#  'Astoria Three',
#  'Lee Davis',
#  'Mitch Coleman',
#  'The Three Queens',
#  'More than Jazz',
#  'Herman Fred Trio',
#  'Holborns',
#  'Dusty Diamond Trio',
#  'Moonside Trio',
#  'The City of Birches',
#  "Pimm's Trio",
#  'Andy Goodman',
#  'Tribute Trio',
#  'Kingsley Thomas',
#  'Leslie Rossiter Band',
#  'Ben Lively',
#  'Nikolaj Hess',
#  'Flatland Park',
#  'Leonard Peters',
#  'Cleo Lounge Trio',
#  'Franklin Trio',
#  'Paul Moretti Trio',
#  'CMC 3',
#  'Nouveau Jazz Trio',
#  'Turtleneck Trio',
#  'Elton Willis Trio',
#  'Marc Frost',
#  'Goldilocks Trio',
#  'Hara Noda',
#  'Meadow Park',
#  'Carlton Maison Quartet',
#  'Tate Jackson Trio',
#  'Ted Jonson Trio',
#  'Tosh Rhann Band',
#  'Dee Burton',
#  'Keanan Field Group',
#  'Basinettes',
#  'Pearl Street Trio',
#  'Norwood Macdonald Group',
#  'Felix McCoy Quartet',
#  'The Central Park North',
#  'South North',
#  'Stan Getz',
#  'Joe Martin',
#  'Al Fowler Trio',
#  'Vincent Hall Trio',
#  'Andi Weiss Trio',
#  'Tyrone Coates & Friends',
#  'Three Four Trio',
#  'Hamilton Jones Trio',
#  'Maurice Font',
#  'Garry Cooper Trio',
#  'Juraj Stanik Trio',
#  'Bernhard Cohen',
#  "Sally's Trio",
#  'Reuben Plays',
#  'The Bob Davis Group',
#  'Rudy Winston',
#  'The Headliner Trio',
#  'George Kuntz Four',
#  'Cedar Wright',
#  'Joel Lyssarides',
#  'Mayfare Trio',
#  'The Lenny Ryan Trio',
#  'Tim Franks Trio',
#  'Nick Osman Trio',
#  'Tore Lundblad',
#  'Duponte et Duponte',
#  'Arta Porting',
#  'Fulton Street Players',
#  'Clover Post',
#  'Josh Lavender Trio',
#  'Red Stairs Jazz Quartet',
#  'The Sweetgreens',
#  'William Adams',
#  'Geeder',
#  'The Groove Trio',
#  'James & LIsa',
#  'Eduard Landings',
#  'Bill Evans',
#  'Bill Charlap Trio',
#  '6th Street Jazz',
#  'Mandy',
#  'Wendy Marcini',
#  'Vendla',
#  'Halcyon Jazz Band',
#  'Baxter Williams',
#  'Mornington',
#  'Bill Parker',
#  'Billy Hicks Quartet',
#  'Ikigai',
#  'Kendrettes',
#  'Hope Heights Jazz Band',
#  'Figgy Mold',
#  'The Collective',
#  'Loft Trio',
#  'Reed Stricklers',
#  'Lyle Jones',
#  'Archie Taylor',
#  'Piper Williamson',
#  'The Dox Band',
#  'Mike Coen',
#  'Yorkville',
#  'Kingsbury Station',
#  'Martin Hoper',
#  'Half Time Feel',
#  'Aurelius Markus Trio',
#  'Gene Hart Trio',
#  'The Ebbing Tides',
#  'Eternal Time Trio',
#  'Will Rivers Trio',
#  'Art Hirahara',
#  'Benjamine Leroy Quartet',
#  'The Holly Molly Trio',
#  'Bladverk Band',
#  'Red Garland',
#  'Hudson Harris & Haim',
#  'Irvin Smith Group',
#  'The Levon Trio',
#  'Long Island Quartet',
#  'Gillian Spencer Trio',
#  'Bridgerton Vail',
#  'Rainy Days Trio',
#  'Eric Rowland',
#  'Old Town Trio',
#  'We Three Trio',
#  'Ari Hoenig',
#  'Manuel Cali Band',
#  'Jaden Berry',
#  'Mino Conte & Co',
#  'Wildflower Trio',
#  'Martin Landström',
#  'James Jackson Jazz Trio',
#  'Kristian Hart Trio',
#  'Les trois copines',
#  'The Blue Green',
#  'Portraits in Jazz',
#  'Michael Stylez & Co',
#  'Charlie Regan Three',
#  'Odo Lefebvre',
#  'Anita Rosswell',
#  'KTZ Players',
#  'The Jazz Cultivators',
#  'Louis Silva Band',
#  'Art Taylor',
#  'Karl-Erik Trio',
#  'Light Hands Trio',
#  'Nitai Hershkovits',
#  'Meadowpoints',
#  'Mark Roswell Trio',
#  'The Don Mason Trio',
#  'Willowdale',
#  'Lia Riggs Trio',
#  'Henry Lindon',
#  'Songbird Trio',
#  'Foster Davies',
#  'West Village Trio',
#  'Ballroom Jazz Collective',
#  'Courtney Salas Group',
#  'The Mill Basin Band',
#  'Bruce Willmington & Co',
#  'Corin Stannard Trio',
#  'Ryder Quartet',
#  'Hermie',
#  'Motor City Trio',
#  'Hollbeck',
#  'The Boston Four',
#  'Leonardo Mendonça',
#  'Brad Mehldau Trio',
#  'Nordic Quartet',
#  'Bernstein Square',
#  'Nelly Vernon',
#  'Midnight Sound Band',
#  'Carla Anderson',
#  'Joanna Mason',
#  'Angela Rowles',
#  'Eddie Harper',
#  'Henning Witsell',
#  'Luc Brooks',
#  'Bill Evans Trio',
#  'Neil Chapman Green',
#  'Joey Alexander',
#  'Rudy Royston',
#  'Steve Luke & Holloway',
#  'Sophie Lemon Jazz',
#  'Greydon Park Band',
#  'Jon Belle',
#  'Madeleine West',
#  'Joyce Trio',
#  'Newington Green',
#  'Cecil Andrews',
#  'Cole Peers trio',
#  'Theo Rollins',
#  'Krista Lake Band',
#  'Chris Memento',
#  'Japari Park',
#  'Sodermalm Strand',
#  'Danny Ryan Jazz Band',
#  'Ray Horne Trio',
#  'Steve Blumenthal',
#  'Bergsundet',
#  'The Lyon Hearts',
#  'The Southern Belle',
#  'Southside Trio',
#  'Maxime Leroy Trio',
#  'Gustaf Scheringer Trio']
