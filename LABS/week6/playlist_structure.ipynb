# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

results = sp.search(q="blue moon",limit=3, market='DE')
results
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['external_urls']["spotify"]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=blue+moon&type=track&market=DE&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#        'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#        'id': '1YzCsTRb22dQkh9lghPIrp',
#        'name': 'Billie Holiday',
#        'type': 'artist',
#        'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4izD3SCRElbkO06i8yf4Zp'},
#      'href': 'https://api.spotify.com/v1/albums/4izD3SCRElbkO06i8yf4Zp',
#      'id': '4izD3SCRElbkO06i8yf4Zp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334708df3636189370a12e6c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234708df3636189370a12e6c1',
#        'width': 300},
# ...

# %% [markdown]
# Choose a random song and take the track_id

# %%
results["tracks"]["items"][0]["artists"][0]["id"]
# Out:
# '1YzCsTRb22dQkh9lghPIrp'

# %%
results["tracks"]["items"][0]["artists"][0]["href"]
# Out:
# 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp'

# %%
results["tracks"]["items"][0]["external_urls"]["spotify"]
# Out:
# 'https://open.spotify.com/track/1pZn8AX1WulW8IO338hE5D'

# %%
results["tracks"]["items"][0]["id"]
# Out:
# '1pZn8AX1WulW8IO338hE5D'

# %%
#https://open.spotify.com/playlist/37i9dQZF1DWV7EzJMK2FUI

# %%
from IPython.display import IFrame

# %%
track_id = '1pZn8AX1WulW8IO338hE5D'

IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1pZn8AX1WulW8IO338hE5D?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# play_song function

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song('1pZn8AX1WulW8IO338hE5D')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1pZn8AX1WulW8IO338hE5D?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=blue+moon&type=track&market=DE&offset=0&limit=3',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#                                               'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#                                               'id': '1YzCsTRb22dQkh9lghPIrp',
#                                               'name': 'Billie Holiday',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4izD3SCRElbkO06i8yf4Zp'},
#                                  'href': 'https://api.spotify.com/v1/albums/4izD3SCRElbkO06i8yf4Zp',
# ...

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#     'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#     'id': '1YzCsTRb22dQkh9lghPIrp',
#     'name': 'Billie Holiday',
#     'type': 'artist',
#     'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4izD3SCRElbkO06i8yf4Zp'},
#   'href': 'https://api.spotify.com/v1/albums/4izD3SCRElbkO06i8yf4Zp',
#   'id': '4izD3SCRElbkO06i8yf4Zp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27334708df3636189370a12e6c1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0234708df3636189370a12e6c1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485134708df3636189370a12e6c1',
#     'width': 64}],
#   'name': 'Solitude',
# ...

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# Get track id

# %%
results['tracks']['items'][0]['id']
# Out:
# '1pZn8AX1WulW8IO338hE5D'

# %%
import pandas as pd

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'Blue Moon' and the id is: 1pZn8AX1WulW8IO338hE5D
# The name of song is: 'Moonwalking in Calabasas (feat. Blueface) - Remix' and the id is: 73xjJ1TIE6WP3HNKczQE4F
# The name of song is: 'Blue Moon' and the id is: 5qfEAELRtcWyKjaheHHWQb

# %%
song = sp.search(q="Blue Moon", limit=3,market="DE") 
song
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Blue+Moon&type=track&market=DE&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1YzCsTRb22dQkh9lghPIrp'},
#        'href': 'https://api.spotify.com/v1/artists/1YzCsTRb22dQkh9lghPIrp',
#        'id': '1YzCsTRb22dQkh9lghPIrp',
#        'name': 'Billie Holiday',
#        'type': 'artist',
#        'uri': 'spotify:artist:1YzCsTRb22dQkh9lghPIrp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4izD3SCRElbkO06i8yf4Zp'},
#      'href': 'https://api.spotify.com/v1/albums/4izD3SCRElbkO06i8yf4Zp',
#      'id': '4izD3SCRElbkO06i8yf4Zp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334708df3636189370a12e6c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234708df3636189370a12e6c1',
#        'width': 300},
# ...

# %%
song["tracks"]["items"][2]
# Out:
# {'album': {'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1JQYskbOoudT9cylam24a3'},
#     'href': 'https://api.spotify.com/v1/artists/1JQYskbOoudT9cylam24a3',
#     'id': '1JQYskbOoudT9cylam24a3',
#     'name': 'The Marcels',
#     'type': 'artist',
#     'uri': 'spotify:artist:1JQYskbOoudT9cylam24a3'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5LNSdmCEtpQEGkNk652yjF'},
#   'href': 'https://api.spotify.com/v1/albums/5LNSdmCEtpQEGkNk652yjF',
#   'id': '5LNSdmCEtpQEGkNk652yjF',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d42cbb433cdc04f7337d8fdb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d42cbb433cdc04f7337d8fdb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d42cbb433cdc04f7337d8fdb',
#     'width': 64}],
#   'name': 'The Best Of The Marcels',
# ...

# %% [markdown]
# Import a playlist

# %%
jazz_playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DWV7EzJMK2FUI",market="DE")

# %%
jazz_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWV7EzJMK2FUI/tracks?offset=0&limit=100&market=DE&additional_types=track',
#  'items': [{'added_at': '2023-02-16T23:01:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vmN5DgVFk2GDBHDu1ZJeb'},
#        'href': 'https://api.spotify.com/v1/artists/4vmN5DgVFk2GDBHDu1ZJeb',
#        'id': '4vmN5DgVFk2GDBHDu1ZJeb',
#        'name': 'The Groove Trio',
#        'type': 'artist',
#        'uri': 'spotify:artist:4vmN5DgVFk2GDBHDu1ZJeb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63Y51ZVDizFQyxA8znmmbn'},
# ...

# %%
jazz_playlist['items'][0]
# Out:
# {'added_at': '2023-02-16T23:01:00Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vmN5DgVFk2GDBHDu1ZJeb'},
#      'href': 'https://api.spotify.com/v1/artists/4vmN5DgVFk2GDBHDu1ZJeb',
#      'id': '4vmN5DgVFk2GDBHDu1ZJeb',
#      'name': 'The Groove Trio',
#      'type': 'artist',
#      'uri': 'spotify:artist:4vmN5DgVFk2GDBHDu1ZJeb'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/63Y51ZVDizFQyxA8znmmbn'},
#    'href': 'https://api.spotify.com/v1/albums/63Y51ZVDizFQyxA8znmmbn',
#    'id': '63Y51ZVDizFQyxA8znmmbn',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736abf1b888ce307bb6b15669c',
# ...

# %%
jazz_playlist["items"][0]["track"]["id"]
# Out:
# '4SPtyeZCNeiPsquKP8B8ip'

# %%
play_song('4SPtyeZCNeiPsquKP8B8ip')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/4SPtyeZCNeiPsquKP8B8ip?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(list(jazz_playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",jazz_playlist["total"]) #  Let's check items:
len(jazz_playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  525
# 100

# %% [markdown]
# Function to get tracks from the playlist

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
jazz_tracks=get_playlist_tracks("spotify", "37i9dQZF1DWV7EzJMK2FUI")

# %%
len(jazz_tracks)
# Out:
# 525

# %%
jazz_tracks
# Out:
# [{'added_at': '2023-02-16T23:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4vmN5DgVFk2GDBHDu1ZJeb'},
#       'href': 'https://api.spotify.com/v1/artists/4vmN5DgVFk2GDBHDu1ZJeb',
#       'id': '4vmN5DgVFk2GDBHDu1ZJeb',
#       'name': 'The Groove Trio',
#       'type': 'artist',
#       'uri': 'spotify:artist:4vmN5DgVFk2GDBHDu1ZJeb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/63Y51ZVDizFQyxA8znmmbn'},
#     'href': 'https://api.spotify.com/v1/albums/63Y51ZVDizFQyxA8znmmbn',
#     'id': '63Y51ZVDizFQyxA8znmmbn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736abf1b888ce307bb6b15669c',
# ...

# %% [markdown]
# List of track features from the playlist

# %%
list_of_audio_features_jazz=[]
for item in range(0,513):
    list_of_audio_features_jazz.append(sp.audio_features(jazz_tracks[item]["track"]["id"])[0])

# %%
df_jazz=pd.DataFrame(list_of_audio_features_jazz)    
df_jazz
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.481  0.1880    7   -13.449     1       0.0400         0.979
# 1           0.348  0.1590    7   -18.122     1       0.0339         0.978
# 2           0.458  0.1900    7   -16.454     1       0.0362         0.955
# 3           0.475  0.1380    5   -17.099     0       0.0424         0.965
# 4           0.508  0.1260    0   -18.687     1       0.0422         0.947
# ..            ...     ...  ...       ...   ...          ...           ...
# 508         0.445  0.1590    0   -14.159     1       0.0419         0.924
# 509         0.508  0.0556    7   -22.714     1       0.0404         0.944
# 510         0.523  0.1340    0   -20.673     1       0.0362         0.973
# 511         0.309  0.1040    0   -23.378     1       0.0428         0.976
# 512         0.353  0.0717    5   -21.734     1       0.0318         0.967
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# Artists names from tracks

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("37i9dQZF1DWV7EzJMK2FUI")
# Out:
# ['Leslie Rossiter Band',
#  'The Jazz Cultivators',
#  'Bruce Willmington & Co',
#  'Turning Trio',
#  'Gustaf Scheringer Trio',
#  'Coal Diamond Trio',
#  'West Village Trio',
#  'Lennie Weston',
#  'Mabon Clarke Quartet',
#  'Bill Evans',
#  'Billy Charlotte',
#  'Martin Landström',
#  'Pearl Street Trio',
#  'Herman Fred Trio',
#  'Jon Belle',
#  'Green Trio',
#  'Danny Ryan Jazz Band',
#  'Three Four Trio',
#  'The Blue Green',
#  'Red Stairs Jazz Quartet',
#  'Reed Stricklers',
#  'Paul Moretti Trio',
#  'Southside Players',
#  "Brandon's Three",
#  'Tom Stills Quartet',
#  'Nordic Quartet',
#  'Sarah Troedsson',
#  'Jazmina Tozer Three',
#  'Bill Charlap Trio',
#  'George Kuntz Four',
#  'Tim Franks Trio',
#  'Steve Luke & Holloway',
#  'Jennie Reigen',
#  'Kristian Hart Trio',
#  'The Lyon Hearts',
#  'Geeder',
#  'Grayville Trio',
#  'Jaden Berry',
#  "Sally's Trio",
#  'Akio',
#  'Matt Marantz Quartet',
#  'The Levon Trio',
#  'Mitch Coleman',
#  'Henry Albert Trio',
# ...

# %% [markdown]
# Import another playlist

# %%
sixties_playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DXaKIA8E7WcJj",market="DE")

# %%
sixties_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaKIA8E7WcJj/tracks?offset=0&limit=100&market=DE&additional_types=track',
#  'items': [{'added_at': '2022-08-12T11:06:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3RwQ26hR2tJtA8F9p2n7jG'},
#        'href': 'https://api.spotify.com/v1/artists/3RwQ26hR2tJtA8F9p2n7jG',
#        'id': '3RwQ26hR2tJtA8F9p2n7jG',
#        'name': 'The Temptations',
#        'type': 'artist',
#        'uri': 'spotify:artist:3RwQ26hR2tJtA8F9p2n7jG'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/45tweuKI0zdh8zgKo05cTw'},
# ...

# %%
sixties_playlist["items"][0]["track"]["id"]
# Out:
# '745H5CctFr12Mo7cqa1BMH'

# %%
play_song('745H5CctFr12Mo7cqa1BMH')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/745H5CctFr12Mo7cqa1BMH?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
sixties_tracks=get_playlist_tracks("spotify", "37i9dQZF1DXaKIA8E7WcJj")

# %%
list_of_audio_features_sixties=[]
for item in range(0,150):
    list_of_audio_features_sixties.append(sp.audio_features(sixties_tracks[item]["track"]["id"])[0])

# %%
df_sixties=pd.DataFrame(list_of_audio_features_sixties)
df_sixties
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.572   0.418    0   -10.738     1       0.0349      0.635000
# 1           0.526   0.436    1    -6.020     1       0.0232      0.098100
# 2           0.731   0.837    9    -8.673     1       0.0477      0.000287
# 3           0.691   0.507   11   -10.230     1       0.0343      0.627000
# 4           0.491   0.605    7   -10.098     1       0.0367      0.192000
# ..            ...     ...  ...       ...   ...          ...           ...
# 145         0.864   0.346    4   -12.918     1       0.0365      0.277000
# 146         0.594   0.889    5    -7.775     1       0.2460      0.768000
# 147         0.711   0.663    2    -9.262     1       0.0308      0.260000
# 148         0.259   0.241    2   -15.955     1       0.0420      0.554000
# 149         0.456   0.470    2    -9.564     1       0.0294      0.513000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# ### Function to include more songs in the playlist

# %%
def new_playlist(playlist_id):
    playlist=sp.user_playlist_tracks("Spotify", playlist_id,market="DE")
    playlist_tracks=get_playlist_tracks("Spotify", playlist_id)
    number_songs=len(playlist_tracks)
    list_of_audio_features=[]
    for item in range(0,int(number_songs)):
        list_of_audio_features.append(sp.audio_features(playlist_tracks[item]["track"]["id"])[0])
    df_playlist = pd.DataFrame(list_of_audio_features)
    return df_playlist

# %%
rock_playlist = new_playlist("73wCNB78g3O2nIDLYJA35G")

# %%
hip_hop_playlist = new_playlist("5pvJLjAhcKCHXGOb7pEbBZ")

# %%
indie_playlist = new_playlist("37i9dQZF1DWWM6GBnxtToT")

# %%
blues_playlist = new_playlist("37i9dQZF1DXd9rSDyQguIk")

# %%
flamenco_playlist = new_playlist("37i9dQZF1DWTfrrcwZAlVH")

# %%
folk_playlist = new_playlist("37i9dQZF1EQp62d3Dl7ECY")

# %%
reggae_playlist = new_playlist("37i9dQZF1EQpjs4F0vUZ1x")

# %%
punk_playlist = new_playlist("4gmu3yP2ESftcnczbzMnQ6")

# %%
britpop_playlist = new_playlist("6kBBVVMbXPQCrkQ09TBvmW")

# %%
techno_playlist = new_playlist("1yswYW9ONg19LAlBOv87qq")

# %%
classical_playlist = new_playlist("1h0CEZCm6IbFTbxThn6Xcs")

# %%
df_playlist=pd.concat([df_jazz, df_sixties, rock_playlist, hip_hop_playlist, indie_playlist, blues_playlist, flamenco_playlist, folk_playlist, reggae_playlist, punk_playlist, britpop_playlist, techno_playlist, classical_playlist])

# %%
df_playlist
# Out:
#      danceability   energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.481  0.18800    7   -13.449     1       0.0400         0.979
# 1           0.348  0.15900    7   -18.122     1       0.0339         0.978
# 2           0.458  0.19000    7   -16.454     1       0.0362         0.955
# 3           0.475  0.13800    5   -17.099     0       0.0424         0.965
# 4           0.508  0.12600    0   -18.687     1       0.0422         0.947
# ..            ...      ...  ...       ...   ...          ...           ...
# 179         0.162  0.06820    3   -21.254     1       0.0393         0.989
# 180         0.489  0.01410    2   -23.312     0       0.0453         0.994
# 181         0.273  0.00516    4   -27.926     0       0.0397         0.994
# 182         0.130  0.08600   10   -21.920     1       0.0373         0.932
# 183         0.176  0.00600    5   -42.238     1       0.0384         0.899
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
df_playlist['type'].value_counts()
# Out:
# audio_features    2241
# Name: type, dtype: int64

# %%
df_playlist.drop(columns=['type', 'uri', 'track_href'], inplace=True)

# %%
df_playlist.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'id', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df_playlist_categorical = df_playlist.drop(columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature'])
#df_playlist_categorical = df_playlist['analysis_url']

# %%
df_playlist_categorical
# Out:
#                          id                                       analysis_url
# 0    4SPtyeZCNeiPsquKP8B8ip  https://api.spotify.com/v1/audio-analysis/4SPt...
# 1    7xi4NE5HjjIU4sjk2OP466  https://api.spotify.com/v1/audio-analysis/7xi4...
# 2    4WnBYBYzYhS2I838VTxhaN  https://api.spotify.com/v1/audio-analysis/4WnB...
# 3    1nsMASRDWwUwlBMmOuh80d  https://api.spotify.com/v1/audio-analysis/1nsM...
# 4    1POSSxzIB7fLcHDDfbmjDZ  https://api.spotify.com/v1/audio-analysis/1POS...
# ..                      ...                                                ...
# 179  2TOUdZaG9w8pbGVoH0GohP  https://api.spotify.com/v1/audio-analysis/2TOU...
# 180  3SokfTeWt84ZeUenQUPzAX  https://api.spotify.com/v1/audio-analysis/3Sok...
# 181  73cFlYu63RLX1qn9qzMXiJ  https://api.spotify.com/v1/audio-analysis/73cF...
# 182  3Sy6wgTNEp6vSgLs4EyXAf  https://api.spotify.com/v1/audio-analysis/3Sy6...
# 183  4wudbbceOZKjRlhTtbHvAs  https://api.spotify.com/v1/audio-analysis/4wud...
#
# [2241 rows x 2 columns]

# %%
df_playlist_numerical = df_playlist.drop(columns=['id', 'analysis_url'])

# %%
# 1. Scale features --> scaler.fit
# 2. Clustering (choosing k)--> kmean.fit
# 3. getting clusters/cluster labels

#user function -> song -> id --> audio_features -> scale --> kmeans.predict --> random song from same cluster

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### 1. Scale features

# %%
df_playlist_numerical.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   2241.000000  2241.000000  2241.000000  2241.000000  2241.000000
# mean       0.549040     0.513066     5.083891   -11.662120     0.660419
# std        0.175859     0.311309     3.515795     6.847873     0.473673
# min        0.065900     0.000707     0.000000   -43.657000     0.000000
# 25%        0.434000     0.175000     2.000000   -16.562000     0.000000
# 50%        0.541000     0.563000     5.000000    -9.390000     1.000000
# 75%        0.680000     0.803000     8.000000    -6.371000     1.000000
# max        0.965000     0.995000    11.000000    -1.278000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  2241.000000   2241.000000       2241.000000  2241.000000  2241.000000
# mean      0.070356      0.440115          0.317123     0.164668     0.434484
# std       0.076068      0.403881          0.400910     0.130844     0.285666
# ...

# %%
scaler = StandardScaler()
scaler.fit(df_playlist_numerical)
playlist_scaled = scaler.transform(df_playlist_numerical)
playlist_scaled_df = pd.DataFrame(playlist_scaled, columns = df_playlist_numerical.columns)
display(df_playlist_numerical.head())
print()
display(playlist_scaled_df.head())
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.481   0.188    7   -13.449     1       0.0400         0.979
# 1         0.348   0.159    7   -18.122     1       0.0339         0.978
# 2         0.458   0.190    7   -16.454     1       0.0362         0.955
# 3         0.475   0.138    5   -17.099     0       0.0424         0.965
# 4         0.508   0.126    0   -18.687     1       0.0422         0.947
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0             0.935    0.1040    0.200   52.127       183776               4
# 1             0.973    0.1120    0.290  106.682       220879               4
# 2             0.947    0.1560    0.183   67.360       201515               4
# 3             0.884    0.0971    0.123  118.338       236785               4
# 4             0.902    0.3660    0.095  117.126       273124               4
#    danceability    energy       key  loudness      mode  speechiness  \
# ...

# %% [markdown]
# ### 2. Clustering (choosing k)--> kmean.fit

# %%
kmeans = KMeans(n_clusters=5, random_state=1234)
kmeans.fit(playlist_scaled_df)
# Out:
# KMeans(n_clusters=5, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([3, 3, 3, ..., 3, 3, 0])

# %%
# assign a cluster to each example
labels = kmeans.predict(playlist_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(df_playlist_numerical.to_numpy()[row_ix, 1], df_playlist_numerical.to_numpy()[row_ix, 3])
    # show the plot
pyplot.show()

# %% [markdown]
# ### 3. getting clusters/cluster labels

# %%
clusters = kmeans.predict(playlist_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     191
# 1     212
# 2    1041
# 3     605
# 4     192
# dtype: int64

# %%
#playlist_df = pd.DataFrame(X)
df_playlist_numerical["cluster"] = clusters
df_playlist_numerical
# Out:
#      danceability   energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.481  0.18800    7   -13.449     1       0.0400         0.979
# 1           0.348  0.15900    7   -18.122     1       0.0339         0.978
# 2           0.458  0.19000    7   -16.454     1       0.0362         0.955
# 3           0.475  0.13800    5   -17.099     0       0.0424         0.965
# 4           0.508  0.12600    0   -18.687     1       0.0422         0.947
# ..            ...      ...  ...       ...   ...          ...           ...
# 179         0.162  0.06820    3   -21.254     1       0.0393         0.989
# 180         0.489  0.01410    2   -23.312     0       0.0453         0.994
# 181         0.273  0.00516    4   -27.926     0       0.0397         0.994
# 182         0.130  0.08600   10   -21.920     1       0.0373         0.932
# 183         0.176  0.00600    5   -42.238     1       0.0384         0.899
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
df_playlist_numerical[df_playlist_numerical['cluster'] == 2].sample()
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 75         0.618   0.938    9    -3.442     1       0.0456        0.0179
#
#     instrumentalness  liveness  valence   tempo  duration_ms  time_signature  \
# 75               0.0     0.167    0.875  91.455       269000               4
#
#     cluster
# 75        2

# %%
kmeans.inertia_
# Out:
# 16490.696249231216

# %%
kmeans5 = KMeans(n_clusters=5,
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=1,
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans5.fit(playlist_scaled_df)
print(kmeans5.inertia_)
# Out:
# 16739.743062918078

# %%
import pickle

with open ("scaler.pickle", "wb") as f:
    pickle.dump(scaler, f)

with open("kmeans5.pickle", "wb") as f:
    pickle.dump(kmeans5, f)

# %% [markdown]
# ## Chosing K

# %% [markdown]
# We have used K=3 by default for now - but we know that 3 might not be the optimal number of clusters for our dataset. Having a metric like inertia, we can compute it for several K values and then use the "elbow method" to choose the best K.
#
# We will now leave all other parameters with their default value, since it seems to work pretty well.

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(playlist_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# ### Silouhette

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(playlist_scaled_df)
    
    #filename = "Model/kmeans_" + str(k) + ".pickle"
    #with open(filename, "wb") as f:
        #pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(playlist_scaled_df, kmeans.predict(playlist_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
df_playlist_numerical
# Out:
#      danceability   energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.481  0.18800    7   -13.449     1       0.0400         0.979
# 1           0.348  0.15900    7   -18.122     1       0.0339         0.978
# 2           0.458  0.19000    7   -16.454     1       0.0362         0.955
# 3           0.475  0.13800    5   -17.099     0       0.0424         0.965
# 4           0.508  0.12600    0   -18.687     1       0.0422         0.947
# ..            ...      ...  ...       ...   ...          ...           ...
# 179         0.162  0.06820    3   -21.254     1       0.0393         0.989
# 180         0.489  0.01410    2   -23.312     0       0.0453         0.994
# 181         0.273  0.00516    4   -27.926     0       0.0397         0.994
# 182         0.130  0.08600   10   -21.920     1       0.0373         0.932
# 183         0.176  0.00600    5   -42.238     1       0.0384         0.899
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
df_playlist_categorical
# Out:
#                          id                                       analysis_url
# 0    4SPtyeZCNeiPsquKP8B8ip  https://api.spotify.com/v1/audio-analysis/4SPt...
# 1    7xi4NE5HjjIU4sjk2OP466  https://api.spotify.com/v1/audio-analysis/7xi4...
# 2    4WnBYBYzYhS2I838VTxhaN  https://api.spotify.com/v1/audio-analysis/4WnB...
# 3    1nsMASRDWwUwlBMmOuh80d  https://api.spotify.com/v1/audio-analysis/1nsM...
# 4    1POSSxzIB7fLcHDDfbmjDZ  https://api.spotify.com/v1/audio-analysis/1POS...
# ..                      ...                                                ...
# 179  2TOUdZaG9w8pbGVoH0GohP  https://api.spotify.com/v1/audio-analysis/2TOU...
# 180  3SokfTeWt84ZeUenQUPzAX  https://api.spotify.com/v1/audio-analysis/3Sok...
# 181  73cFlYu63RLX1qn9qzMXiJ  https://api.spotify.com/v1/audio-analysis/73cF...
# 182  3Sy6wgTNEp6vSgLs4EyXAf  https://api.spotify.com/v1/audio-analysis/3Sy6...
# 183  4wudbbceOZKjRlhTtbHvAs  https://api.spotify.com/v1/audio-analysis/4wud...
#
# [2241 rows x 2 columns]

# %%
df_playlist_numerical = pd.concat([df_playlist_categorical, df_playlist_numerical], axis=1)

# %%
playlist = df_playlist_numerical
playlist
# Out:
#                          id  \
# 0    4SPtyeZCNeiPsquKP8B8ip
# 1    7xi4NE5HjjIU4sjk2OP466
# 2    4WnBYBYzYhS2I838VTxhaN
# 3    1nsMASRDWwUwlBMmOuh80d
# 4    1POSSxzIB7fLcHDDfbmjDZ
# ..                      ...
# 179  2TOUdZaG9w8pbGVoH0GohP
# 180  3SokfTeWt84ZeUenQUPzAX
# 181  73cFlYu63RLX1qn9qzMXiJ
# 182  3Sy6wgTNEp6vSgLs4EyXAf
# 183  4wudbbceOZKjRlhTtbHvAs
#
#                                           analysis_url  danceability   energy  \
# 0    https://api.spotify.com/v1/audio-analysis/4SPt...         0.481  0.18800
# 1    https://api.spotify.com/v1/audio-analysis/7xi4...         0.348  0.15900
# 2    https://api.spotify.com/v1/audio-analysis/4WnB...         0.458  0.19000
# 3    https://api.spotify.com/v1/audio-analysis/1nsM...         0.475  0.13800
# 4    https://api.spotify.com/v1/audio-analysis/1POS...         0.508  0.12600
# ..                                                 ...           ...      ...
# ...

# %%
playlist.to_csv('playlist.csv')
